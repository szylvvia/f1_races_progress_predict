# %%
# Na bazie OpenF1Api via https://openf1.org

# %%
# wyznaczenie liczby sezonów - lata od tzw "ery hybrydowej" 2014-2025
def seasons_count(end_year=2025):
    start_year = 2014
    seasons = list()
    for year in range(start_year, end_year + 1):
        seasons.append(year)
    return seasons

seasons = seasons_count(2025)
print(seasons)
# Out:
# [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025]

# %%
# formatowanie pól daty i czasu

from datetime import datetime

def format_datetime_fields(datetime_string):
    dt = datetime.fromisoformat(datetime_string.replace('Z', '+00:00'))
    return dt.date().isoformat(), dt.time().isoformat()

# %%
# pobiernie meetiings - race week 
import requests
import pandas as pd

def get_all_meetings(start_season=2014, end_season=2025):
    meetings = []
    
    for year in range(start_season, end_season + 1):
        url = f"https://api.openf1.org/v1/meetings?year={year}"
        response = requests.get(url)
        
        if response.status_code == 200:
            data = response.json()
            
            if isinstance(data, list) and len(data) > 0:
                for meeting in data:
                    date_start, time_start = format_datetime_fields(meeting['date_start'])
                    meetings.append({
                        "circuit_key": meeting['circuit_key'],
                        "circuit_short_name": meeting['circuit_short_name'],
                        "country_code": meeting['country_code'],
                        "country_key": meeting['country_key'],
                        "country_name": meeting['country_name'],
                        "date_start": date_start,
                        "time_start": time_start,
                        "gmt_offset": meeting['gmt_offset'],
                        "location": meeting['location'],
                        "meeting_key": meeting['meeting_key'],
                        "meeting_name": meeting['meeting_name'],
                        "meeting_official_name": meeting['meeting_official_name'],
                        "year": meeting['year'],
                    })
                print(f"Fetched {len(data)} meetings for {year}")
            else:
                print(f"No meetings found for {year}")
        else:
            print(f"Error fetching data for {year}: {response.status_code}")
    
    return pd.DataFrame(meetings)

# %%
all_meetings_df = get_all_meetings(2014, 2025)
all_meetings_df.head()
# Out:
# No meetings found for 2014
# No meetings found for 2015
# No meetings found for 2016
# Error fetching data for 2017: 429
# No meetings found for 2018
# Error fetching data for 2019: 429
# Error fetching data for 2020: 429
# No meetings found for 2021
# No meetings found for 2022
# Fetched 23 meetings for 2023
# Fetched 25 meetings for 2024
# Fetched 18 meetings for 2025
#    circuit_key circuit_short_name country_code  country_key  country_name  \
# 0           63             Sakhir          BRN           36       Bahrain
# 1           63             Sakhir          BRN           36       Bahrain
# 2          149             Jeddah          KSA          153  Saudi Arabia
# 3           10          Melbourne          AUS            5     Australia
# 4          144               Baku          AZE           30    Azerbaijan
#
#    date_start time_start gmt_offset   location  meeting_key  \
# 0  2023-02-23   07:00:00   03:00:00     Sakhir         1140
# 1  2023-03-03   11:30:00   03:00:00     Sakhir         1141
# 2  2023-03-17   13:30:00   03:00:00     Jeddah         1142
# 3  2023-03-31   01:30:00   11:00:00  Melbourne         1143
# 4  2023-04-28   09:30:00   04:00:00       Baku         1207
#
#                meeting_name                        meeting_official_name  year
# 0        Pre-Season Testing     FORMULA 1 ARAMCO PRE-SEASON TESTING 2023  2023
# 1        Bahrain Grand Prix   FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2023  2023
# 2  Saudi Arabian Grand Prix  FORMULA 1 STC SAUDI ARABIAN GRAND PRIX 2023  2023
# 3     Australian Grand Prix   FORMULA 1 ROLEX AUSTRALIAN GRAND PRIX 2023  2023
# 4     Azerbaijan Grand Prix         FORMULA 1 AZERBAIJAN GRAND PRIX 2023  2023

# %%
# pobierz kolumny z tabeli meetings
meetings_columns = all_meetings_df.columns.tolist()
print("Meetings columns:", meetings_columns)
# Out:
# Meetings columns: ['circuit_key', 'circuit_short_name', 'country_code', 'country_key', 'country_name', 'date_start', 'time_start', 'gmt_offset', 'location', 'meeting_key', 'meeting_name', 'meeting_official_name', 'year']

# %%
# unikalne wartości w kolumnie meeting_key
meetings_key_unique = all_meetings_df['meeting_key'].unique()
print(meetings_key_unique)
# Out:
# [1140 1141 1142 1143 1207 1208 1210 1211 1212 1213 1214 1215 1216 1217
#  1218 1219 1220 1221 1222 1223 1224 1225 1226 1228 1229 1230 1231 1232
#  1233 1234 1235 1236 1237 1238 1239 1240 1241 1242 1243 1244 1245 1246
#  1247 1248 1249 1250 1251 1252 1253 1254 1255 1256 1257 1258 1259 1260
#  1261 1262 1263 1264 1277 1265 1266 1267 1268 1269]

# %%
# pobranie poszczególnych wyścigów w określonych sezonach - sessions
import requests
import pandas as pd
from time import sleep

def get_all_sessions(meetings):
    sessions = []
    
    for meeting in meetings_key_unique:
        url = f"https://api.openf1.org/v1/sessions?meeting_key={meeting}"
        response = requests.get(url)
        
        if response.status_code == 200:
            data = response.json()
            
            if isinstance(data, list) and len(data) > 0:
                for session in data:
                    date_start, time_start = format_datetime_fields(session['date_start'])
                    date_end, time_end = format_datetime_fields(session['date_end'])
                    
                    sessions.append({
                        'meeting_key': session['meeting_key'],
                        'year': session['year'],
                        'session_key': session['session_key'],
                        'session_type': session['session_type'],
                        'session_name': session['session_name'],
                        'date_start': date_start,
                        'time_start': time_start,
                        'date_end': date_end,
                        'time_end': time_end,
                        'gmt_offset': session['gmt_offset'],
                        'location': session['location'],
                        'country_name': session['country_name'],
                        'country_code': session['country_code'],
                        'circuit_short_name': session['circuit_short_name'],
                    })
                
                print(f"Fetched {len(data)} sessions for {meeting}")
            else:
                print(f"No sessions found for {meeting}")
        else:
            print(f"Error fetching data for {meeting}: {response.status_code}")
        sleep(1)
    return pd.DataFrame(sessions)

# Pobierz wszystkie sesje 2014–2024
all_sessions_df = get_all_sessions(meetings_key_unique)
# Out:
# Fetched 3 sessions for 1140
# Fetched 5 sessions for 1141
# Fetched 5 sessions for 1142
# Fetched 5 sessions for 1143
# Fetched 5 sessions for 1207
# Fetched 5 sessions for 1208
# Fetched 5 sessions for 1210
# Fetched 5 sessions for 1211
# Fetched 5 sessions for 1212
# Fetched 5 sessions for 1213
# Fetched 5 sessions for 1214
# Fetched 5 sessions for 1215
# Fetched 5 sessions for 1216
# Fetched 5 sessions for 1217
# Fetched 5 sessions for 1218
# Fetched 5 sessions for 1219
# Fetched 5 sessions for 1220
# Fetched 5 sessions for 1221
# Fetched 5 sessions for 1222
# Fetched 5 sessions for 1223
# Fetched 5 sessions for 1224
# Fetched 5 sessions for 1225
# Fetched 5 sessions for 1226
# Fetched 3 sessions for 1228
# Fetched 5 sessions for 1229
# Fetched 5 sessions for 1230
# Fetched 5 sessions for 1231
# Fetched 5 sessions for 1232
# Fetched 5 sessions for 1233
# Fetched 5 sessions for 1234
# Fetched 5 sessions for 1235
# Fetched 5 sessions for 1236
# Fetched 5 sessions for 1237
# Fetched 5 sessions for 1238
# Fetched 5 sessions for 1239
# Fetched 5 sessions for 1240
# Fetched 5 sessions for 1241
# Fetched 5 sessions for 1242
# Fetched 5 sessions for 1243
# Fetched 5 sessions for 1244
# Fetched 5 sessions for 1245
# Fetched 5 sessions for 1246
# Fetched 5 sessions for 1247
# Fetched 5 sessions for 1248
# Fetched 5 sessions for 1249
# Fetched 5 sessions for 1250
# Fetched 5 sessions for 1251
# Fetched 5 sessions for 1252
# Fetched 3 sessions for 1253
# Fetched 5 sessions for 1254
# Fetched 5 sessions for 1255
# Fetched 5 sessions for 1256
# Fetched 5 sessions for 1257
# Fetched 5 sessions for 1258
# Fetched 5 sessions for 1259
# Fetched 5 sessions for 1260
# Fetched 5 sessions for 1261
# Fetched 5 sessions for 1262
# Fetched 5 sessions for 1263
# Fetched 5 sessions for 1264
# Fetched 5 sessions for 1277
# Fetched 5 sessions for 1265
# Fetched 5 sessions for 1266
# Fetched 5 sessions for 1267
# Fetched 5 sessions for 1268
# Fetched 4 sessions for 1269

# %%
all_sessions_df.head()
# Out:
#    meeting_key  year  session_key session_type session_name  date_start  \
# 0         1140  2023         9222     Practice   Practice 1  2023-02-23
# 1         1140  2023         7763     Practice   Practice 2  2023-02-24
# 2         1140  2023         7764     Practice   Practice 3  2023-02-25
# 3         1141  2023         7765     Practice   Practice 1  2023-03-03
# 4         1141  2023         7766     Practice   Practice 2  2023-03-03
#
#   time_start    date_end  time_end gmt_offset location country_name  \
# 0   07:00:00  2023-02-23  16:30:00   03:00:00   Sakhir      Bahrain
# 1   07:00:00  2023-02-24  16:30:00   03:00:00   Sakhir      Bahrain
# 2   07:00:00  2023-02-25  16:30:00   03:00:00   Sakhir      Bahrain
# 3   11:30:00  2023-03-03  12:30:00   03:00:00   Sakhir      Bahrain
# 4   15:00:00  2023-03-03  16:00:00   03:00:00   Sakhir      Bahrain
#
#   country_code circuit_short_name
# 0          BRN             Sakhir
# 1          BRN             Sakhir
# 2          BRN             Sakhir
# 3          BRN             Sakhir
# 4          BRN             Sakhir

# %%
all_sessions_df.tail(100)
# Out:
#      meeting_key  year  session_key session_type       session_name  \
# 223         1250  2024         9639     Practice         Practice 3
# 224         1250  2024         9640   Qualifying         Qualifying
# 225         1250  2024         9644         Race               Race
# 226         1251  2024         9645     Practice         Practice 1
# 227         1251  2024         9650   Qualifying  Sprint Qualifying
# ..           ...   ...          ...          ...                ...
# 318         1268  2025         9912         Race               Race
# 319         1269  2025         9897     Practice         Practice 1
# 320         1269  2025         9898     Practice         Practice 2
# 321         1269  2025         9899     Practice         Practice 3
# 322         1269  2025         9900   Qualifying         Qualifying
#
#      date_start time_start    date_end  time_end gmt_offset   location  \
# 223  2024-11-23   02:30:00  2024-11-23  03:30:00  -08:00:00  Las Vegas
# 224  2024-11-23   06:00:00  2024-11-23  07:00:00  -08:00:00  Las Vegas
# 225  2024-11-24   06:00:00  2024-11-24  08:00:00  -08:00:00  Las Vegas
# 226  2024-11-29   13:30:00  2024-11-29  14:30:00   03:00:00     Lusail
# 227  2024-11-29   17:30:00  2024-11-29  18:14:00   03:00:00     Lusail
# ..          ...        ...         ...       ...        ...        ...
# 318  2025-09-07   13:00:00  2025-09-07  15:00:00   02:00:00      Monza
# 319  2025-09-19   08:30:00  2025-09-19  09:30:00   04:00:00       Baku
# 320  2025-09-19   12:00:00  2025-09-19  13:00:00   04:00:00       Baku
# 321  2025-09-20   08:30:00  2025-09-20  09:30:00   04:00:00       Baku
# 322  2025-09-20   12:00:00  2025-09-20  13:00:00   04:00:00       Baku
#
#       country_name country_code circuit_short_name
# 223  United States          USA          Las Vegas
# 224  United States          USA          Las Vegas
# 225  United States          USA          Las Vegas
# 226          Qatar          QAT             Lusail
# 227          Qatar          QAT             Lusail
# ..             ...          ...                ...
# 318          Italy          ITA              Monza
# 319     Azerbaijan          AZE               Baku
# 320     Azerbaijan          AZE               Baku
# 321     Azerbaijan          AZE               Baku
# 322     Azerbaijan          AZE               Baku
#
# [100 rows x 14 columns]

# %%
# pobranie kolumn z tabeli sessions
sessions_columns = all_sessions_df.columns.tolist()
print("Sessions columns:", sessions_columns)
# Out:
# Sessions columns: ['meeting_key', 'year', 'session_key', 'session_type', 'session_name', 'date_start', 'time_start', 'date_end', 'time_end', 'gmt_offset', 'location', 'country_name', 'country_code', 'circuit_short_name']

# %%
# unikalne wartości w kolumnie session_key
sessions_key_unique= all_sessions_df['session_key'].unique()
print(sessions_key_unique)
# Out:
# [ 9222  7763  7764  7765  7766  7767  7768  7953  7772  7773  7774  7775
#   7779  7780  7781  7782  7783  7787  9063  9064  9278  9069  9070  9071
#   9072  9073  9074  9078  9087  9088  9089  9090  9094  9095  9096  9097
#   9098  9102  9103  9104  9105  9106  9110  9111  9112  9282  9117  9118
#   9119  9120  9121  9122  9126  9223  9127  9128  9129  9133  9134  9135
#   9286  9140  9141  9142  9143  9144  9145  9149  9150  9151  9152  9153
#   9157  9158  9159  9160  9161  9165  9166  9167  9168  9169  9173  9214
#   9215  9298  9220  9221  9206  9207  9294  9212  9213  9174  9175  9176
#   9177  9181  9198  9304  9308  9204  9205  9182  9183  9184  9314  9189
#   9190  9191  9192  9193  9197  9462  9463  9464  9465  9466  9467  9468
#   9472  9473  9474  9475  9476  9480  9481  9482  9483  9484  9488  9489
#   9490  9491  9492  9496  9663  9668  9672  9664  9673  9497  9502  9506
#   9498  9507  9508  9509  9510  9511  9515  9516  9517  9518  9519  9523
#   9524  9525  9526  9527  9531  9532  9533  9534  9535  9539  9540  9545
#   9549  9541  9550  9551  9552  9553  9554  9558  9559  9560  9561  9562
#   9566  9567  9568  9569  9570  9574  9575  9576  9577  9578  9582  9583
#   9584  9585  9586  9590  9591  9592  9593  9594  9598  9599  9600  9601
#   9602  9606  9607  9612  9616  9608  9617  9618  9619  9620  9621  9625
#   9626  9631  9635  9627  9636  9637  9638  9639  9640  9644  9645  9650
#   9654  9646  9655  9461  9656  9657  9658  9662  9683  9684  9685  9686
#   9687  9688  9689  9693  9988  9989  9993  9994  9998  9999 10000 10001
#  10002 10006 10007 10008 10009 10010 10014 10015 10016 10017 10018 10022
#  10023 10024 10028 10029 10033  9980  9981  9982  9983  9987  9972  9973
#   9974  9975  9979  9964  9965  9966  9967  9971  9956  9957  9958  9959
#   9963  9948  9949  9950  9951  9955  9940  9941  9942  9943  9947  9929
#   9930  9934  9935  9939  9921  9922  9923  9924  9928  9913  9914  9915
#   9916  9920  9905  9906  9907  9908  9912  9897  9898  9899  9900]

# %%
# pobranie kierowcow poszczegolnych zespołów dka kazdego z meeting w sessions

def get_all_drivers(unique_meetings_keys):
    drivers = []
    for meeting_key in unique_meetings_keys:
        url = f"https://api.openf1.org/v1/drivers?meeting_key={meeting_key}"
        response = requests.get(url)
        
        if response.status_code == 200:
            data = response.json()
            
            if isinstance(data, list) and len(data) > 0:
                for driver in data:
                    drivers.append({
                        'driver_number': driver.get('driver_number'),
                        'broadcast_name': driver.get('broadcast_name'),
                        'full_name': driver.get('full_name'),
                        'first_name': driver.get('first_name'),
                        'last_name': driver.get('last_name'),
                        'name_acronym': driver.get('name_acronym'),
                        'country_code': driver.get('country_code'),
                        'team_name': driver.get('team_name'),
                        'meeting_key': meeting_key,
                        'session_key': driver.get('session_key')
                    })
                print(f"Fetched {len(data)} drivers for meeting {meeting_key}")
            else:
                print(f"No drivers found for meeting {meeting_key}")
        else:
            print(f"Error fetching data for meeting {meeting_key}: {response.status_code}")
        sleep(1)
    return pd.DataFrame(drivers)

# %%
drivers_df = get_all_drivers(meetings_key_unique)
# Out:
# Fetched 53 drivers for meeting 1140
# Fetched 100 drivers for meeting 1141
# Fetched 100 drivers for meeting 1142
# Fetched 100 drivers for meeting 1143
# Fetched 99 drivers for meeting 1207
# Fetched 100 drivers for meeting 1208
# Fetched 100 drivers for meeting 1210
# Fetched 100 drivers for meeting 1211
# Fetched 100 drivers for meeting 1212
# Fetched 100 drivers for meeting 1213
# Fetched 100 drivers for meeting 1214
# Fetched 115 drivers for meeting 1215
# Fetched 100 drivers for meeting 1216
# Fetched 100 drivers for meeting 1217
# Fetched 100 drivers for meeting 1218
# Fetched 99 drivers for meeting 1219
# Fetched 100 drivers for meeting 1220
# Fetched 100 drivers for meeting 1221
# Fetched 100 drivers for meeting 1222
# Fetched 100 drivers for meeting 1223
# Fetched 100 drivers for meeting 1224
# Fetched 100 drivers for meeting 1225
# Fetched 100 drivers for meeting 1226
# Fetched 60 drivers for meeting 1228
# Fetched 100 drivers for meeting 1229
# Fetched 100 drivers for meeting 1230
# Fetched 97 drivers for meeting 1231
# Fetched 100 drivers for meeting 1232
# Fetched 100 drivers for meeting 1233
# Fetched 100 drivers for meeting 1234
# Fetched 100 drivers for meeting 1235
# Fetched 100 drivers for meeting 1236
# Fetched 100 drivers for meeting 1237
# Fetched 100 drivers for meeting 1238
# Fetched 100 drivers for meeting 1239
# Fetched 100 drivers for meeting 1240
# Fetched 100 drivers for meeting 1241
# Fetched 100 drivers for meeting 1242
# Fetched 100 drivers for meeting 1243
# Fetched 100 drivers for meeting 1244
# Fetched 100 drivers for meeting 1245
# Fetched 100 drivers for meeting 1246
# Fetched 100 drivers for meeting 1247
# Fetched 100 drivers for meeting 1248
# Fetched 100 drivers for meeting 1249
# Fetched 100 drivers for meeting 1250
# Fetched 100 drivers for meeting 1251
# Fetched 100 drivers for meeting 1252
# Fetched 56 drivers for meeting 1253
# Fetched 100 drivers for meeting 1254
# Fetched 100 drivers for meeting 1255
# Fetched 100 drivers for meeting 1256
# Fetched 100 drivers for meeting 1257
# Fetched 100 drivers for meeting 1258
# Fetched 100 drivers for meeting 1259
# Fetched 100 drivers for meeting 1260
# Fetched 100 drivers for meeting 1261
# Fetched 99 drivers for meeting 1262
# Fetched 100 drivers for meeting 1263
# Fetched 100 drivers for meeting 1264
# Fetched 100 drivers for meeting 1277
# Fetched 100 drivers for meeting 1265
# Fetched 100 drivers for meeting 1266
# Fetched 100 drivers for meeting 1267
# Fetched 100 drivers for meeting 1268
# Fetched 80 drivers for meeting 1269

# %%
drivers_df.head()
# Out:
#    driver_number broadcast_name       full_name first_name   last_name  \
# 0              1   M VERSTAPPEN  Max VERSTAPPEN        Max  Verstappen
# 1              2     L SARGEANT  Logan SARGEANT      Logan    Sargeant
# 2              4       L NORRIS    Lando NORRIS      Lando      Norris
# 3             10        P GASLY    Pierre GASLY     Pierre       Gasly
# 4             11        S PEREZ    Sergio PEREZ     Sergio       Perez
#
#   name_acronym country_code        team_name  meeting_key  session_key
# 0          VER          NED  Red Bull Racing         1140         7763
# 1          SAR          USA         Williams         1140         7763
# 2          NOR          GBR          McLaren         1140         7763
# 3          GAS          FRA           Alpine         1140         7763
# 4          PER          MEX  Red Bull Racing         1140         7763

# %%
# pobranie kolumn z tabeli drivers
drivers_columns = drivers_df.columns.tolist()
print("Drivers columns:", drivers_columns)
# Out:
# Drivers columns: ['driver_number', 'broadcast_name', 'full_name', 'first_name', 'last_name', 'name_acronym', 'country_code', 'team_name', 'meeting_key', 'session_key']

# %%
unique_drivers = drivers_df['broadcast_name'].unique()

# %%
print(unique_drivers)
# Out:
# ['M VERSTAPPEN' 'L SARGEANT' 'L NORRIS' 'P GASLY' 'S PEREZ' 'F ALONSO'
#  'C LECLERC' 'K MAGNUSSEN' 'N DE VRIES' 'Y TSUNODA' 'G ZHOU'
#  'N HULKENBERG' 'E OCON' 'L HAMILTON' 'C SAINZ' 'G RUSSELL' 'O PIASTRI'
#  'A ALBON' 'F DRUGOVICH' 'V BOTTAS' 'L STROLL' 'D RICCIARDO' 'P ARON'
#  'D BEGANOVIC' "Z O'SULLIVAN" 'L FORNAROLI' 'F COLAPINTO' 'M BOYA'
#  'S MONTOYA' 'L BROWNING' 'R VILLAGOMEZ' 'O GRAY' 'I COHEN' 'J MARTI'
#  'C MANSELL' 'T BARNARD' 'W SHIN' 'G BORTOLETO' 'O GOETHE' 'K FREDERICK'
#  'G SAUCY' 'N TSOLOV' 'J EDGAR' 'G MINI' 'C COLLET' 'T SMITH' 'M ESTERSON'
#  'H BARTER' 'N BEDRIN' 'A GARCIA' 'S FLOERSCH' 'R FARIA' 'R SHWARTZMAN'
#  'L LAWSON' 'I HADJAR' 'F VESTI' 'O BEARMAN' 'J DOOHAN' 'T POURCHAIRE'
#  "P O'WARD" 'J DENNIS' 'A IWASA' 'A ANTONELLI' 'R HIRAKAWA' 'A LECLERC'
#  'K ANTONELLI' 'V MARTINS' 'A DUNNE' 'A LINDBLAD']

# %%
# pobranie końcowej tabeli wyników dla sesji
def get_final_session_results(session_keys, include_driver_details=True):
    all_results = []
    
    for session_key in session_keys:
        url = f"https://api.openf1.org/v1/position?session_key={session_key}"
        response = requests.get(url)
        
        if response.status_code == 200:
            data = response.json()
            
            if isinstance(data, list) and len(data) > 0:
                # najnowsze na końcu
                data_sorted = sorted(data, key=lambda x: x.get('date', ''))
                
                # ostatnie pozycje dla każdego kierowcy (pozycja koncowa)
                latest_positions = {}
                for record in data_sorted:
                    driver_number = record.get('driver_number')
                    if driver_number:
                        latest_positions[driver_number] = record
                
                date, time = format_datetime_fields(data_sorted[-1]['date'])
                # wszystkie końcowe pozycje do wyników
                for driver_number, record in latest_positions.items():
                    result = {
                        'session_key': session_key,
                        'driver_number': driver_number,
                        'position': record.get('position'),
                        'date': date,
                        'time': time,
                        'meeting_key': record.get('meeting_key')
                    }
                    all_results.append(result)
                
                print(f"Session {session_key}: Pobrano {len(latest_positions)} końcowych pozycji")
            else:
                print(f"Session {session_key}: Brak danych pozycji")
        else:
            print(f"Error fetching data for session {session_key}: {response.status_code}")
        
        sleep(0.5)
    
    results_df = pd.DataFrame(all_results)
    
    if not results_df.empty and include_driver_details:
        # merge z danymi o sesjach
        results_df = results_df.merge(
            all_sessions_df[['session_key', 'session_name', 'year', 'location', 'country_name', 'circuit_short_name']], 
            on='session_key', 
            how='left'
        )
        
        # merge z danymi o kierowcach używając session_key
        results_df = results_df.merge(
            drivers_df[['driver_number', 'session_key', 'broadcast_name', 'full_name', 'team_name']].drop_duplicates(), 
            on=['driver_number', 'session_key'], 
            how='left'
        )
    
    return results_df

# %%
results_df = get_final_session_results(sessions_key_unique, include_driver_details=True)
results_df.head()
# Out:
# Session 9222: Pobrano 19 końcowych pozycji
# Session 7763: Pobrano 17 końcowych pozycji
# Session 7764: Pobrano 17 końcowych pozycji
# Session 7765: Pobrano 20 końcowych pozycji
# Session 7766: Pobrano 20 końcowych pozycji
# Session 7767: Pobrano 20 końcowych pozycji
# Session 7768: Pobrano 20 końcowych pozycji
# Session 7953: Pobrano 20 końcowych pozycji
# Session 7772: Pobrano 20 końcowych pozycji
# Session 7773: Pobrano 20 końcowych pozycji
# Session 7774: Pobrano 20 końcowych pozycji
# Session 7775: Pobrano 20 końcowych pozycji
# Session 7779: Pobrano 20 końcowych pozycji
# Session 7780: Pobrano 20 końcowych pozycji
# Session 7781: Pobrano 20 końcowych pozycji
# Session 7782: Pobrano 20 końcowych pozycji
# Session 7783: Pobrano 20 końcowych pozycji
# Session 7787: Pobrano 20 końcowych pozycji
# Session 9063: Pobrano 20 końcowych pozycji
# Session 9064: Pobrano 20 końcowych pozycji
# Session 9278: Pobrano 20 końcowych pozycji
# Session 9069: Pobrano 19 końcowych pozycji
# Session 9070: Pobrano 20 końcowych pozycji
# Session 9071: Pobrano 20 końcowych pozycji
# Session 9072: Pobrano 20 końcowych pozycji
# Session 9073: Pobrano 20 końcowych pozycji
# Session 9074: Pobrano 20 końcowych pozycji
# Session 9078: Pobrano 20 końcowych pozycji
# Session 9087: Pobrano 20 końcowych pozycji
# Session 9088: Pobrano 20 końcowych pozycji
# Session 9089: Pobrano 20 końcowych pozycji
# Session 9090: Pobrano 20 końcowych pozycji
# Session 9094: Pobrano 20 końcowych pozycji
# Session 9095: Pobrano 20 końcowych pozycji
# Session 9096: Pobrano 20 końcowych pozycji
# Session 9097: Pobrano 20 końcowych pozycji
# Session 9098: Pobrano 20 końcowych pozycji
# Session 9102: Pobrano 20 końcowych pozycji
# Session 9103: Pobrano 20 końcowych pozycji
# Session 9104: Pobrano 20 końcowych pozycji
# Session 9105: Pobrano 20 końcowych pozycji
# Session 9106: Pobrano 20 końcowych pozycji
# Session 9110: Pobrano 20 końcowych pozycji
# Session 9111: Pobrano 20 końcowych pozycji
# Session 9112: Pobrano 20 końcowych pozycji
# Session 9282: Pobrano 20 końcowych pozycji
# Session 9117: Pobrano 20 końcowych pozycji
# Session 9118: Pobrano 20 końcowych pozycji
# Session 9119: Pobrano 20 końcowych pozycji
# Session 9120: Pobrano 20 końcowych pozycji
# Session 9121: Pobrano 20 końcowych pozycji
# Session 9122: Pobrano 20 końcowych pozycji
# Session 9126: Pobrano 20 końcowych pozycji
# Session 9223: Pobrano 20 końcowych pozycji
# Session 9127: Pobrano 20 końcowych pozycji
# Session 9128: Pobrano 20 końcowych pozycji
# Session 9129: Pobrano 20 końcowych pozycji
# Session 9133: Pobrano 20 końcowych pozycji
# Session 9134: Pobrano 20 końcowych pozycji
# Session 9135: Pobrano 20 końcowych pozycji
# Session 9286: Pobrano 20 końcowych pozycji
# Session 9140: Pobrano 20 końcowych pozycji
# Session 9141: Pobrano 20 końcowych pozycji
# Session 9142: Pobrano 20 końcowych pozycji
# Session 9143: Pobrano 20 końcowych pozycji
# Session 9144: Pobrano 20 końcowych pozycji
# Session 9145: Pobrano 20 końcowych pozycji
# Session 9149: Pobrano 20 końcowych pozycji
# Session 9150: Pobrano 20 końcowych pozycji
# Session 9151: Pobrano 20 końcowych pozycji
# Session 9152: Pobrano 20 końcowych pozycji
# Session 9153: Pobrano 20 końcowych pozycji
# Session 9157: Pobrano 20 końcowych pozycji
# Session 9158: Pobrano 20 końcowych pozycji
# Session 9159: Pobrano 20 końcowych pozycji
# Session 9160: Pobrano 20 końcowych pozycji
# Session 9161: Pobrano 20 końcowych pozycji
# Session 9165: Pobrano 19 końcowych pozycji
# Session 9166: Pobrano 20 końcowych pozycji
# Session 9167: Pobrano 20 końcowych pozycji
# Session 9168: Pobrano 20 końcowych pozycji
# Session 9169: Pobrano 20 końcowych pozycji
# Session 9173: Pobrano 20 końcowych pozycji
# Session 9214: Pobrano 20 końcowych pozycji
# Session 9215: Pobrano 20 końcowych pozycji
# Session 9298: Pobrano 20 końcowych pozycji
# Session 9220: Pobrano 20 końcowych pozycji
# Session 9221: Pobrano 20 końcowych pozycji
# Session 9206: Pobrano 20 końcowych pozycji
# Session 9207: Pobrano 20 końcowych pozycji
# Session 9294: Pobrano 20 końcowych pozycji
# Session 9212: Pobrano 20 końcowych pozycji
# Session 9213: Pobrano 20 końcowych pozycji
# Session 9174: Pobrano 20 końcowych pozycji
# Session 9175: Pobrano 20 końcowych pozycji
# Session 9176: Pobrano 20 końcowych pozycji
# Session 9177: Pobrano 20 końcowych pozycji
# Session 9181: Pobrano 20 końcowych pozycji
# Session 9198: Pobrano 20 końcowych pozycji
# Session 9304: Pobrano 20 końcowych pozycji
# Session 9308: Pobrano 20 końcowych pozycji
# Session 9204: Pobrano 20 końcowych pozycji
# Session 9205: Pobrano 20 końcowych pozycji
# Session 9182: Pobrano 20 końcowych pozycji
# Session 9183: Pobrano 20 końcowych pozycji
# Session 9184: Pobrano 20 końcowych pozycji
# Session 9314: Pobrano 20 końcowych pozycji
# Session 9189: Pobrano 20 końcowych pozycji
# Session 9190: Pobrano 20 końcowych pozycji
# Session 9191: Pobrano 20 końcowych pozycji
# Session 9192: Pobrano 20 końcowych pozycji
# Session 9193: Pobrano 20 końcowych pozycji
# Session 9197: Pobrano 20 końcowych pozycji
# Session 9462: Pobrano 20 końcowych pozycji
# Session 9463: Pobrano 20 końcowych pozycji
# Session 9464: Pobrano 20 końcowych pozycji
# Session 9465: Pobrano 20 końcowych pozycji
# Session 9466: Pobrano 20 końcowych pozycji
# Session 9467: Pobrano 20 końcowych pozycji
# Session 9468: Pobrano 20 końcowych pozycji
# Session 9472: Pobrano 20 końcowych pozycji
# Session 9473: Pobrano 20 końcowych pozycji
# Session 9474: Pobrano 20 końcowych pozycji
# Session 9475: Pobrano 20 końcowych pozycji
# Session 9476: Pobrano 20 końcowych pozycji
# Session 9480: Pobrano 20 końcowych pozycji
# Session 9481: Pobrano 20 końcowych pozycji
# Session 9482: Pobrano 20 końcowych pozycji
# Session 9483: Pobrano 19 końcowych pozycji
# Session 9484: Pobrano 19 końcowych pozycji
# Session 9488: Pobrano 19 końcowych pozycji
# Session 9489: Pobrano 20 końcowych pozycji
# Session 9490: Pobrano 20 końcowych pozycji
# Session 9491: Pobrano 20 końcowych pozycji
# Session 9492: Pobrano 20 końcowych pozycji
# Session 9496: Pobrano 20 końcowych pozycji
# Session 9663: Pobrano 20 końcowych pozycji
# Session 9668: Pobrano 20 końcowych pozycji
# Session 9672: Pobrano 20 końcowych pozycji
# Session 9664: Pobrano 20 końcowych pozycji
# Session 9673: Pobrano 20 końcowych pozycji
# Session 9497: Pobrano 20 końcowych pozycji
# Session 9502: Pobrano 20 końcowych pozycji
# Session 9506: Pobrano 20 końcowych pozycji
# Session 9498: Pobrano 20 końcowych pozycji
# Session 9507: Pobrano 20 końcowych pozycji
# Session 9508: Pobrano 20 końcowych pozycji
# Session 9509: Pobrano 20 końcowych pozycji
# Session 9510: Pobrano 20 końcowych pozycji
# Session 9511: Pobrano 20 końcowych pozycji
# Session 9515: Pobrano 20 końcowych pozycji
# Session 9516: Pobrano 20 końcowych pozycji
# Session 9517: Pobrano 20 końcowych pozycji
# Session 9518: Pobrano 20 końcowych pozycji
# Session 9519: Pobrano 20 końcowych pozycji
# Session 9523: Pobrano 20 końcowych pozycji
# Session 9524: Pobrano 20 końcowych pozycji
# Session 9525: Pobrano 20 końcowych pozycji
# Session 9526: Pobrano 20 końcowych pozycji
# Session 9527: Pobrano 20 końcowych pozycji
# Session 9531: Pobrano 20 końcowych pozycji
# Session 9532: Pobrano 20 końcowych pozycji
# Session 9533: Pobrano 20 końcowych pozycji
# Session 9534: Pobrano 20 końcowych pozycji
# Session 9535: Pobrano 20 końcowych pozycji
# Session 9539: Pobrano 20 końcowych pozycji
# Session 9540: Pobrano 20 końcowych pozycji
# Session 9545: Pobrano 20 końcowych pozycji
# Session 9549: Pobrano 20 końcowych pozycji
# Session 9541: Pobrano 20 końcowych pozycji
# Session 9550: Pobrano 20 końcowych pozycji
# Session 9551: Pobrano 20 końcowych pozycji
# Session 9552: Pobrano 20 końcowych pozycji
# Session 9553: Pobrano 20 końcowych pozycji
# Session 9554: Pobrano 20 końcowych pozycji
# Session 9558: Pobrano 20 końcowych pozycji
# Session 9559: Pobrano 20 końcowych pozycji
# Session 9560: Pobrano 20 końcowych pozycji
# Session 9561: Pobrano 20 końcowych pozycji
# Session 9562: Pobrano 20 końcowych pozycji
# Session 9566: Pobrano 20 końcowych pozycji
# Session 9567: Pobrano 20 końcowych pozycji
# Session 9568: Pobrano 20 końcowych pozycji
# Session 9569: Pobrano 20 końcowych pozycji
# Session 9570: Pobrano 20 końcowych pozycji
# Session 9574: Pobrano 20 końcowych pozycji
# Session 9575: Pobrano 20 końcowych pozycji
# Session 9576: Pobrano 20 końcowych pozycji
# Session 9577: Pobrano 20 końcowych pozycji
# Session 9578: Pobrano 20 końcowych pozycji
# Session 9582: Pobrano 20 końcowych pozycji
# Session 9583: Pobrano 20 końcowych pozycji
# Session 9584: Pobrano 20 końcowych pozycji
# Session 9585: Pobrano 20 końcowych pozycji
# Session 9586: Pobrano 20 końcowych pozycji
# Session 9590: Pobrano 20 końcowych pozycji
# Session 9591: Pobrano 20 końcowych pozycji
# Session 9592: Pobrano 20 końcowych pozycji
# Session 9593: Pobrano 20 końcowych pozycji
# Session 9594: Pobrano 20 końcowych pozycji
# Session 9598: Pobrano 20 końcowych pozycji
# Session 9599: Pobrano 20 końcowych pozycji
# Session 9600: Pobrano 20 końcowych pozycji
# Session 9601: Pobrano 20 końcowych pozycji
# Session 9602: Pobrano 20 końcowych pozycji
# Session 9606: Pobrano 20 końcowych pozycji
# Session 9607: Pobrano 20 końcowych pozycji
# Session 9612: Pobrano 20 końcowych pozycji
# Session 9616: Pobrano 20 końcowych pozycji
# Session 9608: Pobrano 20 końcowych pozycji
# Session 9617: Pobrano 20 końcowych pozycji
# Session 9618: Pobrano 20 końcowych pozycji
# Session 9619: Pobrano 20 końcowych pozycji
# Session 9620: Pobrano 20 końcowych pozycji
# Session 9621: Pobrano 20 końcowych pozycji
# Session 9625: Pobrano 20 końcowych pozycji
# Session 9626: Pobrano 20 końcowych pozycji
# Session 9631: Pobrano 20 końcowych pozycji
# Session 9635: Pobrano 20 końcowych pozycji
# Session 9627: Pobrano 20 końcowych pozycji
# Session 9636: Pobrano 20 końcowych pozycji
# Session 9637: Pobrano 20 końcowych pozycji
# Session 9638: Pobrano 20 końcowych pozycji
# Session 9639: Pobrano 20 końcowych pozycji
# Session 9640: Pobrano 20 końcowych pozycji
# Session 9644: Pobrano 20 końcowych pozycji
# Session 9645: Pobrano 20 końcowych pozycji
# Session 9650: Pobrano 20 końcowych pozycji
# Session 9654: Pobrano 20 końcowych pozycji
# Session 9646: Pobrano 20 końcowych pozycji
# Session 9655: Pobrano 20 końcowych pozycji
# Session 9461: Pobrano 20 końcowych pozycji
# Session 9656: Pobrano 20 końcowych pozycji
# Session 9657: Pobrano 20 końcowych pozycji
# Session 9658: Pobrano 20 końcowych pozycji
# Session 9662: Pobrano 20 końcowych pozycji
# Session 9683: Pobrano 20 końcowych pozycji
# Session 9684: Pobrano 18 końcowych pozycji
# Session 9685: Pobrano 18 końcowych pozycji
# Session 9686: Pobrano 20 końcowych pozycji
# Session 9687: Pobrano 20 końcowych pozycji
# Session 9688: Pobrano 20 końcowych pozycji
# Session 9689: Pobrano 20 końcowych pozycji
# Session 9693: Pobrano 20 końcowych pozycji
# Session 9988: Pobrano 20 końcowych pozycji
# Session 9989: Pobrano 20 końcowych pozycji
# Session 9993: Pobrano 20 końcowych pozycji
# Session 9994: Pobrano 20 końcowych pozycji
# Session 9998: Pobrano 20 końcowych pozycji
# Session 9999: Pobrano 20 końcowych pozycji
# Session 10000: Pobrano 20 końcowych pozycji
# Session 10001: Pobrano 20 końcowych pozycji
# Session 10002: Pobrano 20 końcowych pozycji
# Session 10006: Pobrano 20 końcowych pozycji
# Session 10007: Pobrano 20 końcowych pozycji
# Session 10008: Pobrano 20 końcowych pozycji
# Session 10009: Pobrano 20 końcowych pozycji
# Session 10010: Pobrano 20 końcowych pozycji
# Session 10014: Pobrano 20 końcowych pozycji
# Session 10015: Pobrano 20 końcowych pozycji
# Session 10016: Pobrano 20 końcowych pozycji
# Session 10017: Pobrano 20 końcowych pozycji
# Session 10018: Pobrano 20 końcowych pozycji
# Session 10022: Pobrano 20 końcowych pozycji
# Session 10023: Pobrano 20 końcowych pozycji
# Session 10024: Pobrano 20 końcowych pozycji
# Session 10028: Pobrano 20 końcowych pozycji
# Session 10029: Pobrano 20 końcowych pozycji
# Session 10033: Pobrano 20 końcowych pozycji
# Session 9980: Pobrano 20 końcowych pozycji
# Session 9981: Pobrano 20 końcowych pozycji
# Session 9982: Pobrano 20 końcowych pozycji
# Session 9983: Pobrano 20 końcowych pozycji
# Session 9987: Pobrano 20 końcowych pozycji
# Session 9972: Pobrano 20 końcowych pozycji
# Session 9973: Pobrano 20 końcowych pozycji
# Session 9974: Pobrano 20 końcowych pozycji
# Session 9975: Pobrano 20 końcowych pozycji
# Session 9979: Pobrano 20 końcowych pozycji
# Session 9964: Pobrano 20 końcowych pozycji
# Session 9965: Pobrano 20 końcowych pozycji
# Session 9966: Pobrano 20 końcowych pozycji
# Session 9967: Pobrano 20 końcowych pozycji
# Session 9971: Pobrano 19 końcowych pozycji
# Session 9956: Pobrano 20 końcowych pozycji
# Session 9957: Pobrano 20 końcowych pozycji
# Session 9958: Pobrano 20 końcowych pozycji
# Session 9959: Pobrano 20 końcowych pozycji
# Session 9963: Pobrano 20 końcowych pozycji
# Session 9948: Pobrano 20 końcowych pozycji
# Session 9949: Pobrano 20 końcowych pozycji
# Session 9950: Pobrano 20 końcowych pozycji
# Session 9951: Pobrano 20 końcowych pozycji
# Session 9955: Pobrano 20 końcowych pozycji
# Session 9940: Pobrano 20 końcowych pozycji
# Session 9941: Pobrano 20 końcowych pozycji
# Session 9942: Pobrano 20 końcowych pozycji
# Session 9943: Pobrano 20 końcowych pozycji
# Session 9947: Pobrano 20 końcowych pozycji
# Session 9929: Pobrano 20 końcowych pozycji
# Session 9930: Pobrano 20 końcowych pozycji
# Session 9934: Pobrano 20 końcowych pozycji
# Session 9935: Pobrano 20 końcowych pozycji
# Session 9939: Pobrano 20 końcowych pozycji
# Session 9921: Pobrano 20 końcowych pozycji
# Session 9922: Pobrano 20 końcowych pozycji
# Session 9923: Pobrano 20 końcowych pozycji
# Session 9924: Pobrano 20 końcowych pozycji
# Session 9928: Pobrano 20 końcowych pozycji
# Session 9913: Pobrano 20 końcowych pozycji
# Session 9914: Pobrano 20 końcowych pozycji
# Session 9915: Pobrano 20 końcowych pozycji
# Session 9916: Pobrano 20 końcowych pozycji
# Session 9920: Pobrano 20 końcowych pozycji
# Session 9905: Pobrano 20 końcowych pozycji
# Session 9906: Pobrano 20 końcowych pozycji
# Session 9907: Pobrano 20 końcowych pozycji
# Session 9908: Pobrano 20 końcowych pozycji
# Session 9912: Pobrano 20 końcowych pozycji
# Session 9897: Pobrano 20 końcowych pozycji
# Session 9898: Pobrano 20 końcowych pozycji
# Session 9899: Pobrano 20 końcowych pozycji
# Session 9900: Pobrano 20 końcowych pozycji
#    session_key  driver_number  position        date             time  \
# 0         9222              1         1  2023-02-23  16:13:05.619000
# 1         9222              2        10  2023-02-23  16:13:05.619000
# 2         9222              4         5  2023-02-23  16:13:05.619000
# 3         9222             10        16  2023-02-23  16:13:05.619000
# 4         9222             14         2  2023-02-23  16:13:05.619000
#
#    meeting_key session_name  year location country_name circuit_short_name  \
# 0         1140   Practice 1  2023   Sakhir      Bahrain             Sakhir
# 1         1140   Practice 1  2023   Sakhir      Bahrain             Sakhir
# 2         1140   Practice 1  2023   Sakhir      Bahrain             Sakhir
# 3         1140   Practice 1  2023   Sakhir      Bahrain             Sakhir
# 4         1140   Practice 1  2023   Sakhir      Bahrain             Sakhir
#
#   broadcast_name        full_name        team_name
# 0   M VERSTAPPEN   Max VERSTAPPEN  Red Bull Racing
# 1     L SARGEANT   Logan SARGEANT         Williams
# 2       L NORRIS     Lando NORRIS          McLaren
# 3        P GASLY     Pierre GASLY           Alpine
# 4       F ALONSO  Fernando ALONSO     Aston Martin

# %%
# posortuj wyniki według sesji i pozycji
def sort_results_by_session_and_position(results_df):
    return results_df.sort_values(by=['session_key', 'position'])

sorted_results_df = sort_results_by_session_and_position(results_df)
sorted_results_df.head()
# Out:
#     session_key  driver_number  position        date             time  \
# 29         7763             24         1  2023-02-24  16:00:22.519000
# 19         7763              1         2  2023-02-24  16:00:22.519000
# 24         7763             14         3  2023-02-24  16:00:22.519000
# 27         7763             21         4  2023-02-24  16:00:22.519000
# 30         7763             27         5  2023-02-24  16:00:22.519000
#
#     meeting_key session_name  year location country_name circuit_short_name  \
# 29         1140   Practice 2  2023   Sakhir      Bahrain             Sakhir
# 19         1140   Practice 2  2023   Sakhir      Bahrain             Sakhir
# 24         1140   Practice 2  2023   Sakhir      Bahrain             Sakhir
# 27         1140   Practice 2  2023   Sakhir      Bahrain             Sakhir
# 30         1140   Practice 2  2023   Sakhir      Bahrain             Sakhir
#
#    broadcast_name        full_name        team_name
# 29         G ZHOU      ZHOU Guanyu       Alfa Romeo
# 19   M VERSTAPPEN   Max VERSTAPPEN  Red Bull Racing
# 24       F ALONSO  Fernando ALONSO     Aston Martin
# 27     N DE VRIES    Nyck DE VRIES       AlphaTauri
# 30   N HULKENBERG  Nico HULKENBERG     Haas F1 Team

# %%
# analiza końcowych wyników sesji
def get_session_type_results(session_type, max_sessions=None):
    
    sessions = all_sessions_df[all_sessions_df['session_name'] == session_type]
    
    if max_sessions:
        sessions = sessions.head(max_sessions)
    
    session_keys = sessions['session_key'].tolist()
    
    print(f"Pobieranie wyników dla {len(session_keys)} sesji typu '{session_type}'")
    
    return get_final_session_results(session_keys)

# %%
# pobranie rankingu dla wszystkich dostępnych sesji każdego typu

def get_all_rankings_by_session_type():

    session_types = all_sessions_df['session_name'].unique()
    all_rankings = {}
    
    
    for session_type in session_types:
        print(f"Przetwarzanie: {session_type}")
        
        sessions_of_type = all_sessions_df[all_sessions_df['session_name'] == session_type]
        session_keys = sessions_of_type['session_key'].tolist()
        print(f"   Znaleziono {len(session_keys)} sesji typu '{session_type}'")
        
        rankings = get_final_session_results(session_keys, include_driver_details=True)
        
        if not rankings.empty:
            rankings_sorted = rankings.sort_values(['session_key', 'position'])
            all_rankings[session_type] = rankings_sorted
            
            print(f"Pobrano {len(rankings)} wyników z {rankings['session_key'].nunique()} sesji")
            print(f"Lata: {rankings['year'].min()}-{rankings['year'].max()}")
            print(f"Pozycje: {rankings['position'].min()}-{rankings['position'].max()}")
        else:
            print(f"Brak wyników dla {session_type}")
        
        print()
    
    return all_rankings

# %%
# zwraca ramkę danych dla każdego meeting ze wszystkimi sesjami i końcowymi pozycjami kierowców
def get_meeting_all_sessions_positions():

    all_session_keys = all_sessions_df['session_key'].tolist()
    
    all_results = get_final_session_results(all_session_keys, include_driver_details=True)
    
    meeting_sessions = all_meetings_df.merge(
        all_sessions_df[['meeting_key', 'session_key', 'session_name', 'session_type']], 
        on='meeting_key', 
        how='inner'
    )
    
    # merge wynikami wszystkich sesji
    final_data = meeting_sessions.merge(
        all_results[['session_key', 'driver_number', 'position', 'broadcast_name', 'full_name', 'team_name']], 
        on='session_key', 
        how='inner'  # inner join żeby mieć tylko te z pozycjami
    )
    
    return final_data

# %%
meeting_all_sessions_positions = get_meeting_all_sessions_positions()
meeting_all_sessions_positions.head()
# Out:
# Session 9222: Pobrano 19 końcowych pozycji
# Session 7763: Pobrano 17 końcowych pozycji
# Session 7764: Pobrano 17 końcowych pozycji
# Session 7765: Pobrano 20 końcowych pozycji
# Session 7766: Pobrano 20 końcowych pozycji
# Session 7767: Pobrano 20 końcowych pozycji
# Session 7768: Pobrano 20 końcowych pozycji
# Session 7953: Pobrano 20 końcowych pozycji
# Session 7772: Pobrano 20 końcowych pozycji
# Session 7773: Pobrano 20 końcowych pozycji
# Session 7774: Pobrano 20 końcowych pozycji
# Session 7775: Pobrano 20 końcowych pozycji
# Session 7779: Pobrano 20 końcowych pozycji
# Session 7780: Pobrano 20 końcowych pozycji
# Session 7781: Pobrano 20 końcowych pozycji
# Session 7782: Pobrano 20 końcowych pozycji
# Session 7783: Pobrano 20 końcowych pozycji
# Session 7787: Pobrano 20 końcowych pozycji
# Session 9063: Pobrano 20 końcowych pozycji
# Session 9064: Pobrano 20 końcowych pozycji
# Session 9278: Pobrano 20 końcowych pozycji
# Session 9069: Pobrano 19 końcowych pozycji
# Session 9070: Pobrano 20 końcowych pozycji
# Session 9071: Pobrano 20 końcowych pozycji
# Session 9072: Pobrano 20 końcowych pozycji
# Session 9073: Pobrano 20 końcowych pozycji
# Session 9074: Pobrano 20 końcowych pozycji
# Session 9078: Pobrano 20 końcowych pozycji
# Session 9087: Pobrano 20 końcowych pozycji
# Session 9088: Pobrano 20 końcowych pozycji
# Session 9089: Pobrano 20 końcowych pozycji
# Session 9090: Pobrano 20 końcowych pozycji
# Session 9094: Pobrano 20 końcowych pozycji
# Session 9095: Pobrano 20 końcowych pozycji
# Session 9096: Pobrano 20 końcowych pozycji
# Session 9097: Pobrano 20 końcowych pozycji
# Session 9098: Pobrano 20 końcowych pozycji
# Session 9102: Pobrano 20 końcowych pozycji
# Session 9103: Pobrano 20 końcowych pozycji
# Session 9104: Pobrano 20 końcowych pozycji
# Session 9105: Pobrano 20 końcowych pozycji
# Session 9106: Pobrano 20 końcowych pozycji
# Session 9110: Pobrano 20 końcowych pozycji
# Session 9111: Pobrano 20 końcowych pozycji
# Session 9112: Pobrano 20 końcowych pozycji
# Session 9282: Pobrano 20 końcowych pozycji
# Session 9117: Pobrano 20 końcowych pozycji
# Session 9118: Pobrano 20 końcowych pozycji
# Session 9119: Pobrano 20 końcowych pozycji
# Session 9120: Pobrano 20 końcowych pozycji
# Session 9121: Pobrano 20 końcowych pozycji
# Session 9122: Pobrano 20 końcowych pozycji
# Session 9126: Pobrano 20 końcowych pozycji
# Session 9223: Pobrano 20 końcowych pozycji
# Session 9127: Pobrano 20 końcowych pozycji
# Session 9128: Pobrano 20 końcowych pozycji
# Session 9129: Pobrano 20 końcowych pozycji
# Session 9133: Pobrano 20 końcowych pozycji
# Session 9134: Pobrano 20 końcowych pozycji
# Session 9135: Pobrano 20 końcowych pozycji
# Session 9286: Pobrano 20 końcowych pozycji
# Session 9140: Pobrano 20 końcowych pozycji
# Session 9141: Pobrano 20 końcowych pozycji
# Session 9142: Pobrano 20 końcowych pozycji
# Session 9143: Pobrano 20 końcowych pozycji
# Session 9144: Pobrano 20 końcowych pozycji
# Session 9145: Pobrano 20 końcowych pozycji
# Session 9149: Pobrano 20 końcowych pozycji
# Session 9150: Pobrano 20 końcowych pozycji
# Session 9151: Pobrano 20 końcowych pozycji
# Session 9152: Pobrano 20 końcowych pozycji
# Session 9153: Pobrano 20 końcowych pozycji
# Session 9157: Pobrano 20 końcowych pozycji
# Session 9158: Pobrano 20 końcowych pozycji
# Session 9159: Pobrano 20 końcowych pozycji
# Session 9160: Pobrano 20 końcowych pozycji
# Session 9161: Pobrano 20 końcowych pozycji
# Session 9165: Pobrano 19 końcowych pozycji
# Session 9166: Pobrano 20 końcowych pozycji
# Session 9167: Pobrano 20 końcowych pozycji
# Session 9168: Pobrano 20 końcowych pozycji
# Session 9169: Pobrano 20 końcowych pozycji
# Session 9173: Pobrano 20 końcowych pozycji
# Session 9214: Pobrano 20 końcowych pozycji
# Session 9215: Pobrano 20 końcowych pozycji
# Session 9298: Pobrano 20 końcowych pozycji
# Session 9220: Pobrano 20 końcowych pozycji
# Session 9221: Pobrano 20 końcowych pozycji
# Session 9206: Pobrano 20 końcowych pozycji
# Session 9207: Pobrano 20 końcowych pozycji
# Session 9294: Pobrano 20 końcowych pozycji
# Session 9212: Pobrano 20 końcowych pozycji
# Session 9213: Pobrano 20 końcowych pozycji
# Session 9174: Pobrano 20 końcowych pozycji
# Session 9175: Pobrano 20 końcowych pozycji
# Session 9176: Pobrano 20 końcowych pozycji
# Session 9177: Pobrano 20 końcowych pozycji
# Session 9181: Pobrano 20 końcowych pozycji
# Session 9198: Pobrano 20 końcowych pozycji
# Session 9304: Pobrano 20 końcowych pozycji
# Session 9308: Pobrano 20 końcowych pozycji
# Session 9204: Pobrano 20 końcowych pozycji
# Session 9205: Pobrano 20 końcowych pozycji
# Session 9182: Pobrano 20 końcowych pozycji
# Session 9183: Pobrano 20 końcowych pozycji
# Session 9184: Pobrano 20 końcowych pozycji
# Session 9314: Pobrano 20 końcowych pozycji
# Session 9189: Pobrano 20 końcowych pozycji
# Session 9190: Pobrano 20 końcowych pozycji
# Session 9191: Pobrano 20 końcowych pozycji
# Session 9192: Pobrano 20 końcowych pozycji
# Session 9193: Pobrano 20 końcowych pozycji
# Session 9197: Pobrano 20 końcowych pozycji
# Session 9462: Pobrano 20 końcowych pozycji
# Session 9463: Pobrano 20 końcowych pozycji
# Session 9464: Pobrano 20 końcowych pozycji
# Session 9465: Pobrano 20 końcowych pozycji
# Session 9466: Pobrano 20 końcowych pozycji
# Session 9467: Pobrano 20 końcowych pozycji
# Session 9468: Pobrano 20 końcowych pozycji
# Session 9472: Pobrano 20 końcowych pozycji
# Session 9473: Pobrano 20 końcowych pozycji
# Session 9474: Pobrano 20 końcowych pozycji
# Session 9475: Pobrano 20 końcowych pozycji
# Session 9476: Pobrano 20 końcowych pozycji
# Session 9480: Pobrano 20 końcowych pozycji
# Session 9481: Pobrano 20 końcowych pozycji
# Session 9482: Pobrano 20 końcowych pozycji
# Session 9483: Pobrano 19 końcowych pozycji
# Session 9484: Pobrano 19 końcowych pozycji
# Session 9488: Pobrano 19 końcowych pozycji
# Session 9489: Pobrano 20 końcowych pozycji
# Session 9490: Pobrano 20 końcowych pozycji
# Session 9491: Pobrano 20 końcowych pozycji
# Session 9492: Pobrano 20 końcowych pozycji
# Session 9496: Pobrano 20 końcowych pozycji
# Session 9663: Pobrano 20 końcowych pozycji
# Session 9668: Pobrano 20 końcowych pozycji
# Session 9672: Pobrano 20 końcowych pozycji
# Session 9664: Pobrano 20 końcowych pozycji
# Session 9673: Pobrano 20 końcowych pozycji
# Session 9497: Pobrano 20 końcowych pozycji
# Session 9502: Pobrano 20 końcowych pozycji
# Session 9506: Pobrano 20 końcowych pozycji
# Session 9498: Pobrano 20 końcowych pozycji
# Session 9507: Pobrano 20 końcowych pozycji
# Session 9508: Pobrano 20 końcowych pozycji
# Session 9509: Pobrano 20 końcowych pozycji
# Session 9510: Pobrano 20 końcowych pozycji
# Session 9511: Pobrano 20 końcowych pozycji
# Session 9515: Pobrano 20 końcowych pozycji
# Session 9516: Pobrano 20 końcowych pozycji
# Session 9517: Pobrano 20 końcowych pozycji
# Session 9518: Pobrano 20 końcowych pozycji
# Session 9519: Pobrano 20 końcowych pozycji
# Session 9523: Pobrano 20 końcowych pozycji
# Session 9524: Pobrano 20 końcowych pozycji
# Session 9525: Pobrano 20 końcowych pozycji
# Session 9526: Pobrano 20 końcowych pozycji
# Session 9527: Pobrano 20 końcowych pozycji
# Session 9531: Pobrano 20 końcowych pozycji
# Session 9532: Pobrano 20 końcowych pozycji
# Session 9533: Pobrano 20 końcowych pozycji
# Session 9534: Pobrano 20 końcowych pozycji
# Session 9535: Pobrano 20 końcowych pozycji
# Session 9539: Pobrano 20 końcowych pozycji
# Session 9540: Pobrano 20 końcowych pozycji
# Session 9545: Pobrano 20 końcowych pozycji
# Session 9549: Pobrano 20 końcowych pozycji
# Session 9541: Pobrano 20 końcowych pozycji
# Session 9550: Pobrano 20 końcowych pozycji
# Session 9551: Pobrano 20 końcowych pozycji
# Session 9552: Pobrano 20 końcowych pozycji
# Session 9553: Pobrano 20 końcowych pozycji
# Session 9554: Pobrano 20 końcowych pozycji
# Session 9558: Pobrano 20 końcowych pozycji
# Session 9559: Pobrano 20 końcowych pozycji
# Session 9560: Pobrano 20 końcowych pozycji
# Session 9561: Pobrano 20 końcowych pozycji
# Session 9562: Pobrano 20 końcowych pozycji
# Session 9566: Pobrano 20 końcowych pozycji
# Session 9567: Pobrano 20 końcowych pozycji
# Session 9568: Pobrano 20 końcowych pozycji
# Session 9569: Pobrano 20 końcowych pozycji
# Session 9570: Pobrano 20 końcowych pozycji
# Session 9574: Pobrano 20 końcowych pozycji
# Session 9575: Pobrano 20 końcowych pozycji
# Session 9576: Pobrano 20 końcowych pozycji
# Session 9577: Pobrano 20 końcowych pozycji
# Session 9578: Pobrano 20 końcowych pozycji
# Session 9582: Pobrano 20 końcowych pozycji
# Session 9583: Pobrano 20 końcowych pozycji
# Session 9584: Pobrano 20 końcowych pozycji
# Session 9585: Pobrano 20 końcowych pozycji
# Session 9586: Pobrano 20 końcowych pozycji
# Session 9590: Pobrano 20 końcowych pozycji
# Session 9591: Pobrano 20 końcowych pozycji
# Session 9592: Pobrano 20 końcowych pozycji
# Session 9593: Pobrano 20 końcowych pozycji
# Session 9594: Pobrano 20 końcowych pozycji
# Session 9598: Pobrano 20 końcowych pozycji
# Session 9599: Pobrano 20 końcowych pozycji
# Session 9600: Pobrano 20 końcowych pozycji
# Session 9601: Pobrano 20 końcowych pozycji
# Session 9602: Pobrano 20 końcowych pozycji
# Session 9606: Pobrano 20 końcowych pozycji
# Session 9607: Pobrano 20 końcowych pozycji
# Session 9612: Pobrano 20 końcowych pozycji
# Session 9616: Pobrano 20 końcowych pozycji
# Session 9608: Pobrano 20 końcowych pozycji
# Session 9617: Pobrano 20 końcowych pozycji
# Session 9618: Pobrano 20 końcowych pozycji
# Session 9619: Pobrano 20 końcowych pozycji
# Session 9620: Pobrano 20 końcowych pozycji
# Session 9621: Pobrano 20 końcowych pozycji
# Session 9625: Pobrano 20 końcowych pozycji
# Session 9626: Pobrano 20 końcowych pozycji
# Session 9631: Pobrano 20 końcowych pozycji
# Session 9635: Pobrano 20 końcowych pozycji
# Session 9627: Pobrano 20 końcowych pozycji
# Session 9636: Pobrano 20 końcowych pozycji
# Session 9637: Pobrano 20 końcowych pozycji
# Session 9638: Pobrano 20 końcowych pozycji
# Session 9639: Pobrano 20 końcowych pozycji
# Session 9640: Pobrano 20 końcowych pozycji
# Session 9644: Pobrano 20 końcowych pozycji
# Session 9645: Pobrano 20 końcowych pozycji
# Session 9650: Pobrano 20 końcowych pozycji
# Session 9654: Pobrano 20 końcowych pozycji
# Session 9646: Pobrano 20 końcowych pozycji
# Session 9655: Pobrano 20 końcowych pozycji
# Session 9461: Pobrano 20 końcowych pozycji
# Session 9656: Pobrano 20 końcowych pozycji
# Session 9657: Pobrano 20 końcowych pozycji
# Session 9658: Pobrano 20 końcowych pozycji
# Session 9662: Pobrano 20 końcowych pozycji
# Session 9683: Pobrano 20 końcowych pozycji
# Session 9684: Pobrano 18 końcowych pozycji
# Session 9685: Pobrano 18 końcowych pozycji
# Session 9686: Pobrano 20 końcowych pozycji
# Session 9687: Pobrano 20 końcowych pozycji
# Session 9688: Pobrano 20 końcowych pozycji
# Session 9689: Pobrano 20 końcowych pozycji
# Session 9693: Pobrano 20 końcowych pozycji
# Session 9988: Pobrano 20 końcowych pozycji
# Session 9989: Pobrano 20 końcowych pozycji
# Session 9993: Pobrano 20 końcowych pozycji
# Session 9994: Pobrano 20 końcowych pozycji
# Session 9998: Pobrano 20 końcowych pozycji
# Session 9999: Pobrano 20 końcowych pozycji
# Session 10000: Pobrano 20 końcowych pozycji
# Session 10001: Pobrano 20 końcowych pozycji
# Session 10002: Pobrano 20 końcowych pozycji
# Session 10006: Pobrano 20 końcowych pozycji
# Session 10007: Pobrano 20 końcowych pozycji
# Session 10008: Pobrano 20 końcowych pozycji
# Session 10009: Pobrano 20 końcowych pozycji
# Session 10010: Pobrano 20 końcowych pozycji
# Session 10014: Pobrano 20 końcowych pozycji
# Session 10015: Pobrano 20 końcowych pozycji
# Session 10016: Pobrano 20 końcowych pozycji
# Session 10017: Pobrano 20 końcowych pozycji
# Session 10018: Pobrano 20 końcowych pozycji
# Session 10022: Pobrano 20 końcowych pozycji
# Session 10023: Pobrano 20 końcowych pozycji
# Session 10024: Pobrano 20 końcowych pozycji
# Session 10028: Pobrano 20 końcowych pozycji
# Session 10029: Pobrano 20 końcowych pozycji
# Session 10033: Pobrano 20 końcowych pozycji
# Session 9980: Pobrano 20 końcowych pozycji
# Session 9981: Pobrano 20 końcowych pozycji
# Session 9982: Pobrano 20 końcowych pozycji
# Session 9983: Pobrano 20 końcowych pozycji
# Session 9987: Pobrano 20 końcowych pozycji
# Session 9972: Pobrano 20 końcowych pozycji
# Session 9973: Pobrano 20 końcowych pozycji
# Session 9974: Pobrano 20 końcowych pozycji
# Session 9975: Pobrano 20 końcowych pozycji
# Session 9979: Pobrano 20 końcowych pozycji
# Session 9964: Pobrano 20 końcowych pozycji
# Session 9965: Pobrano 20 końcowych pozycji
# Session 9966: Pobrano 20 końcowych pozycji
# Session 9967: Pobrano 20 końcowych pozycji
# Session 9971: Pobrano 19 końcowych pozycji
# Session 9956: Pobrano 20 końcowych pozycji
# Session 9957: Pobrano 20 końcowych pozycji
# Session 9958: Pobrano 20 końcowych pozycji
# Session 9959: Pobrano 20 końcowych pozycji
# Session 9963: Pobrano 20 końcowych pozycji
# Session 9948: Pobrano 20 końcowych pozycji
# Session 9949: Pobrano 20 końcowych pozycji
# Session 9950: Pobrano 20 końcowych pozycji
# Session 9951: Pobrano 20 końcowych pozycji
# Session 9955: Pobrano 20 końcowych pozycji
# Session 9940: Pobrano 20 końcowych pozycji
# Session 9941: Pobrano 20 końcowych pozycji
# Session 9942: Pobrano 20 końcowych pozycji
# Session 9943: Pobrano 20 końcowych pozycji
# Session 9947: Pobrano 20 końcowych pozycji
# Session 9929: Pobrano 20 końcowych pozycji
# Session 9930: Pobrano 20 końcowych pozycji
# Session 9934: Pobrano 20 końcowych pozycji
# Session 9935: Pobrano 20 końcowych pozycji
# Session 9939: Pobrano 20 końcowych pozycji
# Session 9921: Pobrano 20 końcowych pozycji
# Session 9922: Pobrano 20 końcowych pozycji
# Session 9923: Pobrano 20 końcowych pozycji
# Session 9924: Pobrano 20 końcowych pozycji
# Session 9928: Pobrano 20 końcowych pozycji
# Session 9913: Pobrano 20 końcowych pozycji
# Session 9914: Pobrano 20 końcowych pozycji
# Session 9915: Pobrano 20 końcowych pozycji
# Session 9916: Pobrano 20 końcowych pozycji
# Session 9920: Pobrano 20 końcowych pozycji
# Session 9905: Pobrano 20 końcowych pozycji
# Session 9906: Pobrano 20 końcowych pozycji
# Session 9907: Pobrano 20 końcowych pozycji
# Session 9908: Pobrano 20 końcowych pozycji
# Session 9912: Pobrano 20 końcowych pozycji
# Session 9897: Pobrano 20 końcowych pozycji
# Session 9898: Pobrano 20 końcowych pozycji
# Session 9899: Pobrano 20 końcowych pozycji
# Session 9900: Pobrano 20 końcowych pozycji
#    circuit_key circuit_short_name country_code  country_key country_name  \
# 0           63             Sakhir          BRN           36      Bahrain
# 1           63             Sakhir          BRN           36      Bahrain
# 2           63             Sakhir          BRN           36      Bahrain
# 3           63             Sakhir          BRN           36      Bahrain
# 4           63             Sakhir          BRN           36      Bahrain
#
#    date_start time_start gmt_offset location  meeting_key  ...  \
# 0  2023-02-23   07:00:00   03:00:00   Sakhir         1140  ...
# 1  2023-02-23   07:00:00   03:00:00   Sakhir         1140  ...
# 2  2023-02-23   07:00:00   03:00:00   Sakhir         1140  ...
# 3  2023-02-23   07:00:00   03:00:00   Sakhir         1140  ...
# 4  2023-02-23   07:00:00   03:00:00   Sakhir         1140  ...
#
#                       meeting_official_name  year  session_key  session_name  \
# 0  FORMULA 1 ARAMCO PRE-SEASON TESTING 2023  2023         9222    Practice 1
# 1  FORMULA 1 ARAMCO PRE-SEASON TESTING 2023  2023         9222    Practice 1
# 2  FORMULA 1 ARAMCO PRE-SEASON TESTING 2023  2023         9222    Practice 1
# 3  FORMULA 1 ARAMCO PRE-SEASON TESTING 2023  2023         9222    Practice 1
# 4  FORMULA 1 ARAMCO PRE-SEASON TESTING 2023  2023         9222    Practice 1
#
#   session_type driver_number  position  broadcast_name        full_name  \
# 0     Practice             1         1    M VERSTAPPEN   Max VERSTAPPEN
# 1     Practice             2        10      L SARGEANT   Logan SARGEANT
# 2     Practice             4         5        L NORRIS     Lando NORRIS
# 3     Practice            10        16         P GASLY     Pierre GASLY
# 4     Practice            14         2        F ALONSO  Fernando ALONSO
#
#          team_name
# 0  Red Bull Racing
# 1         Williams
# 2          McLaren
# 3           Alpine
# 4     Aston Martin
#
# [5 rows x 21 columns]

# %%
# pobierz początkową pozycję dla każdego z kierowców w meetings dla każdej sesji
def get_starting_session_position(session_keys, include_driver_details=True):
    all_results = []
    
    for session_key in session_keys:
        url = f"https://api.openf1.org/v1/position?session_key={session_key}"
        response = requests.get(url)
        
        if response.status_code == 200:
            data = response.json()
            
            if isinstance(data, list) and len(data) > 0:
                # najstarsze na początku
                data_sorted = sorted(data, key=lambda x: x.get('date', ''))
                
                # pierwsze pozycje dla każdego kierowcy
                first_positions = {}
                for record in data_sorted:
                    driver_number = record.get('driver_number')
                    if driver_number and driver_number not in first_positions:
                        first_positions[driver_number] = record
                
                date, time = format_datetime_fields(data_sorted[0]['date'])
                for driver_number, record in first_positions.items():
                    result = {
                        'session_key': session_key,
                        'driver_number': driver_number,
                        'position': record.get('position'),
                        'date': date,
                        'time': time,
                        'meeting_key': record.get('meeting_key')
                    }
                    all_results.append(result)
                
                print(f"Session {session_key}: Pobrano {len(first_positions)} początkowych pozycji")
            else:
                print(f"Session {session_key}: Brak danych pozycji")
        else:
            print(f"Error fetching data for session {session_key}: {response.status_code}")
        
        sleep(0.5)
    
    results_df = pd.DataFrame(all_results)
    
    if not results_df.empty and include_driver_details:
        # merge z danymi o sesjach
        results_df = results_df.merge(
            all_sessions_df[['session_key', 'session_name', 'year', 'location', 'country_name']], 
            on='session_key', 
            how='left'
        )

        # merge z danymi o kierowcach używając session_key
        results_df = results_df.merge(
            drivers_df[['driver_number', 'session_key', 'broadcast_name', 'full_name', 'team_name']].drop_duplicates(), 
            on=['driver_number', 'session_key'], 
            how='left'
        )
    
    return results_df

# %%
starting_position_df = get_starting_session_position(sessions_key_unique, include_driver_details=True)
starting_position_df.head()
# Out:
# Session 9222: Pobrano 19 początkowych pozycji
# Session 7763: Pobrano 17 początkowych pozycji
# Session 7764: Pobrano 17 początkowych pozycji
# Session 7765: Pobrano 20 początkowych pozycji
# Session 7766: Pobrano 20 początkowych pozycji
# Session 7767: Pobrano 20 początkowych pozycji
# Session 7768: Pobrano 20 początkowych pozycji
# Session 7953: Pobrano 20 początkowych pozycji
# Session 7772: Pobrano 20 początkowych pozycji
# Session 7773: Pobrano 20 początkowych pozycji
# Session 7774: Pobrano 20 początkowych pozycji
# Session 7775: Pobrano 20 początkowych pozycji
# Session 7779: Pobrano 20 początkowych pozycji
# Session 7780: Pobrano 20 początkowych pozycji
# Session 7781: Pobrano 20 początkowych pozycji
# Session 7782: Pobrano 20 początkowych pozycji
# Session 7783: Pobrano 20 początkowych pozycji
# Session 7787: Pobrano 20 początkowych pozycji
# Session 9063: Pobrano 20 początkowych pozycji
# Session 9064: Pobrano 20 początkowych pozycji
# Session 9278: Pobrano 20 początkowych pozycji
# Session 9069: Pobrano 19 początkowych pozycji
# Session 9070: Pobrano 20 początkowych pozycji
# Session 9071: Pobrano 20 początkowych pozycji
# Session 9072: Pobrano 20 początkowych pozycji
# Session 9073: Pobrano 20 początkowych pozycji
# Session 9074: Pobrano 20 początkowych pozycji
# Session 9078: Pobrano 20 początkowych pozycji
# Session 9087: Pobrano 20 początkowych pozycji
# Session 9088: Pobrano 20 początkowych pozycji
# Session 9089: Pobrano 20 początkowych pozycji
# Session 9090: Pobrano 20 początkowych pozycji
# Session 9094: Pobrano 20 początkowych pozycji
# Session 9095: Pobrano 20 początkowych pozycji
# Session 9096: Pobrano 20 początkowych pozycji
# Session 9097: Pobrano 20 początkowych pozycji
# Session 9098: Pobrano 20 początkowych pozycji
# Session 9102: Pobrano 20 początkowych pozycji
# Session 9103: Pobrano 20 początkowych pozycji
# Session 9104: Pobrano 20 początkowych pozycji
# Session 9105: Pobrano 20 początkowych pozycji
# Session 9106: Pobrano 20 początkowych pozycji
# Session 9110: Pobrano 20 początkowych pozycji
# Session 9111: Pobrano 20 początkowych pozycji
# Session 9112: Pobrano 20 początkowych pozycji
# Session 9282: Pobrano 20 początkowych pozycji
# Session 9117: Pobrano 20 początkowych pozycji
# Session 9118: Pobrano 20 początkowych pozycji
# Session 9119: Pobrano 20 początkowych pozycji
# Session 9120: Pobrano 20 początkowych pozycji
# Session 9121: Pobrano 20 początkowych pozycji
# Session 9122: Pobrano 20 początkowych pozycji
# Session 9126: Pobrano 20 początkowych pozycji
# Session 9223: Pobrano 20 początkowych pozycji
# Session 9127: Pobrano 20 początkowych pozycji
# Session 9128: Pobrano 20 początkowych pozycji
# Session 9129: Pobrano 20 początkowych pozycji
# Session 9133: Pobrano 20 początkowych pozycji
# Session 9134: Pobrano 20 początkowych pozycji
# Session 9135: Pobrano 20 początkowych pozycji
# Session 9286: Pobrano 20 początkowych pozycji
# Session 9140: Pobrano 20 początkowych pozycji
# Session 9141: Pobrano 20 początkowych pozycji
# Session 9142: Pobrano 20 początkowych pozycji
# Session 9143: Pobrano 20 początkowych pozycji
# Session 9144: Pobrano 20 początkowych pozycji
# Session 9145: Pobrano 20 początkowych pozycji
# Session 9149: Pobrano 20 początkowych pozycji
# Session 9150: Pobrano 20 początkowych pozycji
# Session 9151: Pobrano 20 początkowych pozycji
# Session 9152: Pobrano 20 początkowych pozycji
# Session 9153: Pobrano 20 początkowych pozycji
# Session 9157: Pobrano 20 początkowych pozycji
# Session 9158: Pobrano 20 początkowych pozycji
# Session 9159: Pobrano 20 początkowych pozycji
# Session 9160: Pobrano 20 początkowych pozycji
# Session 9161: Pobrano 20 początkowych pozycji
# Session 9165: Pobrano 19 początkowych pozycji
# Session 9166: Pobrano 20 początkowych pozycji
# Session 9167: Pobrano 20 początkowych pozycji
# Session 9168: Pobrano 20 początkowych pozycji
# Session 9169: Pobrano 20 początkowych pozycji
# Session 9173: Pobrano 20 początkowych pozycji
# Session 9214: Pobrano 20 początkowych pozycji
# Session 9215: Pobrano 20 początkowych pozycji
# Session 9298: Pobrano 20 początkowych pozycji
# Session 9220: Pobrano 20 początkowych pozycji
# Session 9221: Pobrano 20 początkowych pozycji
# Session 9206: Pobrano 20 początkowych pozycji
# Session 9207: Pobrano 20 początkowych pozycji
# Session 9294: Pobrano 20 początkowych pozycji
# Session 9212: Pobrano 20 początkowych pozycji
# Session 9213: Pobrano 20 początkowych pozycji
# Session 9174: Pobrano 20 początkowych pozycji
# Session 9175: Pobrano 20 początkowych pozycji
# Session 9176: Pobrano 20 początkowych pozycji
# Session 9177: Pobrano 20 początkowych pozycji
# Session 9181: Pobrano 20 początkowych pozycji
# Session 9198: Pobrano 20 początkowych pozycji
# Session 9304: Pobrano 20 początkowych pozycji
# Session 9308: Pobrano 20 początkowych pozycji
# Session 9204: Pobrano 20 początkowych pozycji
# Session 9205: Pobrano 20 początkowych pozycji
# Session 9182: Pobrano 20 początkowych pozycji
# Session 9183: Pobrano 20 początkowych pozycji
# Session 9184: Pobrano 20 początkowych pozycji
# Session 9314: Pobrano 20 początkowych pozycji
# Session 9189: Pobrano 20 początkowych pozycji
# Session 9190: Pobrano 20 początkowych pozycji
# Session 9191: Pobrano 20 początkowych pozycji
# Session 9192: Pobrano 20 początkowych pozycji
# Session 9193: Pobrano 20 początkowych pozycji
# Session 9197: Pobrano 20 początkowych pozycji
# Session 9462: Pobrano 20 początkowych pozycji
# Session 9463: Pobrano 20 początkowych pozycji
# Session 9464: Pobrano 20 początkowych pozycji
# Session 9465: Pobrano 20 początkowych pozycji
# Session 9466: Pobrano 20 początkowych pozycji
# Session 9467: Pobrano 20 początkowych pozycji
# Session 9468: Pobrano 20 początkowych pozycji
# Session 9472: Pobrano 20 początkowych pozycji
# Session 9473: Pobrano 20 początkowych pozycji
# Session 9474: Pobrano 20 początkowych pozycji
# Session 9475: Pobrano 20 początkowych pozycji
# Session 9476: Pobrano 20 początkowych pozycji
# Session 9480: Pobrano 20 początkowych pozycji
# Session 9481: Pobrano 20 początkowych pozycji
# Session 9482: Pobrano 20 początkowych pozycji
# Session 9483: Pobrano 19 początkowych pozycji
# Session 9484: Pobrano 19 początkowych pozycji
# Session 9488: Pobrano 19 początkowych pozycji
# Session 9489: Pobrano 20 początkowych pozycji
# Session 9490: Pobrano 20 początkowych pozycji
# Session 9491: Pobrano 20 początkowych pozycji
# Session 9492: Pobrano 20 początkowych pozycji
# Session 9496: Pobrano 20 początkowych pozycji
# Session 9663: Pobrano 20 początkowych pozycji
# Session 9668: Pobrano 20 początkowych pozycji
# Session 9672: Pobrano 20 początkowych pozycji
# Session 9664: Pobrano 20 początkowych pozycji
# Session 9673: Pobrano 20 początkowych pozycji
# Session 9497: Pobrano 20 początkowych pozycji
# Session 9502: Pobrano 20 początkowych pozycji
# Session 9506: Pobrano 20 początkowych pozycji
# Session 9498: Pobrano 20 początkowych pozycji
# Session 9507: Pobrano 20 początkowych pozycji
# Session 9508: Pobrano 20 początkowych pozycji
# Session 9509: Pobrano 20 początkowych pozycji
# Session 9510: Pobrano 20 początkowych pozycji
# Session 9511: Pobrano 20 początkowych pozycji
# Session 9515: Pobrano 20 początkowych pozycji
# Session 9516: Pobrano 20 początkowych pozycji
# Session 9517: Pobrano 20 początkowych pozycji
# Session 9518: Pobrano 20 początkowych pozycji
# Session 9519: Pobrano 20 początkowych pozycji
# Session 9523: Pobrano 20 początkowych pozycji
# Session 9524: Pobrano 20 początkowych pozycji
# Session 9525: Pobrano 20 początkowych pozycji
# Session 9526: Pobrano 20 początkowych pozycji
# Session 9527: Pobrano 20 początkowych pozycji
# Session 9531: Pobrano 20 początkowych pozycji
# Session 9532: Pobrano 20 początkowych pozycji
# Session 9533: Pobrano 20 początkowych pozycji
# Session 9534: Pobrano 20 początkowych pozycji
# Session 9535: Pobrano 20 początkowych pozycji
# Session 9539: Pobrano 20 początkowych pozycji
# Session 9540: Pobrano 20 początkowych pozycji
# Session 9545: Pobrano 20 początkowych pozycji
# Session 9549: Pobrano 20 początkowych pozycji
# Session 9541: Pobrano 20 początkowych pozycji
# Session 9550: Pobrano 20 początkowych pozycji
# Session 9551: Pobrano 20 początkowych pozycji
# Session 9552: Pobrano 20 początkowych pozycji
# Session 9553: Pobrano 20 początkowych pozycji
# Session 9554: Pobrano 20 początkowych pozycji
# Session 9558: Pobrano 20 początkowych pozycji
# Session 9559: Pobrano 20 początkowych pozycji
# Session 9560: Pobrano 20 początkowych pozycji
# Session 9561: Pobrano 20 początkowych pozycji
# Session 9562: Pobrano 20 początkowych pozycji
# Session 9566: Pobrano 20 początkowych pozycji
# Session 9567: Pobrano 20 początkowych pozycji
# Session 9568: Pobrano 20 początkowych pozycji
# Session 9569: Pobrano 20 początkowych pozycji
# Session 9570: Pobrano 20 początkowych pozycji
# Session 9574: Pobrano 20 początkowych pozycji
# Session 9575: Pobrano 20 początkowych pozycji
# Session 9576: Pobrano 20 początkowych pozycji
# Session 9577: Pobrano 20 początkowych pozycji
# Session 9578: Pobrano 20 początkowych pozycji
# Session 9582: Pobrano 20 początkowych pozycji
# Session 9583: Pobrano 20 początkowych pozycji
# Session 9584: Pobrano 20 początkowych pozycji
# Session 9585: Pobrano 20 początkowych pozycji
# Session 9586: Pobrano 20 początkowych pozycji
# Session 9590: Pobrano 20 początkowych pozycji
# Session 9591: Pobrano 20 początkowych pozycji
# Session 9592: Pobrano 20 początkowych pozycji
# Session 9593: Pobrano 20 początkowych pozycji
# Session 9594: Pobrano 20 początkowych pozycji
# Session 9598: Pobrano 20 początkowych pozycji
# Session 9599: Pobrano 20 początkowych pozycji
# Session 9600: Pobrano 20 początkowych pozycji
# Session 9601: Pobrano 20 początkowych pozycji
# Session 9602: Pobrano 20 początkowych pozycji
# Session 9606: Pobrano 20 początkowych pozycji
# Session 9607: Pobrano 20 początkowych pozycji
# Session 9612: Pobrano 20 początkowych pozycji
# Session 9616: Pobrano 20 początkowych pozycji
# Session 9608: Pobrano 20 początkowych pozycji
# Session 9617: Pobrano 20 początkowych pozycji
# Session 9618: Pobrano 20 początkowych pozycji
# Session 9619: Pobrano 20 początkowych pozycji
# Session 9620: Pobrano 20 początkowych pozycji
# Session 9621: Pobrano 20 początkowych pozycji
# Session 9625: Pobrano 20 początkowych pozycji
# Session 9626: Pobrano 20 początkowych pozycji
# Session 9631: Pobrano 20 początkowych pozycji
# Session 9635: Pobrano 20 początkowych pozycji
# Session 9627: Pobrano 20 początkowych pozycji
# Session 9636: Pobrano 20 początkowych pozycji
# Session 9637: Pobrano 20 początkowych pozycji
# Session 9638: Pobrano 20 początkowych pozycji
# Session 9639: Pobrano 20 początkowych pozycji
# Session 9640: Pobrano 20 początkowych pozycji
# Session 9644: Pobrano 20 początkowych pozycji
# Session 9645: Pobrano 20 początkowych pozycji
# Session 9650: Pobrano 20 początkowych pozycji
# Session 9654: Pobrano 20 początkowych pozycji
# Session 9646: Pobrano 20 początkowych pozycji
# Session 9655: Pobrano 20 początkowych pozycji
# Session 9461: Pobrano 20 początkowych pozycji
# Session 9656: Pobrano 20 początkowych pozycji
# Session 9657: Pobrano 20 początkowych pozycji
# Session 9658: Pobrano 20 początkowych pozycji
# Session 9662: Pobrano 20 początkowych pozycji
# Session 9683: Pobrano 20 początkowych pozycji
# Session 9684: Pobrano 18 początkowych pozycji
# Session 9685: Pobrano 18 początkowych pozycji
# Session 9686: Pobrano 20 początkowych pozycji
# Session 9687: Pobrano 20 początkowych pozycji
# Session 9688: Pobrano 20 początkowych pozycji
# Session 9689: Pobrano 20 początkowych pozycji
# Session 9693: Pobrano 20 początkowych pozycji
# Session 9988: Pobrano 20 początkowych pozycji
# Session 9989: Pobrano 20 początkowych pozycji
# Session 9993: Pobrano 20 początkowych pozycji
# Session 9994: Pobrano 20 początkowych pozycji
# Session 9998: Pobrano 20 początkowych pozycji
# Session 9999: Pobrano 20 początkowych pozycji
# Session 10000: Pobrano 20 początkowych pozycji
# Session 10001: Pobrano 20 początkowych pozycji
# Session 10002: Pobrano 20 początkowych pozycji
# Session 10006: Pobrano 20 początkowych pozycji
# Session 10007: Pobrano 20 początkowych pozycji
# Session 10008: Pobrano 20 początkowych pozycji
# Session 10009: Pobrano 20 początkowych pozycji
# Session 10010: Pobrano 20 początkowych pozycji
# Session 10014: Pobrano 20 początkowych pozycji
# Session 10015: Pobrano 20 początkowych pozycji
# Session 10016: Pobrano 20 początkowych pozycji
# Session 10017: Pobrano 20 początkowych pozycji
# Session 10018: Pobrano 20 początkowych pozycji
# Session 10022: Pobrano 20 początkowych pozycji
# Session 10023: Pobrano 20 początkowych pozycji
# Session 10024: Pobrano 20 początkowych pozycji
# Session 10028: Pobrano 20 początkowych pozycji
# Session 10029: Pobrano 20 początkowych pozycji
# Session 10033: Pobrano 20 początkowych pozycji
# Session 9980: Pobrano 20 początkowych pozycji
# Session 9981: Pobrano 20 początkowych pozycji
# Session 9982: Pobrano 20 początkowych pozycji
# Session 9983: Pobrano 20 początkowych pozycji
# Session 9987: Pobrano 20 początkowych pozycji
# Session 9972: Pobrano 20 początkowych pozycji
# Session 9973: Pobrano 20 początkowych pozycji
# Session 9974: Pobrano 20 początkowych pozycji
# Session 9975: Pobrano 20 początkowych pozycji
# Session 9979: Pobrano 20 początkowych pozycji
# Session 9964: Pobrano 20 początkowych pozycji
# Session 9965: Pobrano 20 początkowych pozycji
# Session 9966: Pobrano 20 początkowych pozycji
# Session 9967: Pobrano 20 początkowych pozycji
# Session 9971: Pobrano 19 początkowych pozycji
# Session 9956: Pobrano 20 początkowych pozycji
# Session 9957: Pobrano 20 początkowych pozycji
# Session 9958: Pobrano 20 początkowych pozycji
# Session 9959: Pobrano 20 początkowych pozycji
# Session 9963: Pobrano 20 początkowych pozycji
# Session 9948: Pobrano 20 początkowych pozycji
# Session 9949: Pobrano 20 początkowych pozycji
# Session 9950: Pobrano 20 początkowych pozycji
# Session 9951: Pobrano 20 początkowych pozycji
# Session 9955: Pobrano 20 początkowych pozycji
# Session 9940: Pobrano 20 początkowych pozycji
# Session 9941: Pobrano 20 początkowych pozycji
# Session 9942: Pobrano 20 początkowych pozycji
# Session 9943: Pobrano 20 początkowych pozycji
# Session 9947: Pobrano 20 początkowych pozycji
# Session 9929: Pobrano 20 początkowych pozycji
# Session 9930: Pobrano 20 początkowych pozycji
# Session 9934: Pobrano 20 początkowych pozycji
# Session 9935: Pobrano 20 początkowych pozycji
# Session 9939: Pobrano 20 początkowych pozycji
# Session 9921: Pobrano 20 początkowych pozycji
# Session 9922: Pobrano 20 początkowych pozycji
# Session 9923: Pobrano 20 początkowych pozycji
# Session 9924: Pobrano 20 początkowych pozycji
# Session 9928: Pobrano 20 początkowych pozycji
# Session 9913: Pobrano 20 początkowych pozycji
# Session 9914: Pobrano 20 początkowych pozycji
# Session 9915: Pobrano 20 początkowych pozycji
# Session 9916: Pobrano 20 początkowych pozycji
# Session 9920: Pobrano 20 początkowych pozycji
# Session 9905: Pobrano 20 początkowych pozycji
# Session 9906: Pobrano 20 początkowych pozycji
# Session 9907: Pobrano 20 początkowych pozycji
# Session 9908: Pobrano 20 początkowych pozycji
# Session 9912: Pobrano 20 początkowych pozycji
# Session 9897: Pobrano 20 początkowych pozycji
# Session 9898: Pobrano 20 początkowych pozycji
# Session 9899: Pobrano 20 początkowych pozycji
# Session 9900: Pobrano 20 początkowych pozycji
#    session_key  driver_number  position        date             time  \
# 0         9222              1         1  2023-02-23  06:54:49.318000
# 1         9222              2         2  2023-02-23  06:54:49.318000
# 2         9222              4         3  2023-02-23  06:54:49.318000
# 3         9222             10         4  2023-02-23  06:54:49.318000
# 4         9222             14         5  2023-02-23  06:54:49.318000
#
#    meeting_key session_name  year location country_name broadcast_name  \
# 0         1140   Practice 1  2023   Sakhir      Bahrain   M VERSTAPPEN
# 1         1140   Practice 1  2023   Sakhir      Bahrain     L SARGEANT
# 2         1140   Practice 1  2023   Sakhir      Bahrain       L NORRIS
# 3         1140   Practice 1  2023   Sakhir      Bahrain        P GASLY
# 4         1140   Practice 1  2023   Sakhir      Bahrain       F ALONSO
#
#          full_name        team_name
# 0   Max VERSTAPPEN  Red Bull Racing
# 1   Logan SARGEANT         Williams
# 2     Lando NORRIS          McLaren
# 3     Pierre GASLY           Alpine
# 4  Fernando ALONSO     Aston Martin

# %%
# dla kazdego meeting w session pobierz pit stop dla kazdego kierowcy gdzie pit duration jest rozny od null
def get_pit_stops_for_sessions(session_key):
    pit_stops = []
    
    for session_key in session_key:
        url = f"https://api.openf1.org/v1/pit?session_key={session_key}&pit_duration>0"
        response = requests.get(url)
        
        if response.status_code == 200:
            data = response.json()
            
            pit_date, pit_time = format_datetime_fields(data[0]['date']) if data else (None, None)

            if isinstance(data, list) and len(data) > 0:
                for pit in data:
                    pit_stops.append({
                        'meeting_key': pit.get('meeting_key'),
                        'session_key': session_key,
                        'driver_number': pit.get('driver_number'),
                        'lap': pit.get('lap'),
                        'pit_duration': pit.get('pit_duration'),
                        'date': pit_date,
                        'time': pit_time,
                    })
                print(f"Fetched {len(data)} pit stops for session {session_key}")
            else:
                print(f"No pit stops found for session {session_key}")
        else:
            print(f"Error fetching data for session {session_key}: {response.status_code}")
        
        sleep(0.5)
    
    return pd.DataFrame(pit_stops)

# %%
pit_stops_df = get_pit_stops_for_sessions(sessions_key_unique)
pit_stops_df.head()
# Out:
# No pit stops found for session 9222
# No pit stops found for session 7763
# No pit stops found for session 7764
# No pit stops found for session 7765
# No pit stops found for session 7766
# No pit stops found for session 7767
# No pit stops found for session 7768
# No pit stops found for session 7953
# No pit stops found for session 7772
# No pit stops found for session 7773
# No pit stops found for session 7774
# No pit stops found for session 7775
# No pit stops found for session 7779
# No pit stops found for session 7780
# No pit stops found for session 7781
# No pit stops found for session 7782
# No pit stops found for session 7783
# No pit stops found for session 7787
# No pit stops found for session 9063
# No pit stops found for session 9064
# No pit stops found for session 9278
# No pit stops found for session 9069
# No pit stops found for session 9070
# No pit stops found for session 9071
# No pit stops found for session 9072
# No pit stops found for session 9073
# No pit stops found for session 9074
# No pit stops found for session 9078
# No pit stops found for session 9087
# No pit stops found for session 9088
# No pit stops found for session 9089
# No pit stops found for session 9090
# No pit stops found for session 9094
# Fetched 76 pit stops for session 9095
# Fetched 75 pit stops for session 9096
# Fetched 41 pit stops for session 9097
# Fetched 71 pit stops for session 9098
# Fetched 43 pit stops for session 9102
# No pit stops found for session 9103
# Fetched 98 pit stops for session 9104
# Fetched 40 pit stops for session 9105
# Fetched 64 pit stops for session 9106
# Fetched 33 pit stops for session 9110
# Fetched 74 pit stops for session 9111
# Fetched 70 pit stops for session 9112
# Fetched 65 pit stops for session 9282
# Fetched 11 pit stops for session 9117
# Fetched 63 pit stops for session 9118
# Fetched 71 pit stops for session 9119
# Fetched 59 pit stops for session 9120
# Fetched 58 pit stops for session 9121
# Fetched 81 pit stops for session 9122
# Fetched 24 pit stops for session 9126
# Fetched 61 pit stops for session 9223
# Fetched 63 pit stops for session 9127
# Fetched 75 pit stops for session 9128
# Fetched 73 pit stops for session 9129
# Fetched 36 pit stops for session 9133
# Fetched 30 pit stops for session 9134
# Fetched 68 pit stops for session 9135
# Fetched 35 pit stops for session 9286
# Fetched 10 pit stops for session 9140
# Fetched 37 pit stops for session 9141
# Fetched 58 pit stops for session 9142
# Fetched 35 pit stops for session 9143
# Fetched 36 pit stops for session 9144
# Fetched 75 pit stops for session 9145
# Fetched 101 pit stops for session 9149
# Fetched 53 pit stops for session 9150
# Fetched 60 pit stops for session 9151
# Fetched 73 pit stops for session 9152
# Fetched 76 pit stops for session 9153
# Fetched 25 pit stops for session 9157
# Fetched 53 pit stops for session 9158
# Fetched 53 pit stops for session 9159
# Fetched 66 pit stops for session 9160
# Fetched 72 pit stops for session 9161
# Fetched 25 pit stops for session 9165
# Fetched 59 pit stops for session 9166
# Fetched 68 pit stops for session 9167
# Fetched 61 pit stops for session 9168
# Fetched 45 pit stops for session 9169
# Fetched 43 pit stops for session 9173
# Fetched 62 pit stops for session 9214
# Fetched 74 pit stops for session 9215
# Fetched 28 pit stops for session 9298
# Fetched 3 pit stops for session 9220
# Fetched 54 pit stops for session 9221
# Fetched 49 pit stops for session 9206
# Fetched 74 pit stops for session 9207
# Fetched 35 pit stops for session 9294
# No pit stops found for session 9212
# Fetched 36 pit stops for session 9213
# Fetched 62 pit stops for session 9174
# Fetched 75 pit stops for session 9175
# Fetched 64 pit stops for session 9176
# Fetched 71 pit stops for session 9177
# Fetched 38 pit stops for session 9181
# Fetched 60 pit stops for session 9198
# Fetched 77 pit stops for session 9304
# Fetched 40 pit stops for session 9308
# No pit stops found for session 9204
# Fetched 67 pit stops for session 9205
# Fetched 1 pit stops for session 9182
# Fetched 77 pit stops for session 9183
# Fetched 40 pit stops for session 9184
# Fetched 55 pit stops for session 9314
# Fetched 31 pit stops for session 9189
# Fetched 76 pit stops for session 9190
# Fetched 26 pit stops for session 9191
# Fetched 72 pit stops for session 9192
# Fetched 69 pit stops for session 9193
# Fetched 37 pit stops for session 9197
# Fetched 197 pit stops for session 9462
# Fetched 191 pit stops for session 9463
# Fetched 192 pit stops for session 9464
# Fetched 58 pit stops for session 9465
# Fetched 59 pit stops for session 9466
# Fetched 64 pit stops for session 9467
# Fetched 72 pit stops for session 9468
# Fetched 43 pit stops for session 9472
# Fetched 54 pit stops for session 9473
# Fetched 57 pit stops for session 9474
# Fetched 44 pit stops for session 9475
# Fetched 73 pit stops for session 9476
# Fetched 19 pit stops for session 9480
# Fetched 62 pit stops for session 9481
# Fetched 57 pit stops for session 9482
# Fetched 67 pit stops for session 9483
# Fetched 67 pit stops for session 9484
# Fetched 36 pit stops for session 9488
# Fetched 59 pit stops for session 9489
# Fetched 17 pit stops for session 9490
# Fetched 56 pit stops for session 9491
# Fetched 55 pit stops for session 9492
# Fetched 54 pit stops for session 9496
# Fetched 35 pit stops for session 9663
# Fetched 33 pit stops for session 9668
# Fetched 1 pit stops for session 9672
# Fetched 74 pit stops for session 9664
# Fetched 40 pit stops for session 9673
# Fetched 47 pit stops for session 9497
# Fetched 38 pit stops for session 9502
# Fetched 37 pit stops for session 9506
# Fetched 83 pit stops for session 9498
# Fetched 28 pit stops for session 9507
# Fetched 62 pit stops for session 9508
# Fetched 58 pit stops for session 9509
# Fetched 72 pit stops for session 9510
# Fetched 80 pit stops for session 9511
# Fetched 27 pit stops for session 9515
# Fetched 55 pit stops for session 9516
# Fetched 57 pit stops for session 9517
# Fetched 49 pit stops for session 9518
# Fetched 72 pit stops for session 9519
# Fetched 23 pit stops for session 9523
# Fetched 28 pit stops for session 9524
# Fetched 45 pit stops for session 9525
# Fetched 61 pit stops for session 9526
# Fetched 71 pit stops for session 9527
# Fetched 42 pit stops for session 9531
# Fetched 87 pit stops for session 9532
# Fetched 71 pit stops for session 9533
# Fetched 78 pit stops for session 9534
# Fetched 67 pit stops for session 9535
# Fetched 42 pit stops for session 9539
# Fetched 99 pit stops for session 9540
# Fetched 41 pit stops for session 9545
# No pit stops found for session 9549
# Fetched 88 pit stops for session 9541
# Fetched 45 pit stops for session 9550
# Fetched 53 pit stops for session 9551
# Fetched 62 pit stops for session 9552
# Fetched 39 pit stops for session 9553
# Fetched 78 pit stops for session 9554
# Fetched 45 pit stops for session 9558
# Fetched 84 pit stops for session 9559
# Fetched 62 pit stops for session 9560
# Fetched 93 pit stops for session 9561
# Fetched 75 pit stops for session 9562
# Fetched 40 pit stops for session 9566
# Fetched 46 pit stops for session 9567
# Fetched 59 pit stops for session 9568
# Fetched 5 pit stops for session 9569
# Fetched 64 pit stops for session 9570
# Fetched 34 pit stops for session 9574
# Fetched 49 pit stops for session 9575
# Fetched 60 pit stops for session 9576
# Fetched 15 pit stops for session 9577
# Fetched 75 pit stops for session 9578
# Fetched 26 pit stops for session 9582
# Fetched 54 pit stops for session 9583
# Fetched 73 pit stops for session 9584
# Fetched 97 pit stops for session 9585
# Fetched 72 pit stops for session 9586
# Fetched 30 pit stops for session 9590
# Fetched 21 pit stops for session 9591
# Fetched 50 pit stops for session 9592
# Fetched 53 pit stops for session 9593
# Fetched 68 pit stops for session 9594
# Fetched 22 pit stops for session 9598
# Fetched 46 pit stops for session 9599
# Fetched 64 pit stops for session 9600
# Fetched 60 pit stops for session 9601
# Fetched 73 pit stops for session 9602
# Fetched 23 pit stops for session 9606
# Fetched 56 pit stops for session 9607
# Fetched 42 pit stops for session 9612
# No pit stops found for session 9616
# Fetched 79 pit stops for session 9608
# Fetched 23 pit stops for session 9617
# Fetched 43 pit stops for session 9618
# Fetched 57 pit stops for session 9619
# Fetched 83 pit stops for session 9620
# Fetched 79 pit stops for session 9621
# Fetched 21 pit stops for session 9625
# Fetched 82 pit stops for session 9626
# Fetched 51 pit stops for session 9631
# No pit stops found for session 9635
# Fetched 69 pit stops for session 9627
# Fetched 35 pit stops for session 9636
# Fetched 46 pit stops for session 9637
# Fetched 49 pit stops for session 9638
# Fetched 62 pit stops for session 9639
# Fetched 62 pit stops for session 9640
# Fetched 39 pit stops for session 9644
# Fetched 69 pit stops for session 9645
# Fetched 34 pit stops for session 9650
# Fetched 2 pit stops for session 9654
# Fetched 76 pit stops for session 9646
# Fetched 60 pit stops for session 9655
# Fetched 71 pit stops for session 9461
# Fetched 67 pit stops for session 9656
# Fetched 66 pit stops for session 9657
# Fetched 72 pit stops for session 9658
# Fetched 28 pit stops for session 9662
# Fetched 235 pit stops for session 9683
# Fetched 199 pit stops for session 9684
# Fetched 210 pit stops for session 9685
# Fetched 58 pit stops for session 9686
# Fetched 64 pit stops for session 9687
# Fetched 82 pit stops for session 9688
# Fetched 81 pit stops for session 9689
# Fetched 82 pit stops for session 9693
# Fetched 54 pit stops for session 9988
# Fetched 37 pit stops for session 9989
# Fetched 1 pit stops for session 9993
# Fetched 81 pit stops for session 9994
# Fetched 25 pit stops for session 9998
# Fetched 67 pit stops for session 9999
# Fetched 7 pit stops for session 10000
# Fetched 54 pit stops for session 10001
# Fetched 76 pit stops for session 10002
# Fetched 21 pit stops for session 10006
# Fetched 70 pit stops for session 10007
# Fetched 69 pit stops for session 10008
# Fetched 76 pit stops for session 10009
# Fetched 83 pit stops for session 10010
# Fetched 42 pit stops for session 10014
# Fetched 68 pit stops for session 10015
# Fetched 78 pit stops for session 10016
# Fetched 90 pit stops for session 10017
# Fetched 78 pit stops for session 10018
# Fetched 19 pit stops for session 10022
# Fetched 63 pit stops for session 10023
# Fetched 45 pit stops for session 10024
# Fetched 20 pit stops for session 10028
# Fetched 84 pit stops for session 10029
# Fetched 18 pit stops for session 10033
# Fetched 80 pit stops for session 9980
# Fetched 85 pit stops for session 9981
# Fetched 78 pit stops for session 9982
# Fetched 73 pit stops for session 9983
# Fetched 37 pit stops for session 9987
# Fetched 36 pit stops for session 9972
# Fetched 36 pit stops for session 9973
# Fetched 56 pit stops for session 9974
# Fetched 71 pit stops for session 9975
# Fetched 40 pit stops for session 9979
# Fetched 82 pit stops for session 9964
# Fetched 93 pit stops for session 9965
# Fetched 74 pit stops for session 9966
# Fetched 66 pit stops for session 9967
# Fetched 54 pit stops for session 9971
# Fetched 53 pit stops for session 9956
# Fetched 56 pit stops for session 9957
# Fetched 52 pit stops for session 9958
# Fetched 80 pit stops for session 9959
# Fetched 82 pit stops for session 9963
# Fetched 82 pit stops for session 9948
# Fetched 91 pit stops for session 9949
# Fetched 86 pit stops for session 9950
# Fetched 85 pit stops for session 9951
# Fetched 32 pit stops for session 9955
# Fetched 68 pit stops for session 9940
# Fetched 77 pit stops for session 9941
# Fetched 73 pit stops for session 9942
# Fetched 69 pit stops for session 9943
# Fetched 35 pit stops for session 9947
# Fetched 52 pit stops for session 9929
# Fetched 33 pit stops for session 9930
# No pit stops found for session 9934
# Fetched 82 pit stops for session 9935
# Fetched 26 pit stops for session 9939
# Fetched 107 pit stops for session 9921
# Fetched 89 pit stops for session 9922
# Fetched 86 pit stops for session 9923
# Fetched 68 pit stops for session 9924
# Fetched 29 pit stops for session 9928
# Fetched 65 pit stops for session 9913
# Fetched 64 pit stops for session 9914
# Fetched 75 pit stops for session 9915
# Fetched 79 pit stops for session 9916
# Fetched 40 pit stops for session 9920
# Fetched 83 pit stops for session 9905
# Fetched 68 pit stops for session 9906
# Fetched 32 pit stops for session 9907
# Fetched 83 pit stops for session 9908
# Fetched 19 pit stops for session 9912
# Fetched 29 pit stops for session 9897
# Fetched 49 pit stops for session 9898
# Fetched 40 pit stops for session 9899
# Fetched 47 pit stops for session 9900
#    meeting_key  session_key  driver_number   lap  pit_duration        date  \
# 0         1211         9095             14  None          35.3  2023-06-02
# 1         1211         9095             18  None          40.8  2023-06-02
# 2         1211         9095             21  None         155.2  2023-06-02
# 3         1211         9095              2  None         277.0  2023-06-02
# 4         1211         9095             16  None          27.6  2023-06-02
#
#               time
# 0  11:33:46.930000
# 1  11:33:46.930000
# 2  11:33:46.930000
# 3  11:33:46.930000
# 4  11:33:46.930000

# %%
# agregacja pit stops - liczba pit stopów i średnia długość pit stopu dla każdego kierowcy w każdej sesji
pit_stops_agg = (
    pit_stops_df
    .groupby(['session_key', 'driver_number'])
    .agg(
        pit_stop_count=('pit_duration', 'count'),
        avg_pit_duration=('pit_duration', 'mean')
    )
    .reset_index()
)

# %%
pit_stops_agg.head()
# Out:
#    session_key  driver_number  pit_stop_count  avg_pit_duration
# 0         9095              1               4           239.700
# 1         9095              2               4           278.725
# 2         9095              4               4           381.075
# 3         9095             10               3           452.400
# 4         9095             11               4           226.825

# %%
# https://api.openf1.org/v1/race_control
# get all race control for all session in meetings

def get_race_control(session_keys):
    """
    Pobiera wszystkie dane race control dla określonych sesji
    """
    all_race_control = []
    
    for session_key in session_keys:
        url = f"https://api.openf1.org/v1/race_control?session_key={session_key}"
        response = requests.get(url)
        
        if response.status_code == 200:
            data = response.json()
            
            if isinstance(data, list) and len(data) > 0:
                for control in data:
                    date, time = format_datetime_fields(control['date'])
                    
                    race_control_record = {
                        'session_key': session_key,
                        'date': date,
                        'time': time,
                        'category': control.get('category'),
                        'flag': control.get('flag'),
                        'lap_number': control.get('lap_number'),
                        'message': control.get('message')
                    }
                    all_race_control.append(race_control_record)
                
                print(f"Session {session_key}: Pobrano {len(data)} wiadomości race control")
            else:
                print(f"Session {session_key}: Brak danych race control")
        else:
            print(f"Error fetching race control for session {session_key}: {response.status_code}")
        
        sleep(0.5)
    
    return pd.DataFrame(all_race_control)

# %%
race_controlls_df = get_race_control(sessions_key_unique)
race_controlls_df.head()
# Out:
# Session 9222: Pobrano 82 wiadomości race control
# Session 7763: Pobrano 36 wiadomości race control
# Session 7764: Pobrano 46 wiadomości race control
# Session 7765: Pobrano 17 wiadomości race control
# Session 7766: Pobrano 15 wiadomości race control
# Session 7767: Pobrano 5 wiadomości race control
# Session 7768: Pobrano 21 wiadomości race control
# Session 7953: Pobrano 73 wiadomości race control
# Session 7772: Pobrano 25 wiadomości race control
# Session 7773: Pobrano 20 wiadomości race control
# Session 7774: Pobrano 16 wiadomości race control
# Session 7775: Pobrano 42 wiadomości race control
# Session 7779: Pobrano 56 wiadomości race control
# Session 7780: Pobrano 37 wiadomości race control
# Session 7781: Pobrano 66 wiadomości race control
# Session 7782: Pobrano 45 wiadomości race control
# Session 7783: Pobrano 64 wiadomości race control
# Session 7787: Pobrano 103 wiadomości race control
# Session 9063: Pobrano 82 wiadomości race control
# Session 9064: Pobrano 61 wiadomości race control
# Session 9278: Pobrano 57 wiadomości race control
# Session 9069: Pobrano 48 wiadomości race control
# Session 9070: Pobrano 52 wiadomości race control
# Session 9071: Pobrano 38 wiadomości race control
# Session 9072: Pobrano 29 wiadomości race control
# Session 9073: Pobrano 13 wiadomości race control
# Session 9074: Pobrano 25 wiadomości race control
# Session 9078: Pobrano 38 wiadomości race control
# Session 9087: Pobrano 24 wiadomości race control
# Session 9088: Pobrano 26 wiadomości race control
# Session 9089: Pobrano 26 wiadomości race control
# Session 9090: Pobrano 42 wiadomości race control
# Session 9094: Pobrano 242 wiadomości race control
# Session 9095: Pobrano 7 wiadomości race control
# Session 9096: Pobrano 5 wiadomości race control
# Session 9097: Pobrano 15 wiadomości race control
# Session 9098: Pobrano 37 wiadomości race control
# Session 9102: Pobrano 47 wiadomości race control
# Session 9103: Pobrano 11 wiadomości race control
# Session 9104: Pobrano 54 wiadomości race control
# Session 9105: Pobrano 34 wiadomości race control
# Session 9106: Pobrano 75 wiadomości race control
# Session 9110: Pobrano 75 wiadomości race control
# Session 9111: Pobrano 17 wiadomości race control
# Session 9112: Pobrano 77 wiadomości race control
# Session 9282: Pobrano 41 wiadomości race control
# Session 9117: Pobrano 44 wiadomości race control
# Session 9118: Pobrano 210 wiadomości race control
# Session 9119: Pobrano 17 wiadomości race control
# Session 9120: Pobrano 14 wiadomości race control
# Session 9121: Pobrano 18 wiadomości race control
# Session 9122: Pobrano 73 wiadomości race control
# Session 9126: Pobrano 44 wiadomości race control
# Session 9223: Pobrano 110 wiadomości race control
# Session 9127: Pobrano 12 wiadomości race control
# Session 9128: Pobrano 9 wiadomości race control
# Session 9129: Pobrano 25 wiadomości race control
# Session 9133: Pobrano 85 wiadomości race control
# Session 9134: Pobrano 55 wiadomości race control
# Session 9135: Pobrano 110 wiadomości race control
# Session 9286: Pobrano 105 wiadomości race control
# Session 9140: Pobrano 84 wiadomości race control
# Session 9141: Pobrano 54 wiadomości race control
# Session 9142: Pobrano 24 wiadomości race control
# Session 9143: Pobrano 30 wiadomości race control
# Session 9144: Pobrano 47 wiadomości race control
# Session 9145: Pobrano 55 wiadomości race control
# Session 9149: Pobrano 74 wiadomości race control
# Session 9150: Pobrano 19 wiadomości race control
# Session 9151: Pobrano 35 wiadomości race control
# Session 9152: Pobrano 21 wiadomości race control
# Session 9153: Pobrano 20 wiadomości race control
# Session 9157: Pobrano 43 wiadomości race control
# Session 9158: Pobrano 19 wiadomości race control
# Session 9159: Pobrano 13 wiadomości race control
# Session 9160: Pobrano 21 wiadomości race control
# Session 9161: Pobrano 42 wiadomości race control
# Session 9165: Pobrano 74 wiadomości race control
# Session 9166: Pobrano 11 wiadomości race control
# Session 9167: Pobrano 18 wiadomości race control
# Session 9168: Pobrano 8 wiadomości race control
# Session 9169: Pobrano 26 wiadomości race control
# Session 9173: Pobrano 71 wiadomości race control
# Session 9214: Pobrano 7 wiadomości race control
# Session 9215: Pobrano 36 wiadomości race control
# Session 9298: Pobrano 46 wiadomości race control
# Session 9220: Pobrano 63 wiadomości race control
# Session 9221: Pobrano 135 wiadomości race control
# Session 9206: Pobrano 7 wiadomości race control
# Session 9207: Pobrano 25 wiadomości race control
# Session 9294: Pobrano 20 wiadomości race control
# Session 9212: Pobrano 38 wiadomości race control
# Session 9213: Pobrano 79 wiadomości race control
# Session 9174: Pobrano 10 wiadomości race control
# Session 9175: Pobrano 19 wiadomości race control
# Session 9176: Pobrano 31 wiadomości race control
# Session 9177: Pobrano 38 wiadomości race control
# Session 9181: Pobrano 96 wiadomości race control
# Session 9198: Pobrano 9 wiadomości race control
# Session 9304: Pobrano 33 wiadomości race control
# Session 9308: Pobrano 25 wiadomości race control
# Session 9204: Pobrano 10 wiadomości race control
# Session 9205: Pobrano 51 wiadomości race control
# Session 9182: Pobrano 11 wiadomości race control
# Session 9183: Pobrano 46 wiadomości race control
# Session 9184: Pobrano 37 wiadomości race control
# Session 9314: Pobrano 31 wiadomości race control
# Session 9189: Pobrano 73 wiadomości race control
# Session 9190: Pobrano 21 wiadomości race control
# Session 9191: Pobrano 19 wiadomości race control
# Session 9192: Pobrano 7 wiadomości race control
# Session 9193: Pobrano 21 wiadomości race control
# Session 9197: Pobrano 65 wiadomości race control
# Session 9462: Pobrano 22 wiadomości race control
# Session 9463: Pobrano 17 wiadomości race control
# Session 9464: Pobrano 23 wiadomości race control
# Session 9465: Pobrano 11 wiadomości race control
# Session 9466: Pobrano 8 wiadomości race control
# Session 9467: Pobrano 5 wiadomości race control
# Session 9468: Pobrano 14 wiadomości race control
# Session 9472: Pobrano 69 wiadomości race control
# Session 9473: Pobrano 6 wiadomości race control
# Session 9474: Pobrano 10 wiadomości race control
# Session 9475: Pobrano 21 wiadomości race control
# Session 9476: Pobrano 35 wiadomości race control
# Session 9480: Pobrano 66 wiadomości race control
# Session 9481: Pobrano 19 wiadomości race control
# Session 9482: Pobrano 25 wiadomości race control
# Session 9483: Pobrano 18 wiadomości race control
# Session 9484: Pobrano 41 wiadomości race control
# Session 9488: Pobrano 82 wiadomości race control
# Session 9489: Pobrano 15 wiadomości race control
# Session 9490: Pobrano 12 wiadomości race control
# Session 9491: Pobrano 9 wiadomości race control
# Session 9492: Pobrano 15 wiadomości race control
# Session 9496: Pobrano 66 wiadomości race control
# Session 9663: Pobrano 16 wiadomości race control
# Session 9668: Pobrano 62 wiadomości race control
# Session 9672: Pobrano 19 wiadomości race control
# Session 9664: Pobrano 37 wiadomości race control
# Session 9673: Pobrano 56 wiadomości race control
# Session 9497: Pobrano 19 wiadomości race control
# Session 9502: Pobrano 33 wiadomości race control
# Session 9506: Pobrano 56 wiadomości race control
# Session 9498: Pobrano 30 wiadomości race control
# Session 9507: Pobrano 75 wiadomości race control
# Session 9508: Pobrano 16 wiadomości race control
# Session 9509: Pobrano 9 wiadomości race control
# Session 9510: Pobrano 24 wiadomości race control
# Session 9511: Pobrano 28 wiadomości race control
# Session 9515: Pobrano 98 wiadomości race control
# Session 9516: Pobrano 25 wiadomości race control
# Session 9517: Pobrano 14 wiadomości race control
# Session 9518: Pobrano 37 wiadomości race control
# Session 9519: Pobrano 105 wiadomości race control
# Session 9523: Pobrano 118 wiadomości race control
# Session 9524: Pobrano 49 wiadomości race control
# Session 9525: Pobrano 32 wiadomości race control
# Session 9526: Pobrano 43 wiadomości race control
# Session 9527: Pobrano 41 wiadomości race control
# Session 9531: Pobrano 128 wiadomości race control
# Session 9532: Pobrano 11 wiadomości race control
# Session 9533: Pobrano 3 wiadomości race control
# Session 9534: Pobrano 15 wiadomości race control
# Session 9535: Pobrano 19 wiadomości race control
# Session 9539: Pobrano 105 wiadomości race control
# Session 9540: Pobrano 9 wiadomości race control
# Session 9545: Pobrano 24 wiadomości race control
# Session 9549: Pobrano 14 wiadomości race control
# Session 9541: Pobrano 31 wiadomości race control
# Session 9550: Pobrano 123 wiadomości race control
# Session 9551: Pobrano 20 wiadomości race control
# Session 9552: Pobrano 11 wiadomości race control
# Session 9553: Pobrano 20 wiadomości race control
# Session 9554: Pobrano 46 wiadomości race control
# Session 9558: Pobrano 108 wiadomości race control
# Session 9559: Pobrano 17 wiadomości race control
# Session 9560: Pobrano 27 wiadomości race control
# Session 9561: Pobrano 10 wiadomości race control
# Session 9562: Pobrano 52 wiadomości race control
# Session 9566: Pobrano 73 wiadomości race control
# Session 9567: Pobrano 11 wiadomości race control
# Session 9568: Pobrano 19 wiadomości race control
# Session 9569: Pobrano 37 wiadomości race control
# Session 9570: Pobrano 44 wiadomości race control
# Session 9574: Pobrano 21 wiadomości race control
# Session 9575: Pobrano 27 wiadomości race control
# Session 9576: Pobrano 38 wiadomości race control
# Session 9577: Pobrano 28 wiadomości race control
# Session 9578: Pobrano 17 wiadomości race control
# Session 9582: Pobrano 82 wiadomości race control
# Session 9583: Pobrano 19 wiadomości race control
# Session 9584: Pobrano 20 wiadomości race control
# Session 9585: Pobrano 18 wiadomości race control
# Session 9586: Pobrano 30 wiadomości race control
# Session 9590: Pobrano 59 wiadomości race control
# Session 9591: Pobrano 56 wiadomości race control
# Session 9592: Pobrano 62 wiadomości race control
# Session 9593: Pobrano 59 wiadomości race control
# Session 9594: Pobrano 76 wiadomości race control
# Session 9598: Pobrano 113 wiadomości race control
# Session 9599: Pobrano 12 wiadomości race control
# Session 9600: Pobrano 27 wiadomości race control
# Session 9601: Pobrano 18 wiadomości race control
# Session 9602: Pobrano 35 wiadomości race control
# Session 9606: Pobrano 61 wiadomości race control
# Session 9607: Pobrano 35 wiadomości race control
# Session 9612: Pobrano 36 wiadomości race control
# Session 9616: Pobrano 51 wiadomości race control
# Session 9608: Pobrano 34 wiadomości race control
# Session 9617: Pobrano 118 wiadomości race control
# Session 9618: Pobrano 32 wiadomości race control
# Session 9619: Pobrano 22 wiadomości race control
# Session 9620: Pobrano 19 wiadomości race control
# Session 9621: Pobrano 25 wiadomości race control
# Session 9625: Pobrano 118 wiadomości race control
# Session 9626: Pobrano 6 wiadomości race control
# Session 9631: Pobrano 17 wiadomości race control
# Session 9635: Pobrano 20 wiadomości race control
# Session 9627: Pobrano 115 wiadomości race control
# Session 9636: Pobrano 107 wiadomości race control
# Session 9637: Pobrano 28 wiadomości race control
# Session 9638: Pobrano 50 wiadomości race control
# Session 9639: Pobrano 21 wiadomości race control
# Session 9640: Pobrano 42 wiadomości race control
# Session 9644: Pobrano 35 wiadomości race control
# Session 9645: Pobrano 5 wiadomości race control
# Session 9650: Pobrano 25 wiadomości race control
# Session 9654: Pobrano 27 wiadomości race control
# Session 9646: Pobrano 39 wiadomości race control
# Session 9655: Pobrano 110 wiadomości race control
# Session 9461: Pobrano 17 wiadomości race control
# Session 9656: Pobrano 5 wiadomości race control
# Session 9657: Pobrano 3 wiadomości race control
# Session 9658: Pobrano 50 wiadomości race control
# Session 9662: Pobrano 129 wiadomości race control
# Session 9683: Pobrano 58 wiadomości race control
# Session 9684: Pobrano 49 wiadomości race control
# Session 9685: Pobrano 81 wiadomości race control
# Session 9686: Pobrano 29 wiadomości race control
# Session 9687: Pobrano 10 wiadomości race control
# Session 9688: Pobrano 14 wiadomości race control
# Session 9689: Pobrano 53 wiadomości race control
# Session 9693: Pobrano 113 wiadomości race control
# Session 9988: Pobrano 11 wiadomości race control
# Session 9989: Pobrano 123 wiadomości race control
# Session 9993: Pobrano 27 wiadomości race control
# Session 9994: Pobrano 117 wiadomości race control
# Session 9998: Pobrano 56 wiadomości race control
# Session 9999: Pobrano 4 wiadomości race control
# Session 10000: Pobrano 31 wiadomości race control
# Session 10001: Pobrano 15 wiadomości race control
# Session 10002: Pobrano 28 wiadomości race control
# Session 10006: Pobrano 23 wiadomości race control
# Session 10007: Pobrano 9 wiadomości race control
# Session 10008: Pobrano 9 wiadomości race control
# Session 10009: Pobrano 18 wiadomości race control
# Session 10010: Pobrano 62 wiadomości race control
# Session 10014: Pobrano 91 wiadomości race control
# Session 10015: Pobrano 10 wiadomości race control
# Session 10016: Pobrano 21 wiadomości race control
# Session 10017: Pobrano 12 wiadomości race control
# Session 10018: Pobrano 56 wiadomości race control
# Session 10022: Pobrano 65 wiadomości race control
# Session 10023: Pobrano 11 wiadomości race control
# Session 10024: Pobrano 25 wiadomości race control
# Session 10028: Pobrano 107 wiadomości race control
# Session 10029: Pobrano 18 wiadomości race control
# Session 10033: Pobrano 76 wiadomości race control
# Session 9980: Pobrano 14 wiadomości race control
# Session 9981: Pobrano 38 wiadomości race control
# Session 9982: Pobrano 17 wiadomości race control
# Session 9983: Pobrano 46 wiadomości race control
# Session 9987: Pobrano 44 wiadomości race control
# Session 9972: Pobrano 58 wiadomości race control
# Session 9973: Pobrano 39 wiadomości race control
# Session 9974: Pobrano 24 wiadomości race control
# Session 9975: Pobrano 78 wiadomości race control
# Session 9979: Pobrano 196 wiadomości race control
# Session 9964: Pobrano 17 wiadomości race control
# Session 9965: Pobrano 15 wiadomości race control
# Session 9966: Pobrano 13 wiadomości race control
# Session 9967: Pobrano 22 wiadomości race control
# Session 9971: Pobrano 100 wiadomości race control
# Session 9956: Pobrano 30 wiadomości race control
# Session 9957: Pobrano 25 wiadomości race control
# Session 9958: Pobrano 27 wiadomości race control
# Session 9959: Pobrano 45 wiadomości race control
# Session 9963: Pobrano 96 wiadomości race control
# Session 9948: Pobrano 15 wiadomości race control
# Session 9949: Pobrano 8 wiadomości race control
# Session 9950: Pobrano 32 wiadomości race control
# Session 9951: Pobrano 56 wiadomości race control
# Session 9955: Pobrano 117 wiadomości race control
# Session 9940: Pobrano 15 wiadomości race control
# Session 9941: Pobrano 15 wiadomości race control
# Session 9942: Pobrano 72 wiadomości race control
# Session 9943: Pobrano 50 wiadomości race control
# Session 9947: Pobrano 156 wiadomości race control
# Session 9929: Pobrano 19 wiadomości race control
# Session 9930: Pobrano 94 wiadomości race control
# Session 9934: Pobrano 81 wiadomości race control
# Session 9935: Pobrano 42 wiadomości race control
# Session 9939: Pobrano 115 wiadomości race control
# Session 9921: Pobrano 25 wiadomości race control
# Session 9922: Pobrano 24 wiadomości race control
# Session 9923: Pobrano 9 wiadomości race control
# Session 9924: Pobrano 23 wiadomości race control
# Session 9928: Pobrano 92 wiadomości race control
# Session 9913: Pobrano 56 wiadomości race control
# Session 9914: Pobrano 65 wiadomości race control
# Session 9915: Pobrano 23 wiadomości race control
# Session 9916: Pobrano 50 wiadomości race control
# Session 9920: Pobrano 108 wiadomości race control
# Session 9905: Pobrano 45 wiadomości race control
# Session 9906: Pobrano 42 wiadomości race control
# Session 9907: Pobrano 11 wiadomości race control
# Session 9908: Pobrano 30 wiadomości race control
# Session 9912: Pobrano 71 wiadomości race control
# Session 9897: Pobrano 131 wiadomości race control
# Session 9898: Pobrano 44 wiadomości race control
# Session 9899: Pobrano 82 wiadomości race control
# Session 9900: Pobrano 200 wiadomości race control
#    session_key        date      time category   flag  lap_number  \
# 0         9222  2023-02-23  07:00:00     Flag  GREEN         NaN
# 1         9222  2023-02-23  07:08:43     Flag    RED         NaN
# 2         9222  2023-02-23  07:25:11    Other   None         NaN
# 3         9222  2023-02-23  07:25:35     Flag  CLEAR         NaN
# 4         9222  2023-02-23  07:25:39      Drs   None         NaN
#
#                         message
# 0   GREEN LIGHT - PIT EXIT OPEN
# 1                      RED FLAG
# 2  SESSION WILL RESUME AT 10:30
# 3                   TRACK CLEAR
# 4                   DRS ENABLED

# %%
# # pobierz rodzaje opon 
# # https://api.openf1.org/v1/stints?session_key={session_key}
# #     "compound": "SOFT",
# #     "driver_number": 16,
# #     "lap_end": 20,
# #     "lap_start": 1,
# #     "meeting_key": 1219,
# #     "session_key": 9165,
# #     "stint_number": 1,
# #     "tyre_age_at_start": 3

# def get_tyre_stints(session_keys):
#     all_tyres = []
    
#     for session_key in session_keys:
#         url = f"https://api.openf1.org/v1/stints?session_key={session_key}"
#         response = requests.get(url)
        
#         if response.status_code == 200:
#             data = response.json()
            
#             if isinstance(data, list) and len(data) > 0:
#                 for stint in data:
#                     tyre_record = {
#                         'session_key': session_key,
#                         'driver_number': stint.get('driver_number'),
#                         'stint_number': stint.get('stint_number'),
#                         'compound': stint.get('compound'),
#                         'lap_start': stint.get('lap_start'),
#                         'lap_end': stint.get('lap_end'),
#                         'tyre_age_at_start': stint.get('tyre_age_at_start'),
#                         'meeting_key': stint.get('meeting_key')
#                     }
#                     all_tyres.append(tyre_record)
                
#                 print(f"Session {session_key}: Pobrano {len(data)} stints")
#             else:
#                 print(f"Session {session_key}: Brak danych o oponach")
#         else:
#             print(f"Error fetching tyre stints for session {session_key}: {response.status_code}")
        
#         sleep(0.5)
    
#     return pd.DataFrame(all_tyres)

# %%
# stints_tyre = get_tyre_stints(sessions_key_unique)
# stints_tyre.head()
# Out:
# Session 9222: Pobrano 267 stints
# Session 7763: Pobrano 234 stints
# Session 7764: Pobrano 271 stints
# Session 7765: Pobrano 80 stints
# Session 7766: Pobrano 81 stints
# Session 7767: Pobrano 81 stints
# Session 7768: Pobrano 93 stints
# Session 7953: Pobrano 70 stints
# Session 7772: Pobrano 79 stints
# Session 7773: Pobrano 72 stints
# Session 7774: Pobrano 71 stints
# Session 7775: Pobrano 80 stints
# Session 7779: Pobrano 44 stints
# Session 7780: Pobrano 73 stints
# Session 7781: Pobrano 68 stints
# Session 7782: Pobrano 79 stints
# Session 7783: Pobrano 82 stints
# Session 7787: Pobrano 85 stints
# Session 9063: Pobrano 57 stints
# Session 9064: Pobrano 101 stints
# Session 9278: Pobrano 43 stints
# Session 9069: Pobrano 23 stints
# Session 9070: Pobrano 43 stints
# Session 9071: Pobrano 70 stints
# Session 9072: Pobrano 95 stints
# Session 9073: Pobrano 90 stints
# Session 9074: Pobrano 81 stints
# Session 9078: Pobrano 40 stints
# Session 9087: Pobrano 68 stints
# Session 9088: Pobrano 79 stints
# Session 9089: Pobrano 63 stints
# Session 9090: Pobrano 96 stints
# Session 9094: Pobrano 57 stints
# Session 9095: Pobrano 96 stints
# Session 9096: Pobrano 95 stints
# Session 9097: Pobrano 72 stints
# Session 9098: Pobrano 108 stints
# Session 9102: Pobrano 63 stints
# Session 9103: Pobrano 17 stints
# Session 9104: Pobrano 118 stints
# Session 9105: Pobrano 61 stints
# Session 9106: Pobrano 103 stints
# Session 9110: Pobrano 53 stints
# Session 9111: Pobrano 94 stints
# Session 9112: Pobrano 106 stints
# Session 9282: Pobrano 85 stints
# Session 9117: Pobrano 31 stints
# Session 9118: Pobrano 83 stints
# Session 9119: Pobrano 91 stints
# Session 9120: Pobrano 78 stints
# Session 9121: Pobrano 78 stints
# Session 9122: Pobrano 105 stints
# Session 9126: Pobrano 44 stints
# Session 9223: Pobrano 114 stints
# Session 9127: Pobrano 83 stints
# Session 9128: Pobrano 95 stints
# Session 9129: Pobrano 94 stints
# Session 9133: Pobrano 56 stints
# Session 9134: Pobrano 50 stints
# Session 9135: Pobrano 88 stints
# Session 9286: Pobrano 55 stints
# Session 9140: Pobrano 42 stints
# Session 9141: Pobrano 57 stints
# Session 9142: Pobrano 78 stints
# Session 9143: Pobrano 72 stints
# Session 9144: Pobrano 73 stints
# Session 9145: Pobrano 95 stints
# Session 9149: Pobrano 121 stints
# Session 9150: Pobrano 73 stints
# Session 9151: Pobrano 96 stints
# Session 9152: Pobrano 93 stints
# Session 9153: Pobrano 96 stints
# Session 9157: Pobrano 45 stints
# Session 9158: Pobrano 73 stints
# Session 9159: Pobrano 73 stints
# Session 9160: Pobrano 86 stints
# Session 9161: Pobrano 92 stints
# Session 9165: Pobrano 44 stints
# Session 9166: Pobrano 79 stints
# Session 9167: Pobrano 88 stints
# Session 9168: Pobrano 81 stints
# Session 9169: Pobrano 82 stints
# Session 9173: Pobrano 63 stints
# Session 9214: Pobrano 82 stints
# Session 9215: Pobrano 94 stints
# Session 9298: Pobrano 48 stints
# Session 9220: Pobrano 23 stints
# Session 9221: Pobrano 73 stints
# Session 9206: Pobrano 69 stints
# Session 9207: Pobrano 94 stints
# Session 9294: Pobrano 55 stints
# Session 9212: Pobrano 20 stints
# Session 9213: Pobrano 56 stints
# Session 9174: Pobrano 82 stints
# Session 9175: Pobrano 95 stints
# Session 9176: Pobrano 84 stints
# Session 9177: Pobrano 91 stints
# Session 9181: Pobrano 58 stints
# Session 9198: Pobrano 80 stints
# Session 9304: Pobrano 97 stints
# Session 9308: Pobrano 65 stints
# Session 9204: Pobrano 20 stints
# Session 9205: Pobrano 87 stints
# Session 9182: Pobrano 20 stints
# Session 9183: Pobrano 97 stints
# Session 9184: Pobrano 60 stints
# Session 9314: Pobrano 75 stints
# Session 9189: Pobrano 51 stints
# Session 9190: Pobrano 96 stints
# Session 9191: Pobrano 75 stints
# Session 9192: Pobrano 92 stints
# Session 9193: Pobrano 89 stints
# Session 9197: Pobrano 57 stints
# Session 9462: Pobrano 220 stints
# Session 9463: Pobrano 217 stints
# Session 9464: Pobrano 216 stints
# Session 9465: Pobrano 79 stints
# Session 9466: Pobrano 79 stints
# Session 9467: Pobrano 84 stints
# Session 9468: Pobrano 92 stints
# Session 9472: Pobrano 63 stints
# Session 9473: Pobrano 74 stints
# Session 9474: Pobrano 77 stints
# Session 9475: Pobrano 64 stints
# Session 9476: Pobrano 93 stints
# Session 9480: Pobrano 39 stints
# Session 9481: Pobrano 81 stints
# Session 9482: Pobrano 76 stints
# Session 9483: Pobrano 86 stints
# Session 9484: Pobrano 86 stints
# Session 9488: Pobrano 55 stints
# Session 9489: Pobrano 79 stints
# Session 9490: Pobrano 30 stints
# Session 9491: Pobrano 76 stints
# Session 9492: Pobrano 75 stints
# Session 9496: Pobrano 74 stints
# Session 9663: Pobrano 71 stints
# Session 9668: Pobrano 53 stints
# Session 9672: Pobrano 21 stints
# Session 9664: Pobrano 94 stints
# Session 9673: Pobrano 60 stints
# Session 9497: Pobrano 82 stints
# Session 9502: Pobrano 58 stints
# Session 9506: Pobrano 57 stints
# Session 9498: Pobrano 103 stints
# Session 9507: Pobrano 48 stints
# Session 9508: Pobrano 85 stints
# Session 9509: Pobrano 78 stints
# Session 9510: Pobrano 100 stints
# Session 9511: Pobrano 100 stints
# Session 9515: Pobrano 47 stints
# Session 9516: Pobrano 75 stints
# Session 9517: Pobrano 77 stints
# Session 9518: Pobrano 74 stints
# Session 9519: Pobrano 92 stints
# Session 9523: Pobrano 43 stints
# Session 9524: Pobrano 52 stints
# Session 9525: Pobrano 65 stints
# Session 9526: Pobrano 94 stints
# Session 9527: Pobrano 91 stints
# Session 9531: Pobrano 62 stints
# Session 9532: Pobrano 107 stints
# Session 9533: Pobrano 91 stints
# Session 9534: Pobrano 98 stints
# Session 9535: Pobrano 87 stints
# Session 9539: Pobrano 62 stints
# Session 9540: Pobrano 119 stints
# Session 9545: Pobrano 61 stints
# Session 9549: Pobrano 20 stints
# Session 9541: Pobrano 108 stints
# Session 9550: Pobrano 65 stints
# Session 9551: Pobrano 87 stints
# Session 9552: Pobrano 82 stints
# Session 9553: Pobrano 76 stints
# Session 9554: Pobrano 102 stints
# Session 9558: Pobrano 65 stints
# Session 9559: Pobrano 104 stints
# Session 9560: Pobrano 84 stints
# Session 9561: Pobrano 113 stints
# Session 9562: Pobrano 100 stints
# Session 9566: Pobrano 60 stints
# Session 9567: Pobrano 66 stints
# Session 9568: Pobrano 79 stints
# Session 9569: Pobrano 28 stints
# Session 9570: Pobrano 84 stints
# Session 9574: Pobrano 58 stints
# Session 9575: Pobrano 69 stints
# Session 9576: Pobrano 81 stints
# Session 9577: Pobrano 43 stints
# Session 9578: Pobrano 94 stints
# Session 9582: Pobrano 46 stints
# Session 9583: Pobrano 88 stints
# Session 9584: Pobrano 94 stints
# Session 9585: Pobrano 117 stints
# Session 9586: Pobrano 92 stints
# Session 9590: Pobrano 50 stints
# Session 9591: Pobrano 77 stints
# Session 9592: Pobrano 70 stints
# Session 9593: Pobrano 87 stints
# Session 9594: Pobrano 88 stints
# Session 9598: Pobrano 42 stints
# Session 9599: Pobrano 66 stints
# Session 9600: Pobrano 84 stints
# Session 9601: Pobrano 80 stints
# Session 9602: Pobrano 93 stints
# Session 9606: Pobrano 43 stints
# Session 9607: Pobrano 76 stints
# Session 9612: Pobrano 62 stints
# Session 9616: Pobrano 20 stints
# Session 9608: Pobrano 99 stints
# Session 9617: Pobrano 43 stints
# Session 9618: Pobrano 85 stints
# Session 9619: Pobrano 77 stints
# Session 9620: Pobrano 103 stints
# Session 9621: Pobrano 99 stints
# Session 9625: Pobrano 41 stints
# Session 9626: Pobrano 102 stints
# Session 9631: Pobrano 71 stints
# Session 9635: Pobrano 20 stints
# Session 9627: Pobrano 108 stints
# Session 9636: Pobrano 54 stints
# Session 9637: Pobrano 71 stints
# Session 9638: Pobrano 69 stints
# Session 9639: Pobrano 82 stints
# Session 9640: Pobrano 82 stints
# Session 9644: Pobrano 59 stints
# Session 9645: Pobrano 89 stints
# Session 9650: Pobrano 54 stints
# Session 9654: Pobrano 22 stints
# Session 9646: Pobrano 95 stints
# Session 9655: Pobrano 82 stints
# Session 9461: Pobrano 91 stints
# Session 9656: Pobrano 87 stints
# Session 9657: Pobrano 86 stints
# Session 9658: Pobrano 92 stints
# Session 9662: Pobrano 48 stints
# Session 9683: Pobrano 255 stints
# Session 9684: Pobrano 227 stints
# Session 9685: Pobrano 231 stints
# Session 9686: Pobrano 80 stints
# Session 9687: Pobrano 83 stints
# Session 9688: Pobrano 104 stints
# Session 9689: Pobrano 101 stints
# Session 9693: Pobrano 106 stints
# Session 9988: Pobrano 74 stints
# Session 9989: Pobrano 57 stints
# Session 9993: Pobrano 21 stints
# Session 9994: Pobrano 101 stints
# Session 9998: Pobrano 45 stints
# Session 9999: Pobrano 87 stints
# Session 10000: Pobrano 76 stints
# Session 10001: Pobrano 84 stints
# Session 10002: Pobrano 96 stints
# Session 10006: Pobrano 41 stints
# Session 10007: Pobrano 90 stints
# Session 10008: Pobrano 89 stints
# Session 10009: Pobrano 96 stints
# Session 10010: Pobrano 103 stints
# Session 10014: Pobrano 62 stints
# Session 10015: Pobrano 88 stints
# Session 10016: Pobrano 97 stints
# Session 10017: Pobrano 110 stints
# Session 10018: Pobrano 99 stints
# Session 10022: Pobrano 39 stints
# Session 10023: Pobrano 83 stints
# Session 10024: Pobrano 65 stints
# Session 10028: Pobrano 39 stints
# Session 10029: Pobrano 104 stints
# Session 10033: Pobrano 38 stints
# Session 9980: Pobrano 100 stints
# Session 9981: Pobrano 105 stints
# Session 9982: Pobrano 98 stints
# Session 9983: Pobrano 102 stints
# Session 9987: Pobrano 57 stints
# Session 9972: Pobrano 73 stints
# Session 9973: Pobrano 95 stints
# Session 9974: Pobrano 76 stints
# Session 9975: Pobrano 91 stints
# Session 9979: Pobrano 59 stints
# Session 9964: Pobrano 102 stints
# Session 9965: Pobrano 113 stints
# Session 9966: Pobrano 94 stints
# Session 9967: Pobrano 86 stints
# Session 9971: Pobrano 73 stints
# Session 9956: Pobrano 86 stints
# Session 9957: Pobrano 75 stints
# Session 9958: Pobrano 78 stints
# Session 9959: Pobrano 103 stints
# Session 9963: Pobrano 102 stints
# Session 9948: Pobrano 102 stints
# Session 9949: Pobrano 123 stints
# Session 9950: Pobrano 124 stints
# Session 9951: Pobrano 117 stints
# Session 9955: Pobrano 52 stints
# Session 9940: Pobrano 88 stints
# Session 9941: Pobrano 97 stints
# Session 9942: Pobrano 93 stints
# Session 9943: Pobrano 93 stints
# Session 9947: Pobrano 55 stints
# Session 9929: Pobrano 72 stints
# Session 9930: Pobrano 53 stints
# Session 9934: Pobrano 21 stints
# Session 9935: Pobrano 102 stints
# Session 9939: Pobrano 60 stints
# Session 9921: Pobrano 104 stints
# Session 9922: Pobrano 109 stints
# Session 9923: Pobrano 106 stints
# Session 9924: Pobrano 88 stints
# Session 9928: Pobrano 49 stints
# Session 9913: Pobrano 100 stints
# Session 9914: Pobrano 94 stints
# Session 9915: Pobrano 95 stints
# Session 9916: Pobrano 99 stints
# Session 9920: Pobrano 60 stints
# Session 9905: Pobrano 99 stints
# Session 9906: Pobrano 101 stints
# Session 9907: Pobrano 99 stints
# Session 9908: Pobrano 103 stints
# Session 9912: Pobrano 39 stints
# Session 9897: Pobrano 65 stints
# Session 9898: Pobrano 69 stints
# Session 9899: Pobrano 60 stints
# Session 9900: Pobrano 122 stints
#    session_key  driver_number  stint_number compound  lap_start  lap_end  \
# 0         9222             63             1   MEDIUM        1.0      6.0
# 1         9222             24             1   MEDIUM        1.0      3.0
# 2         9222             23             1     SOFT        1.0      2.0
# 3         9222             55             1   MEDIUM        1.0      4.0
# 4         9222             22             1   MEDIUM        1.0      3.0
#
#    tyre_age_at_start  meeting_key
# 0                0.0         1140
# 1                0.0         1140
# 2                0.0         1140
# 3                0.0         1140
# 4                0.0         1140

# %%
# pobierz dane pogodowe dla każdej sesji
# https://api.openf1.org/v1/weather
    # "air_temperature": 27.8,
    # "date": "2023-05-07T18:42:25.233000+00:00",
    # "humidity": 58,
    # "meeting_key": 1208,
    # "pressure": 1018.7,
    # "rainfall": 0,
    # "session_key": 9078,
    # "track_temperature": 52.5,
    # "wind_direction": 136,
    # "wind_speed": 2.4

def get_weather_data(session_keys):
    all_weather = []
    
    for session_key in session_keys:
        url = f"https://api.openf1.org/v1/weather?session_key={session_key}"
        response = requests.get(url)
        
        if response.status_code == 200:
            data = response.json()
            
            if isinstance(data, list) and len(data) > 0:
                for weather in data:
                    date_w, time_w = format_datetime_fields(weather['date'])
                    weather_record = {
                        'session_key': session_key,
                        'meeting_key': weather.get('meeting_key'),
                        'date': date_w,
                        'time': time_w,
                        'air_temperature': weather.get('air_temperature'),
                        'track_temperature': weather.get('track_temperature'),
                        'humidity': weather.get('humidity'),
                        'pressure': weather.get('pressure'),
                        'rainfall': weather.get('rainfall'),
                        'wind_direction': weather.get('wind_direction'),
                        'wind_speed': weather.get('wind_speed')
                    }
                    all_weather.append(weather_record)
                
                print(f"Session {session_key}: Pobrano {len(data)} rekordów pogody")
            else:
                print(f"Session {session_key}: Brak danych o pogodzie")
        else:
            print(f"Error fetching weather data for session {session_key}: {response.status_code}")
        
        sleep(0.5)
    
    return pd.DataFrame(all_weather)

# %%
weather_session_df = get_weather_data(sessions_key_unique)
weather_session_df.head()
# Out:
# Session 9222: Pobrano 590 rekordów pogody
# Session 7763: Pobrano 590 rekordów pogody
# Session 7764: Pobrano 581 rekordów pogody
# Session 7765: Pobrano 84 rekordów pogody
# Session 7766: Pobrano 85 rekordów pogody
# Session 7767: Pobrano 86 rekordów pogody
# Session 7768: Pobrano 95 rekordów pogody
# Session 7953: Pobrano 161 rekordów pogody
# Session 7772: Pobrano 82 rekordów pogody
# Session 7773: Pobrano 83 rekordów pogody
# Session 7774: Pobrano 82 rekordów pogody
# Session 7775: Pobrano 80 rekordów pogody
# Session 7779: Pobrano 148 rekordów pogody
# Session 7780: Pobrano 62 rekordów pogody
# Session 7781: Pobrano 82 rekordów pogody
# Session 7782: Pobrano 84 rekordów pogody
# Session 7783: Pobrano 95 rekordów pogody
# Session 7787: Pobrano 222 rekordów pogody
# Session 9063: Pobrano 83 rekordów pogody
# Session 9064: Pobrano 106 rekordów pogody
# Session 9278: Pobrano 68 rekordów pogody
# Session 9069: Pobrano 82 rekordów pogody
# Session 9070: Pobrano 160 rekordów pogody
# Session 9071: Pobrano 81 rekordów pogody
# Session 9072: Pobrano 82 rekordów pogody
# Session 9073: Pobrano 82 rekordów pogody
# Session 9074: Pobrano 87 rekordów pogody
# Session 9078: Pobrano 155 rekordów pogody
# Session 9087: Pobrano 73 rekordów pogody
# Session 9088: Pobrano 81 rekordów pogody
# Session 9089: Pobrano 72 rekordów pogody
# Session 9090: Pobrano 86 rekordów pogody
# Session 9094: Pobrano 176 rekordów pogody
# Session 9095: Pobrano 82 rekordów pogody
# Session 9096: Pobrano 82 rekordów pogody
# Session 9097: Pobrano 82 rekordów pogody
# Session 9098: Pobrano 88 rekordów pogody
# Session 9102: Pobrano 154 rekordów pogody
# Session 9103: Pobrano 65 rekordów pogody
# Session 9104: Pobrano 107 rekordów pogody
# Session 9105: Pobrano 75 rekordów pogody
# Session 9106: Pobrano 89 rekordów pogody
# Session 9110: Pobrano 162 rekordów pogody
# Session 9111: Pobrano 84 rekordów pogody
# Session 9112: Pobrano 85 rekordów pogody
# Session 9282: Pobrano 62 rekordów pogody
# Session 9117: Pobrano 97 rekordów pogody
# Session 9118: Pobrano 153 rekordów pogody
# Session 9119: Pobrano 81 rekordów pogody
# Session 9120: Pobrano 80 rekordów pogody
# Session 9121: Pobrano 82 rekordów pogody
# Session 9122: Pobrano 94 rekordów pogody
# Session 9126: Pobrano 151 rekordów pogody
# Session 9223: Pobrano 148 rekordów pogody
# Session 9127: Pobrano 82 rekordów pogody
# Session 9128: Pobrano 82 rekordów pogody
# Session 9129: Pobrano 78 rekordów pogody
# Session 9133: Pobrano 164 rekordów pogody
# Session 9134: Pobrano 88 rekordów pogody
# Session 9135: Pobrano 95 rekordów pogody
# Session 9286: Pobrano 103 rekordów pogody
# Session 9140: Pobrano 120 rekordów pogody
# Session 9141: Pobrano 150 rekordów pogody
# Session 9142: Pobrano 81 rekordów pogody
# Session 9143: Pobrano 81 rekordów pogody
# Session 9144: Pobrano 82 rekordów pogody
# Session 9145: Pobrano 100 rekordów pogody
# Session 9149: Pobrano 209 rekordów pogody
# Session 9150: Pobrano 83 rekordów pogody
# Session 9151: Pobrano 82 rekordów pogody
# Session 9152: Pobrano 81 rekordów pogody
# Session 9153: Pobrano 79 rekordów pogody
# Session 9157: Pobrano 156 rekordów pogody
# Session 9158: Pobrano 82 rekordów pogody
# Session 9159: Pobrano 83 rekordów pogody
# Session 9160: Pobrano 82 rekordów pogody
# Session 9161: Pobrano 110 rekordów pogody
# Session 9165: Pobrano 176 rekordów pogody
# Session 9166: Pobrano 83 rekordów pogody
# Session 9167: Pobrano 76 rekordów pogody
# Session 9168: Pobrano 82 rekordów pogody
# Session 9169: Pobrano 92 rekordów pogody
# Session 9173: Pobrano 158 rekordów pogody
# Session 9214: Pobrano 82 rekordów pogody
# Session 9215: Pobrano 83 rekordów pogody
# Session 9298: Pobrano 44 rekordów pogody
# Session 9220: Pobrano 104 rekordów pogody
# Session 9221: Pobrano 159 rekordów pogody
# Session 9206: Pobrano 82 rekordów pogody
# Session 9207: Pobrano 79 rekordów pogody
# Session 9294: Pobrano 62 rekordów pogody
# Session 9212: Pobrano 94 rekordów pogody
# Session 9213: Pobrano 168 rekordów pogody
# Session 9174: Pobrano 81 rekordów pogody
# Session 9175: Pobrano 81 rekordów pogody
# Session 9176: Pobrano 81 rekordów pogody
# Session 9177: Pobrano 78 rekordów pogody
# Session 9181: Pobrano 190 rekordów pogody
# Session 9198: Pobrano 80 rekordów pogody
# Session 9304: Pobrano 86 rekordów pogody
# Session 9308: Pobrano 86 rekordów pogody
# Session 9204: Pobrano 90 rekordów pogody
# Session 9205: Pobrano 183 rekordów pogody
# Session 9182: Pobrano 36 rekordów pogody
# Session 9183: Pobrano 143 rekordów pogody
# Session 9184: Pobrano 73 rekordów pogody
# Session 9314: Pobrano 79 rekordów pogody
# Session 9189: Pobrano 108 rekordów pogody
# Session 9190: Pobrano 81 rekordów pogody
# Session 9191: Pobrano 81 rekordów pogody
# Session 9192: Pobrano 82 rekordów pogody
# Session 9193: Pobrano 78 rekordów pogody
# Session 9197: Pobrano 156 rekordów pogody
# Session 9462: Pobrano 279 rekordów pogody
# Session 9463: Pobrano 560 rekordów pogody
# Session 9464: Pobrano 552 rekordów pogody
# Session 9465: Pobrano 82 rekordów pogody
# Session 9466: Pobrano 82 rekordów pogody
# Session 9467: Pobrano 82 rekordów pogody
# Session 9468: Pobrano 77 rekordów pogody
# Session 9472: Pobrano 157 rekordów pogody
# Session 9473: Pobrano 80 rekordów pogody
# Session 9474: Pobrano 93 rekordów pogody
# Session 9475: Pobrano 82 rekordów pogody
# Session 9476: Pobrano 94 rekordów pogody
# Session 9480: Pobrano 146 rekordów pogody
# Session 9481: Pobrano 81 rekordów pogody
# Session 9482: Pobrano 82 rekordów pogody
# Session 9483: Pobrano 81 rekordów pogody
# Session 9484: Pobrano 78 rekordów pogody
# Session 9488: Pobrano 144 rekordów pogody
# Session 9489: Pobrano 80 rekordów pogody
# Session 9490: Pobrano 86 rekordów pogody
# Session 9491: Pobrano 79 rekordów pogody
# Session 9492: Pobrano 76 rekordów pogody
# Session 9496: Pobrano 181 rekordów pogody
# Session 9663: Pobrano 82 rekordów pogody
# Session 9668: Pobrano 70 rekordów pogody
# Session 9672: Pobrano 80 rekordów pogody
# Session 9664: Pobrano 86 rekordów pogody
# Session 9673: Pobrano 165 rekordów pogody
# Session 9497: Pobrano 77 rekordów pogody
# Session 9502: Pobrano 63 rekordów pogody
# Session 9506: Pobrano 82 rekordów pogody
# Session 9498: Pobrano 77 rekordów pogody
# Session 9507: Pobrano 150 rekordów pogody
# Session 9508: Pobrano 79 rekordów pogody
# Session 9509: Pobrano 78 rekordów pogody
# Session 9510: Pobrano 78 rekordów pogody
# Session 9511: Pobrano 75 rekordów pogody
# Session 9515: Pobrano 143 rekordów pogody
# Session 9516: Pobrano 77 rekordów pogody
# Session 9517: Pobrano 81 rekordów pogody
# Session 9518: Pobrano 79 rekordów pogody
# Session 9519: Pobrano 76 rekordów pogody
# Session 9523: Pobrano 200 rekordów pogody
# Session 9524: Pobrano 78 rekordów pogody
# Session 9525: Pobrano 80 rekordów pogody
# Session 9526: Pobrano 81 rekordów pogody
# Session 9527: Pobrano 78 rekordów pogody
# Session 9531: Pobrano 113 rekordów pogody
# Session 9532: Pobrano 81 rekordów pogody
# Session 9533: Pobrano 81 rekordów pogody
# Session 9534: Pobrano 80 rekordów pogody
# Session 9535: Pobrano 76 rekordów pogody
# Session 9539: Pobrano 154 rekordów pogody
# Session 9540: Pobrano 79 rekordów pogody
# Session 9545: Pobrano 58 rekordów pogody
# Session 9549: Pobrano 78 rekordów pogody
# Session 9541: Pobrano 76 rekordów pogody
# Session 9550: Pobrano 143 rekordów pogody
# Session 9551: Pobrano 81 rekordów pogody
# Session 9552: Pobrano 81 rekordów pogody
# Session 9553: Pobrano 82 rekordów pogody
# Session 9554: Pobrano 85 rekordów pogody
# Session 9558: Pobrano 147 rekordów pogody
# Session 9559: Pobrano 82 rekordów pogody
# Session 9560: Pobrano 81 rekordów pogody
# Session 9561: Pobrano 80 rekordów pogody
# Session 9562: Pobrano 105 rekordów pogody
# Session 9566: Pobrano 155 rekordów pogody
# Session 9567: Pobrano 83 rekordów pogody
# Session 9568: Pobrano 82 rekordów pogody
# Session 9569: Pobrano 82 rekordów pogody
# Session 9570: Pobrano 79 rekordów pogody
# Session 9574: Pobrano 137 rekordów pogody
# Session 9575: Pobrano 81 rekordów pogody
# Session 9576: Pobrano 79 rekordów pogody
# Session 9577: Pobrano 79 rekordów pogody
# Session 9578: Pobrano 79 rekordów pogody
# Session 9582: Pobrano 153 rekordów pogody
# Session 9583: Pobrano 81 rekordów pogody
# Session 9584: Pobrano 79 rekordów pogody
# Session 9585: Pobrano 81 rekordów pogody
# Session 9586: Pobrano 79 rekordów pogody
# Session 9590: Pobrano 133 rekordów pogody
# Session 9591: Pobrano 92 rekordów pogody
# Session 9592: Pobrano 82 rekordów pogody
# Session 9593: Pobrano 82 rekordów pogody
# Session 9594: Pobrano 78 rekordów pogody
# Session 9598: Pobrano 152 rekordów pogody
# Session 9599: Pobrano 80 rekordów pogody
# Session 9600: Pobrano 82 rekordów pogody
# Session 9601: Pobrano 82 rekordów pogody
# Session 9602: Pobrano 93 rekordów pogody
# Session 9606: Pobrano 160 rekordów pogody
# Session 9607: Pobrano 81 rekordów pogody
# Session 9612: Pobrano 63 rekordów pogody
# Session 9616: Pobrano 81 rekordów pogody
# Session 9608: Pobrano 75 rekordów pogody
# Session 9617: Pobrano 155 rekordów pogody
# Session 9618: Pobrano 79 rekordów pogody
# Session 9619: Pobrano 109 rekordów pogody
# Session 9620: Pobrano 83 rekordów pogody
# Session 9621: Pobrano 81 rekordów pogody
# Session 9625: Pobrano 159 rekordów pogody
# Session 9626: Pobrano 82 rekordów pogody
# Session 9631: Pobrano 62 rekordów pogody
# Session 9635: Pobrano 76 rekordów pogody
# Session 9627: Pobrano 107 rekordów pogody
# Session 9636: Pobrano 201 rekordów pogody
# Session 9637: Pobrano 83 rekordów pogody
# Session 9638: Pobrano 116 rekordów pogody
# Session 9639: Pobrano 82 rekordów pogody
# Session 9640: Pobrano 98 rekordów pogody
# Session 9644: Pobrano 143 rekordów pogody
# Session 9645: Pobrano 81 rekordów pogody
# Session 9650: Pobrano 59 rekordów pogody
# Session 9654: Pobrano 74 rekordów pogody
# Session 9646: Pobrano 78 rekordów pogody
# Session 9655: Pobrano 151 rekordów pogody
# Session 9461: Pobrano 82 rekordów pogody
# Session 9656: Pobrano 79 rekordów pogody
# Session 9657: Pobrano 81 rekordów pogody
# Session 9658: Pobrano 81 rekordów pogody
# Session 9662: Pobrano 148 rekordów pogody
# Session 9683: Pobrano 622 rekordów pogody
# Session 9684: Pobrano 563 rekordów pogody
# Session 9685: Pobrano 554 rekordów pogody
# Session 9686: Pobrano 81 rekordów pogody
# Session 9687: Pobrano 81 rekordów pogody
# Session 9688: Pobrano 78 rekordów pogody
# Session 9689: Pobrano 75 rekordów pogody
# Session 9693: Pobrano 178 rekordów pogody
# Session 9988: Pobrano 82 rekordów pogody
# Session 9989: Pobrano 60 rekordów pogody
# Session 9993: Pobrano 84 rekordów pogody
# Session 9994: Pobrano 77 rekordów pogody
# Session 9998: Pobrano 154 rekordów pogody
# Session 9999: Pobrano 81 rekordów pogody
# Session 10000: Pobrano 75 rekordów pogody
# Session 10001: Pobrano 75 rekordów pogody
# Session 10002: Pobrano 85 rekordów pogody
# Session 10006: Pobrano 140 rekordów pogody
# Session 10007: Pobrano 80 rekordów pogody
# Session 10008: Pobrano 79 rekordów pogody
# Session 10009: Pobrano 80 rekordów pogody
# Session 10010: Pobrano 87 rekordów pogody
# Session 10014: Pobrano 158 rekordów pogody
# Session 10015: Pobrano 80 rekordów pogody
# Session 10016: Pobrano 81 rekordów pogody
# Session 10017: Pobrano 81 rekordów pogody
# Session 10018: Pobrano 86 rekordów pogody
# Session 10022: Pobrano 142 rekordów pogody
# Session 10023: Pobrano 78 rekordów pogody
# Session 10024: Pobrano 67 rekordów pogody
# Session 10028: Pobrano 114 rekordów pogody
# Session 10029: Pobrano 78 rekordów pogody
# Session 10033: Pobrano 149 rekordów pogody
# Session 9980: Pobrano 76 rekordów pogody
# Session 9981: Pobrano 81 rekordów pogody
# Session 9982: Pobrano 78 rekordów pogody
# Session 9983: Pobrano 110 rekordów pogody
# Session 9987: Pobrano 150 rekordów pogody
# Session 9972: Pobrano 82 rekordów pogody
# Session 9973: Pobrano 80 rekordów pogody
# Session 9974: Pobrano 73 rekordów pogody
# Session 9975: Pobrano 93 rekordów pogody
# Session 9979: Pobrano 160 rekordów pogody
# Session 9964: Pobrano 80 rekordów pogody
# Session 9965: Pobrano 82 rekordów pogody
# Session 9966: Pobrano 44 rekordów pogody
# Session 9967: Pobrano 77 rekordów pogody
# Session 9971: Pobrano 155 rekordów pogody
# Session 9956: Pobrano 80 rekordów pogody
# Session 9957: Pobrano 80 rekordów pogody
# Session 9958: Pobrano 80 rekordów pogody
# Session 9959: Pobrano 85 rekordów pogody
# Session 9963: Pobrano 167 rekordów pogody
# Session 9948: Pobrano 80 rekordów pogody
# Session 9949: Pobrano 79 rekordów pogody
# Session 9950: Pobrano 79 rekordów pogody
# Session 9951: Pobrano 88 rekordów pogody
# Session 9955: Pobrano 161 rekordów pogody
# Session 9940: Pobrano 81 rekordów pogody
# Session 9941: Pobrano 81 rekordów pogody
# Session 9942: Pobrano 82 rekordów pogody
# Session 9943: Pobrano 87 rekordów pogody
# Session 9947: Pobrano 155 rekordów pogody
# Session 9929: Pobrano 81 rekordów pogody
# Session 9930: Pobrano 76 rekordów pogody
# Session 9934: Pobrano 80 rekordów pogody
# Session 9935: Pobrano 79 rekordów pogody
# Session 9939: Pobrano 223 rekordów pogody
# Session 9921: Pobrano 109 rekordów pogody
# Session 9922: Pobrano 81 rekordów pogody
# Session 9923: Pobrano 71 rekordów pogody
# Session 9924: Pobrano 84 rekordów pogody
# Session 9928: Pobrano 136 rekordów pogody
# Session 9913: Pobrano 82 rekordów pogody
# Session 9914: Pobrano 81 rekordów pogody
# Session 9915: Pobrano 82 rekordów pogody
# Session 9916: Pobrano 78 rekordów pogody
# Session 9920: Pobrano 159 rekordów pogody
# Session 9905: Pobrano 116 rekordów pogody
# Session 9906: Pobrano 81 rekordów pogody
# Session 9907: Pobrano 81 rekordów pogody
# Session 9908: Pobrano 78 rekordów pogody
# Session 9912: Pobrano 144 rekordów pogody
# Session 9897: Pobrano 84 rekordów pogody
# Session 9898: Pobrano 83 rekordów pogody
# Session 9899: Pobrano 83 rekordów pogody
# Session 9900: Pobrano 135 rekordów pogody
#    session_key  meeting_key        date             time  air_temperature  \
# 0         9222         1140  2023-02-23  06:54:55.756000             23.8
# 1         9222         1140  2023-02-23  06:55:55.755000             23.8
# 2         9222         1140  2023-02-23  06:56:55.754000             23.8
# 3         9222         1140  2023-02-23  06:57:55.754000             23.8
# 4         9222         1140  2023-02-23  06:58:55.753000             23.8
#
#    track_temperature  humidity  pressure  rainfall  wind_direction  wind_speed
# 0               29.7      26.0    1012.2         0             193         4.9
# 1               29.7      26.0    1012.2         0             193         4.9
# 2               30.0      27.0    1012.2         0             193         4.3
# 3               30.1      27.0    1012.2         0             186         5.5
# 4               30.1      27.0    1012.2         0             182         4.4

# %%
# grupowanie danych pogodowych według sesji i obliczenie statystyk

def summarize_weather(group):
    return pd.Series({
        'air_temp_mean': group['air_temperature'].mean(),
        'air_temp_min': group['air_temperature'].min(),
        'air_temp_max': group['air_temperature'].max(),
        'track_temp_mean': group['track_temperature'].mean(),
        'humidity_mean': group['humidity'].mean(),
        'rainfall_total': group['rainfall'].sum(),
        'rainfall_max': group['rainfall'].max(),
        'wind_speed_mean': group['wind_speed'].mean(),
        'pressure_mean': group['pressure'].mean(),
        'weather_measurements': len(group)
    })

# %%
gruouped_weather = weather_session_df.groupby('session_key')
gruouped_weather_summary = gruouped_weather.apply(summarize_weather).reset_index()

gruouped_weather_summary.head()
# Out:
# C:\Users\Sylwia\AppData\Local\Temp\ipykernel_4600\457088065.py:2: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   gruouped_weather_summary = gruouped_weather.apply(summarize_weather).reset_index()
#    session_key  air_temp_mean  air_temp_min  air_temp_max  track_temp_mean  \
# 0         7763      26.835254          22.9          31.5        36.444915
# 1         7764      26.641997          24.0          29.2        36.384682
# 2         7765      26.989286          26.3          27.6        40.482143
# 3         7766      22.872941          22.1          23.6        26.972941
# 4         7767      28.000000          27.6          28.5        40.570930
#
#    humidity_mean  rainfall_total  rainfall_max  wind_speed_mean  \
# 0      26.076271             0.0           0.0         2.091695
# 1      42.820998             0.0           0.0         1.154217
# 2      12.261905             0.0           0.0         2.579762
# 3      23.317647             0.0           0.0         1.082353
# 4      19.895349             0.0           0.0         1.777907
#
#    pressure_mean  weather_measurements
# 0    1009.909661                 590.0
# 1    1013.120654                 581.0
# 2    1017.314286                  84.0
# 3    1018.512941                  85.0
# 4    1017.043023                  86.0

# %%
# z sessions tylko sesje typu Race
all_race_df = all_sessions_df[all_sessions_df['session_type'] == 'Race']
all_race_df.head()
# Out:
#     meeting_key  year  session_key session_type session_name  date_start  \
# 7          1141  2023         7953         Race         Race  2023-03-05
# 12         1142  2023         7779         Race         Race  2023-03-19
# 17         1143  2023         7787         Race         Race  2023-04-02
# 21         1207  2023         9069         Race       Sprint  2023-04-29
# 22         1207  2023         9070         Race         Race  2023-04-30
#
#    time_start    date_end  time_end gmt_offset   location  country_name  \
# 7    15:00:00  2023-03-05  17:00:00   03:00:00     Sakhir       Bahrain
# 12   17:00:00  2023-03-19  19:00:00   03:00:00     Jeddah  Saudi Arabia
# 17   05:00:00  2023-04-02  07:00:00   10:00:00  Melbourne     Australia
# 21   13:30:00  2023-04-29  14:00:00   04:00:00       Baku    Azerbaijan
# 22   11:00:00  2023-04-30  13:00:00   04:00:00       Baku    Azerbaijan
#
#    country_code circuit_short_name
# 7           BRN             Sakhir
# 12          KSA             Jeddah
# 17          AUS          Melbourne
# 21          AZE               Baku
# 22          AZE               Baku

# %%
# z sessions tylko sesje typu Qualifying
all_qualifying_df = all_sessions_df[all_sessions_df['session_name'] == 'Qualifying']
all_qualifying_df.head()
# Out:
#     meeting_key  year  session_key session_type session_name  date_start  \
# 6          1141  2023         7768   Qualifying   Qualifying  2023-03-04
# 11         1142  2023         7775   Qualifying   Qualifying  2023-03-18
# 16         1143  2023         7783   Qualifying   Qualifying  2023-04-01
# 19         1207  2023         9064   Qualifying   Qualifying  2023-04-28
# 26         1208  2023         9074   Qualifying   Qualifying  2023-05-06
#
#    time_start    date_end  time_end gmt_offset   location   country_name  \
# 6    15:00:00  2023-03-04  16:00:00   03:00:00     Sakhir        Bahrain
# 11   17:00:00  2023-03-18  18:00:00   03:00:00     Jeddah   Saudi Arabia
# 16   05:00:00  2023-04-01  06:00:00   11:00:00  Melbourne      Australia
# 19   13:00:00  2023-04-28  14:00:00   04:00:00       Baku     Azerbaijan
# 26   20:00:00  2023-05-06  21:00:00  -04:00:00      Miami  United States
#
#    country_code circuit_short_name
# 6           BRN             Sakhir
# 11          KSA             Jeddah
# 16          AUS          Melbourne
# 19          AZE               Baku
# 26          USA              Miami

# %%
# polaczenie wyscigow i kierowcow
df_driver = drivers_df
df_gp = all_meetings_df
df_races = all_race_df

races_session_keys = df_races[['session_key']].drop_duplicates()
df_driver_race = df_driver.merge(races_session_keys, on='session_key', how='inner')

print(df_driver_race['session_key'].unique())
print(df_races['session_key'].unique())

# polaczenie driver z race
df_merged = df_driver_race.merge(df_races, on=['meeting_key', 'session_key'], how='left')
df_merged.head()
# Out:
# [ 7953  7779  7787  9069  9070  9078  9094  9102  9110  9117  9118  9126
#   9133  9140  9141  9149  9157  9165  9173  9220  9221  9212  9213  9181
#   9204  9205  9189  9197  9472  9480  9488  9496  9672  9673  9506  9507
#   9515  9523  9531  9539  9549  9550  9558  9566  9574  9582  9590  9598
#   9606  9616  9617  9625  9635  9636  9644  9654  9655  9662  9693  9993
#   9998 10006 10014 10022 10028 10033  9987  9979  9971  9963  9955  9947
#   9934  9939  9928  9920  9912]
# [ 7953  7779  7787  9069  9070  9078  9094  9102  9110  9117  9118  9126
#   9133  9140  9141  9149  9157  9165  9173  9220  9221  9212  9213  9181
#   9204  9205  9189  9197  9472  9480  9488  9496  9672  9673  9506  9507
#   9515  9523  9531  9539  9549  9550  9558  9566  9574  9582  9590  9598
#   9606  9616  9617  9625  9635  9636  9644  9654  9655  9662  9693  9993
#   9998 10006 10014 10022 10028 10033  9987  9979  9971  9963  9955  9947
#   9934  9939  9928  9920  9912]
#    driver_number broadcast_name       full_name first_name   last_name  \
# 0              1   M VERSTAPPEN  Max VERSTAPPEN        Max  Verstappen
# 1              2     L SARGEANT  Logan SARGEANT      Logan    Sargeant
# 2              4       L NORRIS    Lando NORRIS      Lando      Norris
# 3             10        P GASLY    Pierre GASLY     Pierre       Gasly
# 4             11        S PEREZ    Sergio PEREZ     Sergio       Perez
#
#   name_acronym country_code_x        team_name  meeting_key  session_key  ...  \
# 0          VER            NED  Red Bull Racing         1141         7953  ...
# 1          SAR            USA         Williams         1141         7953  ...
# 2          NOR            GBR          McLaren         1141         7953  ...
# 3          GAS            FRA           Alpine         1141         7953  ...
# 4          PER            MEX  Red Bull Racing         1141         7953  ...
#
#    session_name  date_start time_start    date_end  time_end gmt_offset  \
# 0          Race  2023-03-05   15:00:00  2023-03-05  17:00:00   03:00:00
# 1          Race  2023-03-05   15:00:00  2023-03-05  17:00:00   03:00:00
# 2          Race  2023-03-05   15:00:00  2023-03-05  17:00:00   03:00:00
# 3          Race  2023-03-05   15:00:00  2023-03-05  17:00:00   03:00:00
# 4          Race  2023-03-05   15:00:00  2023-03-05  17:00:00   03:00:00
#
#   location country_name country_code_y circuit_short_name
# 0   Sakhir      Bahrain            BRN             Sakhir
# 1   Sakhir      Bahrain            BRN             Sakhir
# 2   Sakhir      Bahrain            BRN             Sakhir
# 3   Sakhir      Bahrain            BRN             Sakhir
# 4   Sakhir      Bahrain            BRN             Sakhir
#
# [5 rows x 22 columns]

# %%
results_qualifying = get_final_session_results(all_qualifying_df['session_key'].unique(), include_driver_details=True)
results_qualifying.head()
# Out:
# Session 7768: Pobrano 20 końcowych pozycji
# Session 7775: Pobrano 20 końcowych pozycji
# Session 7783: Pobrano 20 końcowych pozycji
# Session 9064: Pobrano 20 końcowych pozycji
# Session 9074: Pobrano 20 końcowych pozycji
# Session 9090: Pobrano 20 końcowych pozycji
# Session 9098: Pobrano 20 końcowych pozycji
# Session 9106: Pobrano 20 końcowych pozycji
# Session 9112: Pobrano 20 końcowych pozycji
# Session 9122: Pobrano 20 końcowych pozycji
# Session 9129: Pobrano 20 końcowych pozycji
# Session 9135: Pobrano 20 końcowych pozycji
# Session 9145: Pobrano 20 końcowych pozycji
# Session 9153: Pobrano 20 końcowych pozycji
# Session 9161: Pobrano 20 końcowych pozycji
# Session 9169: Pobrano 20 końcowych pozycji
# Session 9215: Pobrano 20 końcowych pozycji
# Session 9207: Pobrano 20 końcowych pozycji
# Session 9177: Pobrano 20 końcowych pozycji
# Session 9304: Pobrano 20 końcowych pozycji
# Session 9314: Pobrano 20 końcowych pozycji
# Session 9193: Pobrano 20 końcowych pozycji
# Session 9468: Pobrano 20 końcowych pozycji
# Session 9476: Pobrano 20 końcowych pozycji
# Session 9484: Pobrano 19 końcowych pozycji
# Session 9492: Pobrano 20 końcowych pozycji
# Session 9664: Pobrano 20 końcowych pozycji
# Session 9498: Pobrano 20 końcowych pozycji
# Session 9511: Pobrano 20 końcowych pozycji
# Session 9519: Pobrano 20 końcowych pozycji
# Session 9527: Pobrano 20 końcowych pozycji
# Session 9535: Pobrano 20 końcowych pozycji
# Session 9541: Pobrano 20 końcowych pozycji
# Session 9554: Pobrano 20 końcowych pozycji
# Session 9562: Pobrano 20 końcowych pozycji
# Session 9570: Pobrano 20 końcowych pozycji
# Session 9578: Pobrano 20 końcowych pozycji
# Session 9586: Pobrano 20 końcowych pozycji
# Session 9594: Pobrano 20 końcowych pozycji
# Session 9602: Pobrano 20 końcowych pozycji
# Session 9608: Pobrano 20 końcowych pozycji
# Session 9621: Pobrano 20 końcowych pozycji
# Session 9627: Pobrano 20 końcowych pozycji
# Session 9640: Pobrano 20 końcowych pozycji
# Session 9646: Pobrano 20 końcowych pozycji
# Session 9658: Pobrano 20 końcowych pozycji
# Session 9689: Pobrano 20 końcowych pozycji
# Session 9994: Pobrano 20 końcowych pozycji
# Session 10002: Pobrano 20 końcowych pozycji
# Session 10010: Pobrano 20 końcowych pozycji
# Session 10018: Pobrano 20 końcowych pozycji
# Session 10029: Pobrano 20 końcowych pozycji
# Session 9983: Pobrano 20 końcowych pozycji
# Session 9975: Pobrano 20 końcowych pozycji
# Session 9967: Pobrano 20 końcowych pozycji
# Session 9959: Pobrano 20 końcowych pozycji
# Session 9951: Pobrano 20 końcowych pozycji
# Session 9943: Pobrano 20 końcowych pozycji
# Session 9935: Pobrano 20 końcowych pozycji
# Session 9924: Pobrano 20 końcowych pozycji
# Session 9916: Pobrano 20 końcowych pozycji
# Session 9908: Pobrano 20 końcowych pozycji
# Session 9900: Pobrano 20 końcowych pozycji
#    session_key  driver_number  position        date             time  \
# 0         7768             14         5  2023-03-04  16:09:11.002000
# 1         7768              1         1  2023-03-04  16:09:11.002000
# 2         7768             11         2  2023-03-04  16:09:11.002000
# 3         7768             44         7  2023-03-04  16:09:11.002000
# 4         7768             16         3  2023-03-04  16:09:11.002000
#
#    meeting_key session_name  year location country_name circuit_short_name  \
# 0         1141   Qualifying  2023   Sakhir      Bahrain             Sakhir
# 1         1141   Qualifying  2023   Sakhir      Bahrain             Sakhir
# 2         1141   Qualifying  2023   Sakhir      Bahrain             Sakhir
# 3         1141   Qualifying  2023   Sakhir      Bahrain             Sakhir
# 4         1141   Qualifying  2023   Sakhir      Bahrain             Sakhir
#
#   broadcast_name        full_name        team_name
# 0       F ALONSO  Fernando ALONSO     Aston Martin
# 1   M VERSTAPPEN   Max VERSTAPPEN  Red Bull Racing
# 2        S PEREZ     Sergio PEREZ  Red Bull Racing
# 3     L HAMILTON   Lewis HAMILTON         Mercedes
# 4      C LECLERC  Charles LECLERC          Ferrari

# %%
# dodanie do df_merged wyników kwalifikacji z zachowaniem wszytskich kolumn df_merged a dodanie tylko quali_position
df_final = []

df_final = df_merged.merge(
    results_qualifying[['meeting_key', 'driver_number', 'position']],
    on=['meeting_key', 'driver_number'],
    how='left'
).rename(columns={'position': 'qualifying_position'})

df_final.head()
# Out:
#    driver_number broadcast_name       full_name first_name   last_name  \
# 0              1   M VERSTAPPEN  Max VERSTAPPEN        Max  Verstappen
# 1              2     L SARGEANT  Logan SARGEANT      Logan    Sargeant
# 2              4       L NORRIS    Lando NORRIS      Lando      Norris
# 3             10        P GASLY    Pierre GASLY     Pierre       Gasly
# 4             11        S PEREZ    Sergio PEREZ     Sergio       Perez
#
#   name_acronym country_code_x        team_name  meeting_key  session_key  ...  \
# 0          VER            NED  Red Bull Racing         1141         7953  ...
# 1          SAR            USA         Williams         1141         7953  ...
# 2          NOR            GBR          McLaren         1141         7953  ...
# 3          GAS            FRA           Alpine         1141         7953  ...
# 4          PER            MEX  Red Bull Racing         1141         7953  ...
#
#    date_start time_start    date_end  time_end gmt_offset location  \
# 0  2023-03-05   15:00:00  2023-03-05  17:00:00   03:00:00   Sakhir
# 1  2023-03-05   15:00:00  2023-03-05  17:00:00   03:00:00   Sakhir
# 2  2023-03-05   15:00:00  2023-03-05  17:00:00   03:00:00   Sakhir
# 3  2023-03-05   15:00:00  2023-03-05  17:00:00   03:00:00   Sakhir
# 4  2023-03-05   15:00:00  2023-03-05  17:00:00   03:00:00   Sakhir
#
#   country_name country_code_y circuit_short_name qualifying_position
# 0      Bahrain            BRN             Sakhir                   1
# 1      Bahrain            BRN             Sakhir                  16
# 2      Bahrain            BRN             Sakhir                  11
# 3      Bahrain            BRN             Sakhir                  20
# 4      Bahrain            BRN             Sakhir                   2
#
# [5 rows x 23 columns]

# %%
# dodanie do df_final wyników wyścigu z zachowaniem wszytskich kolumn df_final
df_race_results = results_df[results_df['session_name'] == 'Race']
df_race_results.head()
# Out:
#      session_key  driver_number  position        date             time  \
# 133         7953              1         1  2023-03-05  16:34:46.464000
# 134         7953             11         2  2023-03-05  16:34:46.464000
# 135         7953             16        19  2023-03-05  16:34:46.464000
# 136         7953             55         4  2023-03-05  16:34:46.464000
# 137         7953             14         3  2023-03-05  16:34:46.464000
#
#      meeting_key session_name  year location country_name circuit_short_name  \
# 133         1141         Race  2023   Sakhir      Bahrain             Sakhir
# 134         1141         Race  2023   Sakhir      Bahrain             Sakhir
# 135         1141         Race  2023   Sakhir      Bahrain             Sakhir
# 136         1141         Race  2023   Sakhir      Bahrain             Sakhir
# 137         1141         Race  2023   Sakhir      Bahrain             Sakhir
#
#     broadcast_name        full_name        team_name
# 133   M VERSTAPPEN   Max VERSTAPPEN  Red Bull Racing
# 134        S PEREZ     Sergio PEREZ  Red Bull Racing
# 135      C LECLERC  Charles LECLERC          Ferrari
# 136        C SAINZ     Carlos SAINZ          Ferrari
# 137       F ALONSO  Fernando ALONSO     Aston Martin

# %%
# # doodanie do df_final pozycji startowych z zachowaniem wszytskich kolumn df_final a dod
print(df_final.shape)
df_starting_positions = starting_position_df[starting_position_df['session_name'] == 'Race']
df_starting_positions.head()
# Out:
# (1536, 23)
#      session_key  driver_number  position        date             time  \
# 133         7953              1         1  2023-03-05  14:01:06.787000
# 134         7953             11         2  2023-03-05  14:01:06.787000
# 135         7953             16         3  2023-03-05  14:01:06.787000
# 136         7953             55         4  2023-03-05  14:01:06.787000
# 137         7953             14         5  2023-03-05  14:01:06.787000
#
#      meeting_key session_name  year location country_name broadcast_name  \
# 133         1141         Race  2023   Sakhir      Bahrain   M VERSTAPPEN
# 134         1141         Race  2023   Sakhir      Bahrain        S PEREZ
# 135         1141         Race  2023   Sakhir      Bahrain      C LECLERC
# 136         1141         Race  2023   Sakhir      Bahrain        C SAINZ
# 137         1141         Race  2023   Sakhir      Bahrain       F ALONSO
#
#            full_name        team_name
# 133   Max VERSTAPPEN  Red Bull Racing
# 134     Sergio PEREZ  Red Bull Racing
# 135  Charles LECLERC          Ferrari
# 136     Carlos SAINZ          Ferrari
# 137  Fernando ALONSO     Aston Martin

# %%
# Dodanie pozycji startowej z wyścigu i kwalifikacji do df_final
race_starting = starting_position_df[starting_position_df['session_name'] == 'Race'][['meeting_key', 'driver_number', 'position']].rename(columns={'position': 'starting_position'})
qualifying_starting = starting_position_df[starting_position_df['session_name'] == 'Qualifying'][['meeting_key', 'driver_number', 'position']].rename(columns={'position': 'qualifying_position'})
df_final = df_final.merge(race_starting, on=['meeting_key', 'driver_number'], how='left')
df_final = df_final.merge(qualifying_starting, on=['meeting_key', 'driver_number'], how='left')
df_final.head()
# Out:
#    driver_number broadcast_name       full_name first_name   last_name  \
# 0              1   M VERSTAPPEN  Max VERSTAPPEN        Max  Verstappen
# 1              2     L SARGEANT  Logan SARGEANT      Logan    Sargeant
# 2              4       L NORRIS    Lando NORRIS      Lando      Norris
# 3             10        P GASLY    Pierre GASLY     Pierre       Gasly
# 4             11        S PEREZ    Sergio PEREZ     Sergio       Perez
#
#   name_acronym country_code_x        team_name  meeting_key  session_key  ...  \
# 0          VER            NED  Red Bull Racing         1141         7953  ...
# 1          SAR            USA         Williams         1141         7953  ...
# 2          NOR            GBR          McLaren         1141         7953  ...
# 3          GAS            FRA           Alpine         1141         7953  ...
# 4          PER            MEX  Red Bull Racing         1141         7953  ...
#
#      date_end  time_end gmt_offset location country_name country_code_y  \
# 0  2023-03-05  17:00:00   03:00:00   Sakhir      Bahrain            BRN
# 1  2023-03-05  17:00:00   03:00:00   Sakhir      Bahrain            BRN
# 2  2023-03-05  17:00:00   03:00:00   Sakhir      Bahrain            BRN
# 3  2023-03-05  17:00:00   03:00:00   Sakhir      Bahrain            BRN
# 4  2023-03-05  17:00:00   03:00:00   Sakhir      Bahrain            BRN
#
#   circuit_short_name qualifying_position_x starting_position  \
# 0             Sakhir                     1                 1
# 1             Sakhir                    16                16
# 2             Sakhir                    11                11
# 3             Sakhir                    20                20
# 4             Sakhir                     2                 2
#
#   qualifying_position_y
# 0                     2
# 1                    18
# 2                    13
# 3                    10
# 4                     3
#
# [5 rows x 25 columns]

# %%
df_final.shape
# Out:
# (1536, 25)

# %%
def remove_duplicate_columns(df, column_name):
    cols = [col for col in df.columns if col == column_name]
    if len(cols) > 1:
        first = df.columns.get_loc(column_name)
        df = df.loc[:, ~df.columns.duplicated()]
    return df

# %%
# dodanie do df_final wyników wyścigu z zachowaniem wszytskich kolumn df_final a dodanie tylko final_position
df_final = df_final.merge(
    df_race_results[['meeting_key', 'driver_number', 'position']],
    on=['meeting_key', 'driver_number'],
    how='left'
).rename(columns={'position': 'final_position'})

df_final = remove_duplicate_columns(df_final, 'final_position')
df_final.head()
# Out:
#    driver_number broadcast_name       full_name first_name   last_name  \
# 0              1   M VERSTAPPEN  Max VERSTAPPEN        Max  Verstappen
# 1              2     L SARGEANT  Logan SARGEANT      Logan    Sargeant
# 2              4       L NORRIS    Lando NORRIS      Lando      Norris
# 3             10        P GASLY    Pierre GASLY     Pierre       Gasly
# 4             11        S PEREZ    Sergio PEREZ     Sergio       Perez
#
#   name_acronym country_code_x        team_name  meeting_key  session_key  ...  \
# 0          VER            NED  Red Bull Racing         1141         7953  ...
# 1          SAR            USA         Williams         1141         7953  ...
# 2          NOR            GBR          McLaren         1141         7953  ...
# 3          GAS            FRA           Alpine         1141         7953  ...
# 4          PER            MEX  Red Bull Racing         1141         7953  ...
#
#    time_end gmt_offset location country_name country_code_y  \
# 0  17:00:00   03:00:00   Sakhir      Bahrain            BRN
# 1  17:00:00   03:00:00   Sakhir      Bahrain            BRN
# 2  17:00:00   03:00:00   Sakhir      Bahrain            BRN
# 3  17:00:00   03:00:00   Sakhir      Bahrain            BRN
# 4  17:00:00   03:00:00   Sakhir      Bahrain            BRN
#
#   circuit_short_name qualifying_position_x starting_position  \
# 0             Sakhir                     1                 1
# 1             Sakhir                    16                16
# 2             Sakhir                    11                11
# 3             Sakhir                    20                20
# 4             Sakhir                     2                 2
#
#   qualifying_position_y final_position
# 0                     2              1
# 1                    18             12
# 2                    13             17
# 3                    10              9
# 4                     3              2
#
# [5 rows x 26 columns]

# %%
# policz zwyciestwa kazdego kierowcy do odbywajacego sie meeting, 
# tak aby policz tylko zwyciestwa przed rozpatrywanym meeting
# jako parametr funkcja przyjmuje tylko ramke ze wszytskimi wynikami sesji

def count_wins_before_meeting(race_results):
    race_sorted = race_results.sort_values('meeting_key').reset_index(drop=True).copy()
    
    wins_count = {}
    wins_before_list = []
    
    for idx, row in race_sorted.iterrows():
        driver = row['driver_number']
        meeting = row['meeting_key']
        
        # aktualna liczba zwycięstw przed tym meetingiem
        wins_before = wins_count.get(driver, 0)
        wins_before_list.append(wins_before)
        
        # jeśli kierowca wygrał ten wyścig, zwiększ liczbę zwycięstw
        if row['final_position'] == 1:
            wins_count[driver] = wins_before + 1
    
    race_sorted['wins_before'] = wins_before_list
    
    return race_sorted


test = count_wins_before_meeting(df_final)

#wyswitl tylko dla driver_number 1
print(test[test['driver_number'] == 1][['meeting_key', 'driver_number', 'final_position', 'wins_before']])
# Out:
#       meeting_key  driver_number  final_position  wins_before
# 0            1141              1               1            0
# 36           1142              1               2            1
# 51           1143              1               1            1
# 79           1207              1               2            2
# 81           1207              1               2            2
# ...           ...            ...             ...          ...
# 1454         1265              1               4           38
# 1465         1266              1               9           38
# 1477         1267              1               2           38
# 1511         1268              1               1           38
# 1516         1277              1               5           39
#
# [77 rows x 4 columns]

# %%
# merge z df_final
df_final = df_final.merge(
    test[['meeting_key', 'driver_number', 'wins_before']],
    on=['meeting_key', 'driver_number'],
    how='left'
)
df_final.head()
# Out:
#    driver_number broadcast_name       full_name first_name   last_name  \
# 0              1   M VERSTAPPEN  Max VERSTAPPEN        Max  Verstappen
# 1              2     L SARGEANT  Logan SARGEANT      Logan    Sargeant
# 2              4       L NORRIS    Lando NORRIS      Lando      Norris
# 3             10        P GASLY    Pierre GASLY     Pierre       Gasly
# 4             11        S PEREZ    Sergio PEREZ     Sergio       Perez
#
#   name_acronym country_code_x        team_name  meeting_key  session_key  ...  \
# 0          VER            NED  Red Bull Racing         1141         7953  ...
# 1          SAR            USA         Williams         1141         7953  ...
# 2          NOR            GBR          McLaren         1141         7953  ...
# 3          GAS            FRA           Alpine         1141         7953  ...
# 4          PER            MEX  Red Bull Racing         1141         7953  ...
#
#    gmt_offset location country_name country_code_y circuit_short_name  \
# 0    03:00:00   Sakhir      Bahrain            BRN             Sakhir
# 1    03:00:00   Sakhir      Bahrain            BRN             Sakhir
# 2    03:00:00   Sakhir      Bahrain            BRN             Sakhir
# 3    03:00:00   Sakhir      Bahrain            BRN             Sakhir
# 4    03:00:00   Sakhir      Bahrain            BRN             Sakhir
#
#   qualifying_position_x starting_position qualifying_position_y  \
# 0                     1                 1                     2
# 1                    16                16                    18
# 2                    11                11                    13
# 3                    20                20                    10
# 4                     2                 2                     3
#
#   final_position wins_before
# 0              1           0
# 1             12           0
# 2             17           0
# 3              9           0
# 4              2           0
#
# [5 rows x 27 columns]

# %%
# oblicz liczbe pit stopów dla każdego kierowcy w danym wyścigu i sredni czas trwania pit stopu

def calculate_pit_stops_stats(pit_stops_df):
    pit_stats = (
        pit_stops_df
        .groupby(['session_key', 'driver_number'])
        .agg(
            pit_stop_count=('pit_duration', 'count'),
            avg_pit_duration=('pit_duration', 'mean')
        )
        .reset_index()
    )
    
    return pit_stats

# %%
race_sessions_key_unique = df_final['session_key'].unique()
race_sessions_key_unique
# Out:
# array([ 7953,  7779,  7787,  9069,  9070,  9078,  9094,  9102,  9110,
#         9117,  9118,  9126,  9133,  9140,  9141,  9149,  9157,  9165,
#         9173,  9220,  9221,  9212,  9213,  9181,  9204,  9205,  9189,
#         9197,  9472,  9480,  9488,  9496,  9672,  9673,  9506,  9507,
#         9515,  9523,  9531,  9539,  9549,  9550,  9558,  9566,  9574,
#         9582,  9590,  9598,  9606,  9616,  9617,  9625,  9635,  9636,
#         9644,  9654,  9655,  9662,  9693,  9993,  9998, 10006, 10014,
#        10022, 10028, 10033,  9987,  9979,  9971,  9963,  9955,  9947,
#         9934,  9939,  9928,  9920,  9912])

# %%
df_race_pit_stops = pit_stops_df[pit_stops_df['session_key'].isin(race_sessions_key_unique)]

# %%
df_race_pit_stops_stats = calculate_pit_stops_stats(df_race_pit_stops)
df_race_pit_stops_stats.head()
# Out:
#    session_key  driver_number  pit_stop_count  avg_pit_duration
# 0         9102              1               2             22.25
# 1         9102              2               2             23.15
# 2         9102              4               3             27.50
# 3         9102             10               2             23.45
# 4         9102             11               2             21.60

# %%
# merge pit stop stats z df_final
df_final = df_final.merge(
    df_race_pit_stops_stats,
    on=['session_key', 'driver_number'],
    how='left'
).rename(columns={
    'pit_stop_count': 'pit_stops_count',
    'avg_pit_duration': 'avg_pit_stop_duration'
})

# sortowanie df_final po meeting_key i driver_number

# %%
df_final = df_final.sort_values(by=['session_key', 'driver_number']).reset_index(drop=True)
df_final.head()
# Out:
#    driver_number broadcast_name       full_name first_name   last_name  \
# 0              1   M VERSTAPPEN  Max VERSTAPPEN        Max  Verstappen
# 1              2     L SARGEANT  Logan SARGEANT      Logan    Sargeant
# 2              4       L NORRIS    Lando NORRIS      Lando      Norris
# 3             10        P GASLY    Pierre GASLY     Pierre       Gasly
# 4             11        S PEREZ    Sergio PEREZ     Sergio       Perez
#
#   name_acronym country_code_x        team_name  meeting_key  session_key  ...  \
# 0          VER            NED  Red Bull Racing         1142         7779  ...
# 1          SAR            USA         Williams         1142         7779  ...
# 2          NOR            GBR          McLaren         1142         7779  ...
# 3          GAS            FRA           Alpine         1142         7779  ...
# 4          PER            MEX  Red Bull Racing         1142         7779  ...
#
#    country_name country_code_y circuit_short_name qualifying_position_x  \
# 0  Saudi Arabia            KSA             Jeddah                    15
# 1  Saudi Arabia            KSA             Jeddah                    20
# 2  Saudi Arabia            KSA             Jeddah                    19
# 3  Saudi Arabia            KSA             Jeddah                    10
# 4  Saudi Arabia            KSA             Jeddah                     1
#
#   starting_position qualifying_position_y final_position wins_before  \
# 0                15                     1              2           1
# 1                20                    16             16           0
# 2                19                     7             17           0
# 3                 9                     9              9           0
# 4                 1                     2              1           0
#
#   pit_stops_count avg_pit_stop_duration
# 0             NaN                   NaN
# 1             NaN                   NaN
# 2             NaN                   NaN
# 3             NaN                   NaN
# 4             NaN                   NaN
#
# [5 rows x 29 columns]

# %%
# usunięcie zduplikowanych kolumn w df_final
df_final_clean = df_final.loc[:, ~df_final.columns.duplicated()]
print(df_final_clean[df_final_clean['pit_stops_count'] > 0][['meeting_key', 'session_key', 'driver_number', 'pit_stops_count', 'avg_pit_stop_duration']].head(10))
# Out:
#      meeting_key  session_key  driver_number  pit_stops_count  \
# 177         1211         9102              1              2.0
# 178         1211         9102              2              2.0
# 179         1211         9102              4              3.0
# 180         1211         9102             10              2.0
# 181         1211         9102             11              2.0
# 182         1211         9102             14              2.0
# 183         1211         9102             16              2.0
# 184         1211         9102             18              2.0
# 185         1211         9102             20              3.0
# 186         1211         9102             21              2.0
#
#      avg_pit_stop_duration
# 177              22.250000
# 178              23.150000
# 179              27.500000
# 180              23.450000
# 181              21.600000
# 182              22.650000
# 183              22.350000
# 184              22.800000
# 185              23.033333
# 186              22.200000

# %%
df_final.head()
df_copy = df_final.copy()

# zastap wszystkie wartosci NaN w kolumnach pit_stops_count i avg_pit_stop_duration zerami
df_copy['pit_stops_count'] = df_copy['pit_stops_count'].fillna(0).astype(int)
df_copy['avg_pit_stop_duration'] = df_copy['avg_pit_stop_duration'].fillna(0).astype(float)

# %%
starting_position_df.head()
# Out:
#    session_key  driver_number  position        date             time  \
# 0         9222              1         1  2023-02-23  06:54:49.318000
# 1         9222              2         2  2023-02-23  06:54:49.318000
# 2         9222              4         3  2023-02-23  06:54:49.318000
# 3         9222             10         4  2023-02-23  06:54:49.318000
# 4         9222             14         5  2023-02-23  06:54:49.318000
#
#    meeting_key session_name  year location country_name broadcast_name  \
# 0         1140   Practice 1  2023   Sakhir      Bahrain   M VERSTAPPEN
# 1         1140   Practice 1  2023   Sakhir      Bahrain     L SARGEANT
# 2         1140   Practice 1  2023   Sakhir      Bahrain       L NORRIS
# 3         1140   Practice 1  2023   Sakhir      Bahrain        P GASLY
# 4         1140   Practice 1  2023   Sakhir      Bahrain       F ALONSO
#
#          full_name        team_name
# 0   Max VERSTAPPEN  Red Bull Racing
# 1   Logan SARGEANT         Williams
# 2     Lando NORRIS          McLaren
# 3     Pierre GASLY           Alpine
# 4  Fernando ALONSO     Aston Martin

# %%
# save datasets to csv files
df_copy.to_csv('../../datasets/thesis_f1_race_data_all.csv', index=False)
df_sessions = all_sessions_df

df_copy.head()
# Out:
#    driver_number broadcast_name       full_name first_name   last_name  \
# 0              1   M VERSTAPPEN  Max VERSTAPPEN        Max  Verstappen
# 1              2     L SARGEANT  Logan SARGEANT      Logan    Sargeant
# 2              4       L NORRIS    Lando NORRIS      Lando      Norris
# 3             10        P GASLY    Pierre GASLY     Pierre       Gasly
# 4             11        S PEREZ    Sergio PEREZ     Sergio       Perez
#
#   name_acronym country_code_x        team_name  meeting_key  session_key  ...  \
# 0          VER            NED  Red Bull Racing         1142         7779  ...
# 1          SAR            USA         Williams         1142         7779  ...
# 2          NOR            GBR          McLaren         1142         7779  ...
# 3          GAS            FRA           Alpine         1142         7779  ...
# 4          PER            MEX  Red Bull Racing         1142         7779  ...
#
#    country_name country_code_y circuit_short_name qualifying_position_x  \
# 0  Saudi Arabia            KSA             Jeddah                    15
# 1  Saudi Arabia            KSA             Jeddah                    20
# 2  Saudi Arabia            KSA             Jeddah                    19
# 3  Saudi Arabia            KSA             Jeddah                    10
# 4  Saudi Arabia            KSA             Jeddah                     1
#
#   starting_position qualifying_position_y final_position wins_before  \
# 0                15                     1              2           1
# 1                20                    16             16           0
# 2                19                     7             17           0
# 3                 9                     9              9           0
# 4                 1                     2              1           0
#
#   pit_stops_count avg_pit_stop_duration
# 0               0                   0.0
# 1               0                   0.0
# 2               0                   0.0
# 3               0                   0.0
# 4               0                   0.0
#
# [5 rows x 29 columns]

# %%
def categorize_position(pos):
    if pos == 1:
        return 'winner'
    elif pos in [2, 3]:
        return 'top3'
    elif 4 <= pos <= 10:
        return 'points'
    else:
        return 'no_points'

# %%
# kolumna target
df_final['position_category'] = df_final['final_position'].apply(categorize_position)

# %%
df_final.head()
back = df_copy.copy()

# %%
df_copy['position_category'] = df_copy['final_position'].apply(categorize_position)

# %%
features_to_drop = [ 'full_name', 'first_name', 'last_name',
                    'name_acronym', 'team_name', 'meeting_key', 'session_key', 'location', 'country_name',
                    'country_code_y', 'circuit_short_name', 'final_position', 'position_category','session_type']

#mozna usunac session tyype... bo w modelku niczego to nie zmiana bo wszytskie taka maja 
#ale bedzie potrzeba ogolem

# %%
X = df_copy.drop(columns=features_to_drop)
y = df_copy['position_category']

data = X.copy()
data['position_category'] = y

data.head()
# Out:
#    driver_number broadcast_name country_code_x  year session_name  date_start  \
# 0              1   M VERSTAPPEN            NED  2023         Race  2023-03-19
# 1              2     L SARGEANT            USA  2023         Race  2023-03-19
# 2              4       L NORRIS            GBR  2023         Race  2023-03-19
# 3             10        P GASLY            FRA  2023         Race  2023-03-19
# 4             11        S PEREZ            MEX  2023         Race  2023-03-19
#
#   time_start    date_end  time_end gmt_offset  qualifying_position_x  \
# 0   17:00:00  2023-03-19  19:00:00   03:00:00                     15
# 1   17:00:00  2023-03-19  19:00:00   03:00:00                     20
# 2   17:00:00  2023-03-19  19:00:00   03:00:00                     19
# 3   17:00:00  2023-03-19  19:00:00   03:00:00                     10
# 4   17:00:00  2023-03-19  19:00:00   03:00:00                      1
#
#    starting_position  qualifying_position_y  wins_before  pit_stops_count  \
# 0                 15                      1            1                0
# 1                 20                     16            0                0
# 2                 19                      7            0                0
# 3                  9                      9            0                0
# 4                  1                      2            0                0
#
#    avg_pit_stop_duration position_category
# 0                    0.0              top3
# 1                    0.0         no_points
# 2                    0.0         no_points
# 3                    0.0            points
# 4                    0.0            winner

# %%
#usuwa quali_x i y 
data['qualifying_position'] = data['qualifying_position_y']
data = data.drop(columns=['qualifying_position_x', 'qualifying_position_y'])
data.head()
# Out:
#    driver_number broadcast_name country_code_x  year session_name  date_start  \
# 0              1   M VERSTAPPEN            NED  2023         Race  2023-03-19
# 1              2     L SARGEANT            USA  2023         Race  2023-03-19
# 2              4       L NORRIS            GBR  2023         Race  2023-03-19
# 3             10        P GASLY            FRA  2023         Race  2023-03-19
# 4             11        S PEREZ            MEX  2023         Race  2023-03-19
#
#   time_start    date_end  time_end gmt_offset  starting_position  wins_before  \
# 0   17:00:00  2023-03-19  19:00:00   03:00:00                 15            1
# 1   17:00:00  2023-03-19  19:00:00   03:00:00                 20            0
# 2   17:00:00  2023-03-19  19:00:00   03:00:00                 19            0
# 3   17:00:00  2023-03-19  19:00:00   03:00:00                  9            0
# 4   17:00:00  2023-03-19  19:00:00   03:00:00                  1            0
#
#    pit_stops_count  avg_pit_stop_duration position_category  \
# 0                0                    0.0              top3
# 1                0                    0.0         no_points
# 2                0                    0.0         no_points
# 3                0                    0.0            points
# 4                0                    0.0            winner
#
#    qualifying_position
# 0                    1
# 1                   16
# 2                    7
# 3                    9
# 4                    2

# %%
#zamien kolejnosc zeby position_category byla ostatnia kolumna
cols = data.columns.tolist()
cols = [col for col in cols if col != 'position_category'] + ['position_category']
data = data[cols]
data.head()
# Out:
#    driver_number broadcast_name country_code_x  year session_name  date_start  \
# 0              1   M VERSTAPPEN            NED  2023         Race  2023-03-19
# 1              2     L SARGEANT            USA  2023         Race  2023-03-19
# 2              4       L NORRIS            GBR  2023         Race  2023-03-19
# 3             10        P GASLY            FRA  2023         Race  2023-03-19
# 4             11        S PEREZ            MEX  2023         Race  2023-03-19
#
#   time_start    date_end  time_end gmt_offset  starting_position  wins_before  \
# 0   17:00:00  2023-03-19  19:00:00   03:00:00                 15            1
# 1   17:00:00  2023-03-19  19:00:00   03:00:00                 20            0
# 2   17:00:00  2023-03-19  19:00:00   03:00:00                 19            0
# 3   17:00:00  2023-03-19  19:00:00   03:00:00                  9            0
# 4   17:00:00  2023-03-19  19:00:00   03:00:00                  1            0
#
#    pit_stops_count  avg_pit_stop_duration  qualifying_position  \
# 0                0                    0.0                    1
# 1                0                    0.0                   16
# 2                0                    0.0                    7
# 3                0                    0.0                    9
# 4                0                    0.0                    2
#
#   position_category
# 0              top3
# 1         no_points
# 2         no_points
# 3            points
# 4            winner

# %%
# do csv zapisz x oraz y do pliku f1_data.csv
data.to_csv('../../datasets/thesis_f1_data.csv', index=False)

# %%
# wyswitel informacje o zbiorze danych
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)

#wyswietl cechy
print("Features in X:", X.columns.tolist())
# wyswietl unikalne kategorie pozycji
print("Unique position categories in y:", y.unique())
# Out:
# Shape of X: (2134, 16)
# Shape of y: (2134,)
# Features in X: ['driver_number', 'broadcast_name', 'country_code_x', 'year', 'session_name', 'date_start', 'time_start', 'date_end', 'time_end', 'gmt_offset', 'qualifying_position_x', 'starting_position', 'qualifying_position_y', 'wins_before', 'pit_stops_count', 'avg_pit_stop_duration']
# Unique position categories in y: ['top3' 'no_points' 'points' 'winner']

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

for col in X.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])

# %%
# !pip freeze > requirements.txt

# %%
import sklearn
import numpy as np
print(pd.__version__)
print(np.__version__)
print(requests.__version__)
print(sklearn.__version__)
# Out:
# 2.3.2
# 2.3.3
# 2.32.5
# 1.7.1

# %%
# dla kazdego session w all_sessions_df policz
